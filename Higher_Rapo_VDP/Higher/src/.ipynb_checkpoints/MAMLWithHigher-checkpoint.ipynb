# %%
#pip install torchsummary

# %%
# import os
# os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
# # For mutliple devices (GPUs: 4, 5, 6, 7)
# os.environ["CUDA_VISIBLE_DEVICES"] = "7"
from models import resnet
from lenet import Le

# %%
import random
import numpy as np
import torch
from torch import nn, optim
import learn2learn as l2l
from torchvision.models import resnet18
import torchvision
from torchvision import transforms
from learn2learn.data import TaskDataset
from learn2learn.data.transforms import (NWays,
                                         KShots,
                                         LoadData,
                                         RemapLabels,
                                         ConsecutiveLabels)
import torch.nn.functional as F
import random
from torchsummary import torchsummary
import higher

from jupyterplot import ProgressPlot
import numpy as np
import time
import mlogger
import utils
import argparse
# Out:
# Files already downloaded and verified

# %%
# import sys,os,argparse
# # def arg_parser():
    
# parser = argparse.ArgumentParser('MAML with Higher')

# # General
# general_params = parser.add_argument_group('General')
# general_params.add_argument('--data', type=str, default="./data",
#                             help='Path to the folder the data is downloaded to.')
# general_params.add_argument('--dataset', type=str,
#                             choices=["omniglot", "mini-imagenet", "fc100",
#                                      "cifarfs", "tiered-imagenet"], default='omniglot',
#                             help='Name of the dataset (default: omniglot).')

# meta_params = parser.add_argument_group('Meta Learning Parameters')
# meta_params.add_argument('--ways', type=int, default=5,
#                             help='Number of classes per task (N in "N-way", default: 5).')
# meta_params.add_argument('--shots', type=int, default=1,
#                             help='Number of training example per class (k in "k-shot", default: 5).')
# meta_params.add_argument('--adaptation-steps', type=int, default=1,
#                             help='Number of adaptation steps on meta-train datasets.')
# meta_params.add_argument('--num-tasks', type=int, default=32,
#                           help='Number of tasks to sample from task distribution.')
# meta_params.add_argument('--first-order', action='store_true',
#                           help='Use the first order approximation, do not use highers-order '
#                                'derivatives during meta-optimization.')
# meta_params.add_argument('--meta-lr', type=float, default=0.001,
#                           help='Learning rate for the meta-optimizer (optimization of the outer '
#                                'loss). The default optimizer is Adam (default: 1e-3).')
# meta_params.add_argument('--fast-lr', type=float, default=0.1,
#                           help='Learning rate for the meta-optimizer (optimization of the outer '
#                                'loss). The default optimizer is Adam (default: 1e-3).')
# meta_params.add_argument('--num-test-task', type=int, default=32,
#                             help='Number of test task used to calculate meta test and meta val')


# # Model
# model_params = parser.add_argument_group('Model')
# model_params.add_argument('--input', type=int, default=32,
#                           help='Input to dimension')
# model_params.add_argument('--fine-tune', type=int, default=0,
#                           help='Only meta learn the FC layer')

# # Optimization
# optim_params = parser.add_argument_group('Optimization')
# optim_params.add_argument('--num-epochs', type=int, default=50000,
#                           help='Number of epochs of meta-training (default: 50000).')
# optim_params.add_argument('--seed', type=int, default=utils.fix_seeds(),
#                           help='Number of epochs of meta-training (default: 101).')




# # Misc
# misc = parser.add_argument_group('Misc')
# misc.add_argument('--num-workers', type=int, default=4,
#                   help='Number of workers to use for data-loading (default: 1).')
# misc.add_argument('--device', type=str, default=utils.get_compute_device(), help="Compute device information")


# # Visualization
# viz = parser.add_argument_group('Misc')
# viz.add_argument('--wand_project', type=str, default="Github_Rapo",
#                   help='Wandb project name should go here')
# viz.add_argument('--username', type=str, default="hikmatkhan",
#                   help='Wandb username should go here')
# viz.add_argument('--wandb_logging', type=bool, default=True,
#                   help='If True, Logs will be reported on wandb.')
# viz.add_argument('--verbose', action='store_true')
# #     args = parser.parse_args()
# #     return parser.parse_args()
# # args = parser.parse_args()

# %%
# def main(argv):
#     print(argv)
    
# main(sys.argv)

# %%
#No randomization
seed = 101
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
device = torch.device('cpu')
if torch.cuda.device_count():
    torch.cuda.manual_seed(seed)
    device = torch.device('cuda')
    print("Device:", device)
# Out:
# Device: cuda

# %%
# #Dataset
# # transforms
# transform = transforms.Compose(
#     [transforms.ToTensor(),
#     transforms.Normalize((0.5,), (0.5,))])

# dataset = torchvision.datasets.MNIST(root="data", train=True, download=True, transform=transform)

# %%
# #MetaDataset MNIST or Custom Dataset
# dataset = l2l.data.MetaDataset(dataset)
# ways = 10
# shots = 1
# transforms = [
#     NWays(dataset, n=ways),
#     KShots(dataset, k=shots),
#     LoadData(dataset),
# ]
# tasksets = TaskDataset(dataset, transforms, num_tasks=5)
# # MetaDataset Sampling
# for task in tasksets:
#     X, y = task
#     print(y)

# %%
#Builtin-MetaDatasets
dataset_name = "omniglot"
# "omniglot"
# "mini-imagenet", 
# "fc100", 
# "cifarfs", 
# "tiered-imagenet"

ways = 5
shots = 1
meta_batch= 8
# Create Tasksets using the benchmark interface
tasksets = l2l.vision.benchmarks.get_tasksets(dataset_name,
                                              train_samples=2*shots,
                                              train_ways=ways,
                                              test_samples=2*shots,
                                              test_ways=ways,
                                              root='~/data',
                                              num_tasks=-1)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Separate data into adaptation/evalutation sets
# adaptation_indices = np.zeros(X.size(0), dtype=bool)
# adaptation_indices[np.arange(shots*ways) * 2] = True
# evaluation_indices = torch.from_numpy(~adaptation_indices)
# adaptation_indices = torch.from_numpy(adaptation_indices)

# %%
import matplotlib.pylab as plt
from torchvision import utils
X, y = tasksets.train.sample()
print("X.size:", X.size())
grid = utils.make_grid(X, nrow=shots * 2)
plt.imshow(grid.numpy().transpose((1, 2, 0)))
# Out:
# X.size: torch.Size([10, 1, 28, 28])

# %%
def get_indices(X, ways, shots):
    # Separate data into Meta-Train/Meta-Test sets
    meta_train_indices = np.zeros(X.size(0), dtype=bool)
    # print("X:", X.size())
    meta_train_indices[np.arange(shots * ways) * 2] = True
    meta_test_indices = torch.from_numpy(~meta_train_indices)
    meta_train_indices = torch.from_numpy(meta_train_indices)
    return meta_train_indices, meta_test_indices

def accuracy(predictions, targets):
    predictions = predictions.argmax(dim=1).view(targets.shape)
    return (predictions == targets).sum().float() / targets.size(0)

# %%
meta_train_indices, meta_test_indices = get_indices(X=X, ways=ways, shots=shots)
#Adaptation Data
grid = utils.make_grid(X[meta_train_indices], nrow=shots)
plt.imshow(grid.numpy().transpose((1, 2, 0)))

# %%
#Adaptation Data
grid = utils.make_grid(X[meta_test_indices], nrow=shots)
plt.imshow(grid.numpy().transpose((1, 2, 0)))

# %%
X, y = tasksets.validation.sample()
print("Validation:", y)
grid = utils.make_grid(X, nrow=shots*2)
plt.imshow(grid.numpy().transpose((1, 2, 0)))
# Out:
# Validation: tensor([0, 0, 4, 4, 3, 3, 1, 1, 2, 2])

# %%
X, y = tasksets.test.sample()
print("Test:", y)
grid = utils.make_grid(X, nrow=shots * 2)
plt.imshow(grid.numpy().transpose((1, 2, 0)))
# Out:
# Test: tensor([1, 1, 0, 0, 4, 4, 3, 3, 2, 2])

# %%
model = resnet.ResNet18S(out_dim=ways).to(device)
print(model)
# model = resnet18(pretrained=True).to(device)
# for param in model.parameters():
#     param.requires_grad = False
# num_ftrs = model.fc.in_features

# num_ftrs 
# model.fc = nn.Linear(num_ftrs, ways).to(device)

# print(model(torch.rand((1,3,84,84)).to(device)))
# torchsummary.summary(model, input_size= (3, 84, 84))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-21-4f59565ff539> in <module>
# ----> 1 model = resnet.ResNet18S(out_dim=ways).to(device)
#       2 print(model)
#       3 # model = resnet18(pretrained=True).to(device)
#       4 # for param in model.parameters():
#       5 #     param.requires_grad = False
#
# ~/anaconda3/envs/PY3/lib/python3.6/site-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#     423             return t.to(device, dtype if t.is_floating_point() else None, non_blocking)
#     424
# --> 425         return self._apply(convert)
#     426
#     427     def register_backward_hook(self, hook):
#
# ~/anaconda3/envs/PY3/lib/python3.6/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     199     def _apply(self, fn):
#     200         for module in self.children():
# --> 201             module._apply(fn)
#     202
#     203         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~/anaconda3/envs/PY3/lib/python3.6/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     221                 # `with torch.no_grad():`
#     222                 with torch.no_grad():
# --> 223                     param_applied = fn(param)
#     224                 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     225                 if should_use_set_data:
#
# ~/anaconda3/envs/PY3/lib/python3.6/site-packages/torch/nn/modules/module.py in convert(t)
#     421
#     422         def convert(t):
# --> 423             return t.to(device, dtype if t.is_floating_point() else None, non_blocking)
#     424
#     425         return self._apply(convert)
#
# RuntimeError: CUDA error: out of memory

# %%
# print(model.conv1.weight[0].grad)

# %%
# def main(argv):

# %%
meta_lr_lst = [0.01, 0.05, 0.09, 0.001, 0.005, 0.009]
fast_lr_lst = [0.1, 0.5, 0.9, 0.01, 0.05, 0.09, 0.001, 0.005, 0.009]
adaptation_steps_lst = [1, 5]
shots_lst = [1, 5]
meta_batch_lst = [4]

epochs = 1000
ways = 5
dataset_name = "omniglot"
model = resnet.ResNet18S(out_dim=ways).to(device)

for meta_lr in meta_lr_lst:
    for fast_lr in fast_lr_lst:
        for adaptation_steps in adaptation_steps_lst:
            for shots in shots_lst:
                for meta_batch in meta_batch_lst:

        #             meta_lr = 0.005
        #             fast_lr = 0.01
        #             adaptation_steps = 1
                    optim_meta = optim.Adam(model.parameters(), lr=meta_lr)
                    epochs = 1000
                    # pp = ProgressPlot(plot_names=["ACC", "LOSS"],
                    #                   line_names=["SS", "QS"])
                    tasksets = l2l.vision.benchmarks.get_tasksets(dataset_name,
                                              train_samples=2*shots,
                                              train_ways=ways,
                                              test_samples=2*shots,
                                              test_ways=ways,
                                              root='~/data',
                                              num_tasks=-1)



                    WANDB_LOGGER = True
                    if(WANDB_LOGGER):
                        import wandb
                        wandb.init(project="JOmniGlot", entity="hikmatkhan-", reinit=True)
                        wandb.watch(model, log_freq=10)
                        wandb.log({"Dataset":dataset_name,
                                  "Ways":ways,
                                  "Shots":shots,
                                  "Meta Batch": meta_batch,
                                  "Meta_lr": meta_lr,
                                  "Fast_lr": fast_lr,
                                  "Adaptation Step": adaptation_steps})
        #             if __name__ == "__main__":

                #     meta_train_spt_loss = mlogger.metric.Average()
                #     meta_train_spt_acc = mlogger.metric.Average()
                #     meta_train_qry_loss = mlogger.metric.Average()
                #     meta_train_qry_acc = mlogger.metric.Average()

                    for e in range(epochs):
                        optim_meta.zero_grad()
                        model.train()
                        meta_train_loss = mlogger.metric.Average()
                        meta_train_acc = mlogger.metric.Average()
                        meta_val_loss = mlogger.metric.Average()
                        meta_val_acc = mlogger.metric.Average()
                        meta_test_loss = mlogger.metric.Average()
                        meta_test_acc = mlogger.metric.Average()
                        for t in range(meta_batch):
                            X, y = tasksets.train.sample()

                            X, y = X.to(device), y.to(device)
                #             print(X.size())
                            meta_train_indices, meta_test_indices = get_indices(X=X, ways=ways, shots=shots)
                            optim_fast = optim.Adam(model.parameters(), lr=fast_lr)
                            with higher.innerloop_ctx(model=model, opt=optim_fast, copy_initial_weights=False
                                                     ) as (fmodel, diff_opp):


                #                 print(fmodel.conv1.weight[0].grad)
                                for a in range(adaptation_steps):
                                    y_prd = fmodel(X[meta_train_indices])
                #                     a_meta_train_spt_acc.update(accuracy(y_prd, y[meta_train_indices]))
                                    meta_train_spt_loss = F.cross_entropy(y_prd, y[meta_train_indices])
                #                     a_meta_train_spt_loss.update(meta_train_spt_loss.detach().cpu().item())
                                    diff_opp.step(meta_train_spt_loss)
                #                 meta_train_spt_loss.update(a_meta_train_spt_loss.value)
                #                 meta_train_spt_acc.update(a_meta_train_spt_acc.value)

                                y_prd = fmodel(X[meta_test_indices])
                                meta_train_acc.update(accuracy(y_prd, y[meta_test_indices]))
                                meta_train_qry_loss = F.cross_entropy(y_prd, y[meta_test_indices])
                                meta_train_loss.update(meta_train_qry_loss.detach().cpu().item())

                                meta_train_qry_loss.backward()


                        optim_meta.step()
                        if(WANDB_LOGGER):
                            wandb.log({"Meta Update": e})
                        print("Meta-Update")

                        for t in range(meta_batch):
                            model.eval()
                            X_val, y_val = tasksets.validation.sample()
                            X_val, y_val = X_val.to(device), y_val.to(device)

                #             print(X.size())
                            meta_train_indices, meta_test_indices = get_indices(X=X_val, ways=ways, shots=shots)
                            optim_fast = optim.Adam(model.parameters(), lr=fast_lr)
                            with higher.innerloop_ctx(model=model, opt=optim_fast,  track_higher_grads=False
                                                     ) as (fmodel, diff_opp):


                #                 print(fmodel.conv1.weight[0].grad)
                                for a in range(adaptation_steps):
                                    y_prd = fmodel(X_val[meta_train_indices])
                #                     a_meta_train_spt_acc.update(accuracy(y_prd, y[meta_train_indices]))
                                    meta_val_spt_loss = F.cross_entropy(y_prd, y_val[meta_train_indices])
                #                     a_meta_train_spt_loss.update(meta_train_spt_loss.detach().cpu().item())
                                    diff_opp.step(meta_val_spt_loss)
                #                 meta_train_spt_loss.update(a_meta_train_spt_loss.value)
                #                 meta_train_spt_acc.update(a_meta_train_spt_acc.value)

                                y_prd = fmodel(X_val[meta_test_indices])
                                meta_val_acc.update(accuracy(y_prd, y_val[meta_test_indices]))
                                meta_val_qry_loss = F.cross_entropy(y_prd, y_val[meta_test_indices])
                                meta_val_loss.update(meta_val_qry_loss.detach().cpu().item())



                        for t in range(meta_batch):
                            model.eval()
                            X_test, y_test = tasksets.test.sample()
                            X_test, y_test = X_test.to(device), y_test.to(device)

                            meta_train_indices, meta_test_indices = get_indices(X=X_test, ways=ways, shots=shots)
                            optim_fast = optim.Adam(model.parameters(), lr=fast_lr)
                            with higher.innerloop_ctx(model=model, opt=optim_fast,  track_higher_grads=False
                                                     ) as (fmodel, diff_opp):


                #                 print(fmodel.conv1.weight[0].grad)
                                for a in range(adaptation_steps):
                                    y_prd = fmodel(X_test[meta_train_indices])
                #                     a_meta_train_spt_acc.update(accuracy(y_prd, y[meta_train_indices]))
                                    meta_test_spt_loss = F.cross_entropy(y_prd, y_test[meta_train_indices])
                #                     a_meta_train_spt_loss.update(meta_train_spt_loss.detach().cpu().item())
                                    diff_opp.step(meta_test_spt_loss)
                #                 meta_train_spt_loss.update(a_meta_train_spt_loss.value)
                #                 meta_train_spt_acc.update(a_meta_train_spt_acc.value)

                                y_prd = fmodel(X_test[meta_test_indices])
                                meta_test_acc.update(accuracy(y_prd, y_test[meta_test_indices]))
                                meta_test_qry_loss = F.cross_entropy(y_prd, y_test[meta_test_indices])
                                meta_test_loss.update(meta_test_qry_loss.detach().cpu().item())


                #                 meta_train_qry_loss.backward()

                        if(WANDB_LOGGER):
                            wandb.log({
                                   "Meta Train Acc": meta_train_acc.value,
                                   "Meta Train Loss": meta_train_loss.value,
                                    "Meta Val Acc": meta_val_acc.value,
                                    "Meta Val Loss": meta_val_loss.value,
                                    "Meta Test Acc": meta_test_acc.value,
                                    "Meta Test Loss": meta_test_loss.value
                                   })
                        print("Epoch|", e, "|", "Meta Train Acc:", meta_train_acc.value, " Meta Train Loss:", meta_train_loss.value,
                             "Meta Val Acc:", meta_val_acc.value, " Meta Val Loss:", meta_val_loss.value,
                             "Meta Test Acc:", meta_test_acc.value, " Meta Test Loss:", meta_test_loss.value)


                        meta_train_loss.reset()
                        meta_train_acc.reset()
                        meta_val_loss.reset()
                        meta_val_acc.reset()
                        meta_test_loss.reset()
                        meta_test_acc.reset()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# wandb: Currently logged in as: hikmatkhan- (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.12.0<br/>
#                 Syncing run <strong style="color:#cdcd00">fallen-plant-15</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hikmatkhan-/JOmniGlot" target="_blank">https://wandb.ai/hikmatkhan-/JOmniGlot</a><br/>
#                 Run page: <a href="https://wandb.ai/hikmatkhan-/JOmniGlot/runs/119qp9h7" target="_blank">https://wandb.ai/hikmatkhan-/JOmniGlot/runs/119qp9h7</a><br/>
#                 Run data is saved locally in <code>/home/hikmat/Desktop/JWorkSpace/Higher/src/wandb/run-20210818_212943-119qp9h7</code><br/><br/>
# Meta-Update
# Epoch| 0 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 9.923666954040527 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.7088354612703396e+19 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.064112517167553e+19
# Meta-Update
# Epoch| 1 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 14.696087121963501 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 8.436266073807913e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.442807607831036e+18
# Meta-Update
# Epoch| 2 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 11.2800572514534 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 6.705109153590804e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 6.342605667471196e+17
# Meta-Update
# Epoch| 3 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 7.840957283973694 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.661701324906169e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.7086214473449475e+17
# Meta-Update
# Epoch| 4 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 9.983377456665039 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.3322426398788813e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.693078003650396e+17
# Meta-Update
# Epoch| 5 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 10.573853969573975 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.721129664082084e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.643410845734011e+17
# Meta-Update
# Epoch| 6 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 12.956754684448242 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.0644947379368755e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.6176551724004147e+17
# Meta-Update
# Epoch| 7 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 9.849519610404966 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.2820551466745856e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.552252763331625e+17
# Meta-Update
# Epoch| 8 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 8.268102526664734 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.4868094719557632e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.692285388910756e+17
# Meta-Update
# Epoch| 9 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 11.764165163040161 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 7.105961973199667e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.0453527687782728e+18
# Meta-Update
# Epoch| 10 | Meta Train Acc: 0.30000000447034836  Meta Train Loss: 8.937526524066925 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.62005869342045e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.6592726725458657e+18
# Meta-Update
# Epoch| 11 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 14.175553560256958 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.4353277893059543e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 5.775371054675395e+18
# Meta-Update
# Epoch| 12 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 8.987972497940063 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 6.796463451574108e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 4.2115375906349384e+18
# Meta-Update
# Epoch| 13 | Meta Train Acc: 0.30000000447034836  Meta Train Loss: 8.179528951644897 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 6.790529662196908e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 8.392182134344778e+18
# Meta-Update
# Epoch| 14 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 9.83278489112854 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 8.687508414944772e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 9.460233779512607e+18
# Meta-Update
# Epoch| 15 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 10.620193839073181 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.1118141046108717e+19 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.2478335473397268e+19
# Meta-Update
# Epoch| 16 | Meta Train Acc: 0.30000000447034836  Meta Train Loss: 6.275931537151337 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.4260088788552463e+21 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.427065887761539e+21
# Meta-Update
# Epoch| 17 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 12.340959072113037 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.1748612299962335e+21 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.3156455839351838e+21
# Meta-Update
# Epoch| 18 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 12.810118198394775 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 8.062866716766042e+20 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 9.3878966236482e+20
# Meta-Update
# Epoch| 19 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 10.06419324874878 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 7.476981126711183e+20 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 7.27221590967697e+20
# Meta-Update
# Epoch| 20 | Meta Train Acc: 0.10000000149011612  Meta Train Loss: 10.473921060562134 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 5.121480478028055e+20 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 6.958024656618583e+20
# Meta-Update
# Epoch| 21 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 18.088855981826782 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.143195020987382e+20 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 4.6969245578590945e+20
# Meta-Update
# Epoch| 22 | Meta Train Acc: 0.30000000819563866  Meta Train Loss: 11.915695786476135 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.72162295547388e+20 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.341456518741492e+20
# Meta-Update
# Epoch| 23 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 11.43453049659729 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.365620573746055e+20 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.2335129762352805e+20
# Meta-Update
# Epoch| 24 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 11.246372699737549 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.228305137460964e+20 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 4.7260434080826026e+20
# Meta-Update
# Epoch| 25 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 8.837173223495483 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.59703685312593e+20 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.803122167760038e+20
# Meta-Update
# Epoch| 26 | Meta Train Acc: 0.30000000447034836  Meta Train Loss: 17.105190753936768 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.174592391106485e+20 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.7788867764410647e+20
# Meta-Update
# Epoch| 27 | Meta Train Acc: 0.20000000298023227  Meta Train Loss: 11.477238893508911 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.0442124782066677e+20 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.233431612374825e+20
# Meta-Update
# Epoch| 28 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 13.548426866531372 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.8861759135660114e+20 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.0778420328520168e+20
# Meta-Update
# Epoch| 29 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 15.593254804611206 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 9.933883927402696e+19 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.03893651953996e+20
# Meta-Update
# Epoch| 30 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 12.971576690673828 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 5.075580089693058e+19 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 7.618968188041245e+19
# Meta-Update
# Epoch| 31 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 15.844146728515625 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.2958007277632094e+19 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.2806241687650173e+19
# Meta-Update
# Epoch| 32 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 10.669413566589355 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.2289754641211064e+19 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.5104266638928118e+19
# Meta-Update
# Epoch| 33 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 10.689773082733154 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.4254093756377596e+19 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.6211891857376936e+19
# Meta-Update
# Epoch| 34 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 15.516556024551392 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 6.915868215327326e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.0055194639587082e+19
# Meta-Update
# Epoch| 35 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 12.475780725479126 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 5.699645627286159e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 6.744078182141395e+18
# Meta-Update
# Epoch| 36 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 8.919274926185608 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 6.240453478108365e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 5.767795694437925e+18
# Meta-Update
# Epoch| 37 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 11.961472153663635 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 5.315563675715633e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 5.309918920457585e+18
# Meta-Update
# Epoch| 38 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 15.230561971664429 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 5.246560799857574e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 5.181949648318759e+18
# Meta-Update
# Epoch| 39 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 12.851895332336426 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 5.059694125792625e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 4.203942301749215e+18
# Meta-Update
# Epoch| 40 | Meta Train Acc: 0.10000000149011612  Meta Train Loss: 12.83756971359253 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.3271671812141875e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.8052000118897377e+18
# Meta-Update
# Epoch| 41 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 12.7118079662323 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.92745031173564e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.846582537182773e+18
# Meta-Update
# Epoch| 42 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 16.058215856552124 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.753028872346534e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 4.134937089428947e+18
# Meta-Update
# Epoch| 43 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 17.05891180038452 Meta Val Acc: 0.2500000037252903  Meta Val Loss: 3.215488632643125e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.611073399985537e+18
# Meta-Update
# Epoch| 44 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 13.239678621292114 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.3320078655681987e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.8872815255339663e+18
# Meta-Update
# Epoch| 45 | Meta Train Acc: 0.30000000447034836  Meta Train Loss: 12.084883213043213 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.306756275366265e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.476104774263243e+18
# Meta-Update
# Epoch| 46 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 11.145437717437744 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.2693430557689774e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.475307697052582e+18
# Meta-Update
# Epoch| 47 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 13.342720985412598 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.03276627708792e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.659271522981249e+18
# Meta-Update
# Epoch| 48 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 11.416752576828003 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.228973318124077e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.7395432935123845e+18
# Meta-Update
# Epoch| 49 | Meta Train Acc: 0.10000000149011612  Meta Train Loss: 9.786709308624268 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.7083056184114545e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 4.022123623006339e+18
# Meta-Update
# Epoch| 50 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 12.473947763442993 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.700483898849886e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.640685515864277e+18
# Meta-Update
# Epoch| 51 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 9.33191466331482 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.247903250528862e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 4.0536548677118853e+18
# Meta-Update
# Epoch| 52 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 9.840361833572388 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.4988461637257134e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.7676341663346196e+18
# Meta-Update
# Epoch| 53 | Meta Train Acc: 0.30000000447034836  Meta Train Loss: 7.466721415519714 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.9349911060763116e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.9047810620304916e+18
# Meta-Update
# Epoch| 54 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 9.400958776473999 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 5.582542210089353e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 6.002610696200651e+18
# Meta-Update
# Epoch| 55 | Meta Train Acc: 0.30000000447034836  Meta Train Loss: 12.43401575088501 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 5.108607412382728e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 7.794665115894153e+18
# Meta-Update
# Epoch| 56 | Meta Train Acc: 0.20000000298023227  Meta Train Loss: 12.541218519210815 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.649836529290576e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 5.202013742660846e+18
# Meta-Update
# Epoch| 57 | Meta Train Acc: 0.30000000819563866  Meta Train Loss: 12.435229420661926 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.722920311274602e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 5.695952505167413e+18
# Meta-Update
# Epoch| 58 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 9.414663910865784 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 5.353091244522209e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 5.666909455275524e+18
# Meta-Update
# Epoch| 59 | Meta Train Acc: 0.30000000819563866  Meta Train Loss: 7.396119654178619 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 6.112215650254455e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 4.836434441482011e+18
# Meta-Update
# Epoch| 60 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 10.162558913230896 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 5.276118421191262e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 5.156581578603758e+18
# Meta-Update
# Epoch| 61 | Meta Train Acc: 0.30000000447034836  Meta Train Loss: 8.412436783313751 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.693413130036838e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 4.1689554294365225e+18
# Meta-Update
# Epoch| 62 | Meta Train Acc: 0.30000000447034836  Meta Train Loss: 9.342684030532837 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 5.445651294444323e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 4.3017420056140186e+18
# Meta-Update
# Epoch| 63 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 10.335490942001343 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.680978134563029e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 4.400160390927876e+18
# Meta-Update
# Epoch| 64 | Meta Train Acc: 0.10000000149011612  Meta Train Loss: 11.915389060974121 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.1246626843567063e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 4.759750652270215e+18
# Meta-Update
# Epoch| 65 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 7.532225131988525 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.1454807187445514e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.816578445408731e+18
# Meta-Update
# Epoch| 66 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 10.81169718503952 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.86875810616705e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 4.07775733082384e+18
# Meta-Update
# Epoch| 67 | Meta Train Acc: 0.10000000149011612  Meta Train Loss: 12.130484819412231 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.998121815261315e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.360643855639642e+18
# Meta-Update
# Epoch| 68 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 15.869213342666626 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.0805488534078095e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.409753164537135e+18
# Meta-Update
# Epoch| 69 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 11.154020309448242 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.946643471122825e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.444378984719057e+18
# Meta-Update
# Epoch| 70 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 10.642457962036133 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.528136600760615e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.0065101426018222e+18
# Meta-Update
# Epoch| 71 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 11.782948732376099 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.70672965598498e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.258930868145881e+18
# Meta-Update
# Epoch| 72 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 9.046246647834778 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.7829102281618883e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.818066012948398e+18
# Meta-Update
# Epoch| 73 | Meta Train Acc: 0.4000000096857548  Meta Train Loss: 12.716322541236877 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.182164306324357e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.4067330623070536e+18
# Meta-Update
# Epoch| 74 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 14.636420249938965 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.802558088633385e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.079362202510295e+18
# Meta-Update
# Epoch| 75 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 9.47899341583252 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.984991600534618e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.9270995645531423e+18
# Meta-Update
# Epoch| 76 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 9.945908546447754 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.5405069469000663e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.952980178485379e+18
# Meta-Update
# Epoch| 77 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 14.103137969970703 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.7289721047133716e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.5998249120238141e+18
# Meta-Update
# Epoch| 78 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 12.189785718917847 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.4483346466254356e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.3150351654534513e+18
# Meta-Update
# Epoch| 79 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 11.971826553344727 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.6200846163564298e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.7821428377651773e+18
# Meta-Update
# Epoch| 80 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 13.122782230377197 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.095594189591937e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.6949086847290573e+18
# Meta-Update
# Epoch| 81 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 9.72925877571106 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.2397948646968525e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.527184405024473e+18
# Meta-Update
# Epoch| 82 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 12.672417998313902 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.14751986316424e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.9816844069972214e+18
# Meta-Update
# Epoch| 83 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 12.982574939727783 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.304022217958097e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.1736973452359762e+18
# Meta-Update
# Epoch| 84 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 15.186131000518799 Meta Val Acc: 0.15000000223517418  Meta Val Loss: 3.336344305068409e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.6069756389212815e+18
# Meta-Update
# Epoch| 85 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 16.245237588882446 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.7944488310879027e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.0720928501027308e+18
# Meta-Update
# Epoch| 86 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 10.652629375457764 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.1618255058740183e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.434680070904742e+18
# Meta-Update
# Epoch| 87 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 17.426095962524414 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.29841048240862e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.7939818292172554e+18
# Meta-Update
# Epoch| 88 | Meta Train Acc: 0.30000000447034836  Meta Train Loss: 13.096966028213501 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.2108605962500178e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 9.786167165295002e+17
# Meta-Update
# Epoch| 89 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 11.539350748062134 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 8.330316360261304e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 7.213171830150922e+17
# Meta-Update
# Epoch| 90 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 15.701698303222656 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.0095682265494323e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 8.280113518330511e+17
# Meta-Update
# Epoch| 91 | Meta Train Acc: 0.10000000149011612  Meta Train Loss: 12.335607051849365 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 9.568213981798072e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 5.67102576911188e+17
# Meta-Update
# Epoch| 92 | Meta Train Acc: 0.30000000447034836  Meta Train Loss: 10.65968370437622 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.926849670635848e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 4.356395292656927e+17
# Meta-Update
# Epoch| 93 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 9.867162466049194 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.09327142271189e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 4.1896498016393626e+17
# Meta-Update
# Epoch| 94 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 9.835570335388184 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 5.807595421203169e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.9426384742488474e+17
# Meta-Update
# Epoch| 95 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 9.606969356536865 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.057552364362793e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.4983521106644173e+17
# Meta-Update
# Epoch| 96 | Meta Train Acc: 0.30000000447034836  Meta Train Loss: 10.718966245651245 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.406525967573975e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.608460383345705e+17
# Meta-Update
# Epoch| 97 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 10.934585809707642 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.258863687754056e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.3422618751624806e+17
# Meta-Update
# Epoch| 98 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 10.968518137931824 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.8356338035785728e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.9014386081333248e+17
# Meta-Update
# Epoch| 99 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 17.012375593185425 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.8945635036587622e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.315071167355945e+17
# Meta-Update
# Epoch| 100 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 11.674641132354736 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.0918066555020902e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.948292599638917e+17
# Meta-Update
# Epoch| 101 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 9.943961143493652 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.486957734226821e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.582583162437632e+17
# Meta-Update
# Epoch| 102 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 10.200574159622192 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.151992703722455e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.8313807394701312e+17
# Meta-Update
# Epoch| 103 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 13.535854578018188 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.363209359864627e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.5089768289625702e+17
# Meta-Update
# Epoch| 104 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 10.408399105072021 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.191662509213614e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.170422322490245e+17
# Meta-Update
# Epoch| 105 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 7.9357611536979675 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.1520784585261056e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.3463179406842266e+17
# Meta-Update
# Epoch| 106 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 10.5653156042099 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.9320093007478784e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 5.096689427892142e+17
# Meta-Update
# Epoch| 107 | Meta Train Acc: 0.30000000447034836  Meta Train Loss: 6.616019248962402 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.9195817269775565e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.786919909523456e+17
# Meta-Update
# Epoch| 108 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 8.838943839073181 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 5.0028643211227955e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.9089253275140096e+17
# Meta-Update
# Epoch| 109 | Meta Train Acc: 0.20000000298023227  Meta Train Loss: 12.029895544052124 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 7.105093273114378e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 6.55213410081833e+17
# Meta-Update
# Epoch| 110 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 7.757867693901062 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 6.080712649253847e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 5.841611046791414e+17
# Meta-Update
# Epoch| 111 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 8.562608480453491 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 6.394301182336041e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 8.594375759982756e+17
# Meta-Update
# Epoch| 112 | Meta Train Acc: 0.10000000149011613  Meta Train Loss: 9.272139430046082 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 8.310380324664115e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.0101047195043103e+18
# Meta-Update
# Epoch| 113 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 11.891605377197266 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 9.789497654735012e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.0227523330391409e+18
# Meta-Update
# Epoch| 114 | Meta Train Acc: 0.20000000298023227  Meta Train Loss: 8.384395718574524 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.348280514426962e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.6198731665265132e+18
# Meta-Update
# Epoch| 115 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 7.465103030204773 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.0416211566492385e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.7071158407777485e+18
# Meta-Update
# Epoch| 116 | Meta Train Acc: 0.30000000447034836  Meta Train Loss: 8.147477388381958 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.7556756687392604e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.4378337092847534e+18
# Meta-Update
# Epoch| 117 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 8.235656976699829 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.720878102891725e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.9701194000988897e+18
# Meta-Update
# Epoch| 118 | Meta Train Acc: 0.30000000819563866  Meta Train Loss: 4.446298360824585 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.298481335162372e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.630888489303671e+18
# Meta-Update
# Epoch| 119 | Meta Train Acc: 0.30000000447034836  Meta Train Loss: 7.780850768089294 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.790261978195296e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 4.810314993008378e+18
# Meta-Update
# Epoch| 120 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 10.017624735832214 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.4492718458223985e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.765990412144345e+18
# Meta-Update
# Epoch| 121 | Meta Train Acc: 0.30000000447034836  Meta Train Loss: 6.623641014099121 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.6201497310338744e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.6558625558988063e+18
# Meta-Update
# Epoch| 122 | Meta Train Acc: 0.10000000149011612  Meta Train Loss: 6.103365063667297 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.628379453822075e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.0829255135374868e+18
# Meta-Update
# Epoch| 123 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 11.078747987747192 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.4304628253369303e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.5993589252520673e+18
# Meta-Update
# Epoch| 124 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 6.1448827385902405 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.58275081929438e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.0605449199943683e+18
# Meta-Update
# Epoch| 125 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 8.255837559700012 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.146109875453952e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.0349230162255544e+18
# Meta-Update
# Epoch| 126 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 10.472809910774231 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.154408134686802e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.881046093500252e+17
# Meta-Update
# Epoch| 127 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 9.093946695327759 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.6545617148706816e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.7774745892447846e+17
# Meta-Update
# Epoch| 128 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 9.848528742790222 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.96541634516353e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.9250818777900646e+17
# Meta-Update
# Epoch| 129 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 8.261312365531921 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.47286484140032e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 4.0480781447358054e+17
# Meta-Update
# Epoch| 130 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 9.94956350326538 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.945088249258312e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 4.68587838301012e+17
# Meta-Update
# Epoch| 131 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 5.793732702732086 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.706916694707405e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 5.100184242780897e+17
# Meta-Update
# Epoch| 132 | Meta Train Acc: 0.20000000298023227  Meta Train Loss: 10.12896466255188 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.827018669091717e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 5.0782926226744934e+17
# Meta-Update
# Epoch| 133 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 6.357264161109924 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.5128591473639424e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 4.1696010661003264e+17
# Meta-Update
# Epoch| 134 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 11.916383981704712 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.287341581565952e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.950507998283039e+17
# Meta-Update
# Epoch| 135 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 8.666736960411072 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 5.234886872588616e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 4.881088340285194e+17
# Meta-Update
# Epoch| 136 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 8.598928213119507 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.6355066357088256e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.326345054267638e+17
# Meta-Update
# Epoch| 137 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 10.552253127098083 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.016778742364897e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.5451547401427354e+17
# Meta-Update
# Epoch| 138 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 9.049731016159058 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.3285781638702694e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 5.012703575801856e+17
# Meta-Update
# Epoch| 139 | Meta Train Acc: 0.30000000447034836  Meta Train Loss: 8.234134554862976 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 4.292523459608576e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.3404565558657024e+17
# Meta-Update
# Epoch| 140 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 9.662342190742493 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.9223391703177626e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 5.14353893115691e+17
# Meta-Update
# Epoch| 141 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 8.359851598739624 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 5.80495779588735e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 4.4091765752542e+17
# Meta-Update
# Epoch| 142 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 10.276349067687988 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.942300229881037e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 4.022671952891085e+17
# Meta-Update
# Epoch| 143 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 7.048049092292786 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 6.106457799917568e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.0122411736762941e+18
# Meta-Update
# Epoch| 144 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 10.69607162475586 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.345600746892034e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 9.351698495653806e+17
# Meta-Update
# Epoch| 145 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 7.398181259632111 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 8.147177923967713e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 7.675033028111892e+17
# Meta-Update
# Epoch| 146 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 9.525869488716125 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.1358903100107653e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.3745025267196232e+18
# Meta-Update
# Epoch| 147 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 5.126072466373444 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.3031814366468506e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.4577958239233638e+18
# Meta-Update
# Epoch| 148 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 7.188901424407959 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.9168402105329254e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.3154004266521723e+18
# Meta-Update
# Epoch| 149 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 5.505013525485992 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.8719116743409664e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.8714737337056625e+18
# Meta-Update
# Epoch| 150 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 10.330336332321167 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.9788074317439304e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.6421564189308355e+18
# Meta-Update
# Epoch| 151 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 9.0033118724823 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.424308274640716e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.3501320920081367e+18
# Meta-Update
# Epoch| 152 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 13.191285133361816 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.564911794376147e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.1049788649323889e+18
# Meta-Update
# Epoch| 153 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 6.316612958908081 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.006571103881003e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.1975699917512376e+18
# Meta-Update
# Epoch| 154 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 8.650127530097961 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.5866021007754527e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.2270180585457582e+18
# Meta-Update
# Epoch| 155 | Meta Train Acc: 0.10000000149011612  Meta Train Loss: 10.591489672660828 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.3358250076759654e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.1192609525548974e+18
# Meta-Update
# Epoch| 156 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 12.785984516143799 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.9307807466628055e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.5183096453812716e+18
# Meta-Update
# Epoch| 157 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 10.722191095352173 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.245936176817242e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.2233804274044764e+18
# Meta-Update
# Epoch| 158 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 7.552147090435028 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.539259894555738e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.0386855636822917e+18
# Meta-Update
# Epoch| 159 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 7.654178857803345 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.0477025711557181e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.353688463854797e+18
# Meta-Update
# Epoch| 160 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 9.325751423835754 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.281493894719865e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.165694053123621e+18
# Meta-Update
# Epoch| 161 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 9.383009552955627 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.5006672082194924e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.3302205033647964e+18
# Meta-Update
# Epoch| 162 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 6.740514755249023 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.1648115561167585e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.6047565652717732e+18
# Meta-Update
# Epoch| 163 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 9.099478721618652 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.5786577670008996e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.7062382758799606e+18
# Meta-Update
# Epoch| 164 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 7.8744001388549805 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.9557759788567757e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.4050628682981048e+18
# Meta-Update
# Epoch| 165 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 8.151268243789673 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.813156006335611e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.986021275994161e+18
# Meta-Update
# Epoch| 166 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 6.5256534814834595 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.8911475959091692e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.101424859612709e+18
# Meta-Update
# Epoch| 167 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 6.310860753059387 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.3518938031802286e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.9643505546457254e+18
# Meta-Update
# Epoch| 168 | Meta Train Acc: 0.10000000149011612  Meta Train Loss: 7.317796587944031 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.218843189593244e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 7.684330945112965e+17
# Meta-Update
# Epoch| 169 | Meta Train Acc: 0.30000000447034836  Meta Train Loss: 7.726330041885376 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.5744064709323653e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 9.632976505164268e+17
# Meta-Update
# Epoch| 170 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 7.63505482673645 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.142278300769452e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.674190526997332e+18
# Meta-Update
# Epoch| 171 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 8.18169367313385 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.8556487291350548e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.1479559468870533e+18
# Meta-Update
# Epoch| 172 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 6.94914436340332 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.692561606847496e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.1485732296633876e+18
# Meta-Update
# Epoch| 173 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 7.975317716598511 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.0442858731321426e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 6.822186182508544e+17
# Meta-Update
# Epoch| 174 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 6.938373684883118 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.1001913922499379e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 9.436448766023434e+17
# Meta-Update
# Epoch| 175 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 7.004334211349487 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.7482459766126019e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 8.169625570540257e+17
# Meta-Update
# Epoch| 176 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 5.606955170631409 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.89216447236617e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 9.446151913188884e+17
# Meta-Update
# Epoch| 177 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 7.095903992652893 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.491212920049107e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.4559125365986427e+18
# Meta-Update
# Epoch| 178 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 7.089890837669373 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.0185147379162808e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.19289010948617e+18
# Meta-Update
# Epoch| 179 | Meta Train Acc: 0.20000000298023227  Meta Train Loss: 7.495798945426941 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 5.5489802361267814e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 7.62337526600958e+17
# Meta-Update
# Epoch| 180 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 5.512977719306946 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.045466509588824e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 5.7104832471131757e+17
# Meta-Update
# Epoch| 181 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 6.685760021209717 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.1424242609380393e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 7.085891075629384e+17
# Meta-Update
# Epoch| 182 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 8.66198205947876 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 9.063685204329103e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 8.888081429162885e+17
# Meta-Update
# Epoch| 183 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 7.107319474220276 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 6.570392006793626e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.0526178777581486e+18
# Meta-Update
# Epoch| 184 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 7.055168986320496 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.487204976827564e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 8.461121436096922e+17
# Meta-Update
# Epoch| 185 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 6.952191770076752 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.6924717031054377e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.001029144370217e+18
# Meta-Update
# Epoch| 186 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 7.406308889389038 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 5.93214440472576e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 7.11474260433961e+17
# Meta-Update
# Epoch| 187 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 6.910059571266174 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 8.760299022461174e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.5891742005835858e+18
# Meta-Update
# Epoch| 188 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 6.74048376083374 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.7864025519696118e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.6108400256693043e+18
# Meta-Update
# Epoch| 189 | Meta Train Acc: 0.15000000223517418  Meta Train Loss: 6.185265958309174 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 9.888803483371438e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.4271329185258537e+18
# Meta-Update
# Epoch| 190 | Meta Train Acc: 0.20000000298023227  Meta Train Loss: 5.392701327800751 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 7.049304998013829e+17 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.0392141008711188e+18
# Meta-Update
# Epoch| 191 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 7.2605860233306885 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.3789813201025106e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.1925337732294902e+18
# Meta-Update
# Epoch| 192 | Meta Train Acc: 0.20000000298023224  Meta Train Loss: 9.201991200447083 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.1295642698603561e+18 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 6.550528899741123e+17
# Meta-Update
# ...
# Meta-Update
# Epoch| 957 | Meta Train Acc: 0.7500000074505806  Meta Train Loss: 0.7643183469772339 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 9.4064852098757e+26 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.14545992575624e+27
# Meta-Update
# Epoch| 958 | Meta Train Acc: 0.350000012665987  Meta Train Loss: 1.684473693370819 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.2940592590619976e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.0964649492213537e+27
# Meta-Update
# Epoch| 959 | Meta Train Acc: 0.5500000156462193  Meta Train Loss: 0.8769835084676743 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.096278563319233e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 9.974181637368543e+26
# Meta-Update
# Epoch| 960 | Meta Train Acc: 0.6000000089406967  Meta Train Loss: 0.8559119254350662 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.4811135420607816e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.2316915183250603e+27
# Meta-Update
# Epoch| 961 | Meta Train Acc: 0.7000000104308128  Meta Train Loss: 0.6894909366965294 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.0949620376414364e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.146053541980532e+27
# Meta-Update
# Epoch| 962 | Meta Train Acc: 0.7000000178813934  Meta Train Loss: 0.9864323288202286 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.1946447192876447e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.160390351474619e+27
# Meta-Update
# Epoch| 963 | Meta Train Acc: 0.7000000104308128  Meta Train Loss: 0.8388830721378326 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 9.45988862620281e+26 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.37581011904857e+27
# Meta-Update
# Epoch| 964 | Meta Train Acc: 0.5500000193715096  Meta Train Loss: 0.8791904896497726 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.4513850275660084e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.2892408403827362e+27
# Meta-Update
# Epoch| 965 | Meta Train Acc: 0.5500000081956387  Meta Train Loss: 1.2835964858531952 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.3129255189894315e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.3130111856689098e+27
# Meta-Update
# Epoch| 966 | Meta Train Acc: 0.7500000149011612  Meta Train Loss: 0.7314309179782867 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.266208161945326e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.1350528630456633e+27
# Meta-Update
# Epoch| 967 | Meta Train Acc: 0.5500000156462193  Meta Train Loss: 1.489369511604309 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.1372074519768447e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.0783454872809999e+27
# Meta-Update
# Epoch| 968 | Meta Train Acc: 0.6500000134110451  Meta Train Loss: 0.7868505269289017 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.2163421854955115e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.195393841564478e+27
# Meta-Update
# Epoch| 969 | Meta Train Acc: 0.5000000149011612  Meta Train Loss: 1.1406981647014618 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.188197766701324e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.2530707228574235e+27
# Meta-Update
# Epoch| 970 | Meta Train Acc: 0.6000000238418579  Meta Train Loss: 0.7031475305557251 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.2969430754565288e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.1245380160094642e+27
# Meta-Update
# Epoch| 971 | Meta Train Acc: 0.5500000081956387  Meta Train Loss: 0.9549236223101616 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.2393192101060512e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.1826983680178375e+27
# Meta-Update
# Epoch| 972 | Meta Train Acc: 0.6500000134110451  Meta Train Loss: 0.8048966638743876 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.0291793065143656e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.2141967369260187e+27
# Meta-Update
# Epoch| 973 | Meta Train Acc: 0.45000001043081284  Meta Train Loss: 1.257939487695694 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.1905010640598553e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.2686380962019237e+27
# Meta-Update
# Epoch| 974 | Meta Train Acc: 0.6500000134110451  Meta Train Loss: 1.2833351492881775 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.309652716102618e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.5906884931307015e+27
# Meta-Update
# Epoch| 975 | Meta Train Acc: 0.6000000089406967  Meta Train Loss: 0.7549274489283562 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.2872175830459876e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.1051676803534722e+27
# Meta-Update
# Epoch| 976 | Meta Train Acc: 0.5000000186264515  Meta Train Loss: 1.5680783241987228 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.073867060541761e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.579838007586081e+27
# Meta-Update
# Epoch| 977 | Meta Train Acc: 0.7000000178813934  Meta Train Loss: 0.9000649303197861 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.231093530222423e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.4182235555523737e+27
# Meta-Update
# Epoch| 978 | Meta Train Acc: 0.5500000156462193  Meta Train Loss: 1.039911299943924 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.437420565601049e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.028969696161456e+27
# Meta-Update
# Epoch| 979 | Meta Train Acc: 0.5500000081956387  Meta Train Loss: 1.177770458161831 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.308852127409819e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.0532475482705855e+27
# Meta-Update
# Epoch| 980 | Meta Train Acc: 0.550000011920929  Meta Train Loss: 0.9809087365865707 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.2702339978187166e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.0877410412270387e+27
# Meta-Update
# Epoch| 981 | Meta Train Acc: 0.45000001415610313  Meta Train Loss: 1.2280513793230057 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.2221337252648934e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.2983008849475623e+27
# Meta-Update
# Epoch| 982 | Meta Train Acc: 0.8500000089406967  Meta Train Loss: 0.4787892624735832 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.3293742039787972e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.1898051052994426e+27
# Meta-Update
# Epoch| 983 | Meta Train Acc: 0.9000000059604645  Meta Train Loss: 0.6592091619968414 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.0697187936279534e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.2919084978302116e+27
# Meta-Update
# Epoch| 984 | Meta Train Acc: 0.5000000186264515  Meta Train Loss: 1.113984376192093 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.410227242484558e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.3162961080665797e+27
# Meta-Update
# Epoch| 985 | Meta Train Acc: 0.2500000037252903  Meta Train Loss: 1.8196054548025131 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 1.3544994072769525e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.3403897878828773e+27
# Meta-Update
# Epoch| 986 | Meta Train Acc: 0.6500000134110451  Meta Train Loss: 0.8745155036449432 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 8.354772596732744e+26 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 8.425276237049902e+26
# Meta-Update
# Epoch| 987 | Meta Train Acc: 0.7000000178813934  Meta Train Loss: 0.8521344512701035 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 6.0158718231005975e+26 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 7.679210585709571e+26
# Meta-Update
# Epoch| 988 | Meta Train Acc: 0.7500000149011612  Meta Train Loss: 0.7561072111129761 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 5.575740349368119e+26 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 4.349725927212207e+26
# Meta-Update
# Epoch| 989 | Meta Train Acc: 0.6500000096857548  Meta Train Loss: 1.22511225938797 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.8634876905686225e+26 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.446094506004094e+26
# Meta-Update
# Epoch| 990 | Meta Train Acc: 0.550000011920929  Meta Train Loss: 0.7562009021639824 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 5.037516192648121e+26 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 3.228532453477259e+26
# Meta-Update
# Epoch| 991 | Meta Train Acc: 0.550000011920929  Meta Train Loss: 1.228201448917389 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.1266701552798474e+26 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.0665009551209506e+27
# Meta-Update
# Epoch| 992 | Meta Train Acc: 0.4000000134110451  Meta Train Loss: 1.2038144916296005 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 5.614697198073904e+26 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 4.178092624196954e+26
# Meta-Update
# Epoch| 993 | Meta Train Acc: 0.5000000074505806  Meta Train Loss: 1.07950958609581 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 3.800279071157356e+26 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.211058906573119e+27
# Meta-Update
# Epoch| 994 | Meta Train Acc: 0.7000000178813934  Meta Train Loss: 1.467480331659317 Meta Val Acc: 0.20000000298023224  Meta Val Loss: 2.2669863632217185e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 5.377752909435305e+26
# Meta-Update
# Epoch| 995 | Meta Train Acc: 0.5000000074505806  Meta Train Loss: 1.2062715962529182 Meta Val Acc: 0.15000000223517418  Meta Val Loss: 6.523980793899922e+26 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 1.894939340778224e+26
# Meta-Update
# Epoch| 996 | Meta Train Acc: 0.45000001415610313  Meta Train Loss: 1.2449522614479065 Meta Val Acc: 0.2500000037252903  Meta Val Loss: 1.9965670425078782e+26 Meta Test Acc: 0.2500000037252903  Meta Test Loss: 9.004818912826454e+26
# Meta-Update
# Epoch| 997 | Meta Train Acc: 0.6000000163912773  Meta Train Loss: 1.1337410509586334 Meta Val Acc: 0.15000000223517418  Meta Val Loss: 1.0849586837984105e+27 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.551824259775674e+25
# Meta-Update
# Epoch| 998 | Meta Train Acc: 0.6500000134110451  Meta Train Loss: 1.0291690528392792 Meta Val Acc: 0.2500000037252903  Meta Val Loss: 2.1156390317098976e+26 Meta Test Acc: 0.20000000298023224  Meta Test Loss: 2.30115318249914e+26
# Meta-Update
# Epoch| 999 | Meta Train Acc: 0.6500000096857548  Meta Train Loss: 1.202811524271965 Meta Val Acc: 0.15000000223517418  Meta Val Loss: 7.212363989571832e+26 Meta Test Acc: 0.15000000223517418  Meta Test Loss: 2.97966899354921e+26
# Files already downloaded and verified
# Files already downloaded and verified
# Finishing last run (ID:265itynp) before initializing another...
# <br/>Waiting for W&B process to finish, PID 133069<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/hikmat/Desktop/JWorkSpace/Higher/src/wandb/run-20210819_001944-265itynp/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/hikmat/Desktop/JWorkSpace/Higher/src/wandb/run-20210819_001944-265itynp/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Dataset</td><td>omniglot</td></tr><tr><td>Ways</td><td>5</td></tr><tr><td>Shots</td><td>1</td></tr><tr><td>Meta Batch</td><td>4</td></tr><tr><td>Meta_lr</td><td>0.01</td></tr><tr><td>Fast_lr</td><td>0.1</td></tr><tr><td>Adaptation Step</td><td>5</td></tr><tr><td>_runtime</td><td>12977</td></tr><tr><td>_timestamp</td><td>1629359770</td></tr><tr><td>_step</td><td>2000</td></tr><tr><td>Meta Update</td><td>999</td></tr><tr><td>Meta Train Acc</td><td>0.65</td></tr><tr><td>Meta Train Loss</td><td>1.20281</td></tr><tr><td>Meta Val Acc</td><td>0.15</td></tr><tr><td>Meta Val Loss</td><td>7.212363989571832e+26</td></tr><tr><td>Meta Test Acc</td><td>0.15</td></tr><tr><td>Meta Test Loss</td><td>2.97966899354921e+26</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Ways</td><td>▁</td></tr><tr><td>Shots</td><td>▁</td></tr><tr><td>Meta Batch</td><td>▁</td></tr><tr><td>Meta_lr</td><td>▁</td></tr><tr><td>Fast_lr</td><td>▁</td></tr><tr><td>Adaptation Step</td><td>▁</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>Meta Update</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>Meta Train Acc</td><td>▄▁▃▇▅█▁▅▄▆▅▅▆▆▄▆▄▅▆█▄▄▆▆▇▆▅▅▇▄█▃▃▃▅▃▇▆▅▅</td></tr><tr><td>Meta Train Loss</td><td>▅▆▅▂▄▂█▃▅▂▂▃▄▄▄▃▄▄▂▁▄▄▂▂▃▆▃▆▂▃▁▅▃▆▄▃▂▃▅▃</td></tr><tr><td>Meta Val Acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Meta Val Loss</td><td>▁▁▁▁▂▁▅▇█▆▇▆▃▂▂▃▃▃▂▂▂▂▂▂▂▂▃▃▃▂▂▁▂▃▂▂▃▃▃▁</td></tr><tr><td>Meta Test Acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Meta Test Loss</td><td>▁▁▁▁▁▂▇███▇█▃▃▃▃▃▃▂▂▂▂▃▂▂▃▂▃▃▃▃▁▂▃▂▂▃▃▃▃</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">volcanic-cosmos-23</strong>: <a href="https://wandb.ai/hikmatkhan-/JOmniGlot/runs/265itynp" target="_blank">https://wandb.ai/hikmatkhan-/JOmniGlot/runs/265itynp</a><br/>
# ...Successfully finished last run (ID:265itynp). Initializing new run:<br/><br/>
#                 Tracking run with wandb version 0.12.0<br/>
#                 Syncing run <strong style="color:#cdcd00">radiant-waterfall-26</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hikmatkhan-/JOmniGlot" target="_blank">https://wandb.ai/hikmatkhan-/JOmniGlot</a><br/>
#                 Run page: <a href="https://wandb.ai/hikmatkhan-/JOmniGlot/runs/3fvxthqf" target="_blank">https://wandb.ai/hikmatkhan-/JOmniGlot/runs/3fvxthqf</a><br/>
#                 Run data is saved locally in <code>/home/hikmat/Desktop/JWorkSpace/Higher/src/wandb/run-20210819_035611-3fvxthqf</code><br/><br/>
# Meta-Update
# Epoch| 0 | Meta Train Acc: 0.7199999839067459  Meta Train Loss: 0.7823615819215775 Meta Val Acc: 0.19999998807907104  Meta Val Loss: 3.138189386025686e+26 Meta Test Acc: 0.19999998807907104  Meta Test Loss: 3.094232731806164e+26
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-4333c3c2a239> in <module>
#      87                                 meta_train_loss.update(meta_train_qry_loss.detach().cpu().item())
#      88
# ---> 89                                 meta_train_qry_loss.backward()
#      90
#      91
#
# ~/anaconda3/envs/PY3/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     193                 products. Defaults to ``False``.
#     194         """
# --> 195         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     196
#     197     def register_hook(self, hook):
#
# ~/anaconda3/envs/PY3/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# RuntimeError: CUDA out of memory. Tried to allocate 20.00 MiB (GPU 0; 15.89 GiB total capacity; 3.13 GiB already allocated; 26.00 MiB free; 3.21 GiB reserved in total by PyTorch)

# %%
# from jupyterplot import ProgressPlot
# import numpy as np
# import time
# pp = ProgressPlot(line_names=["cos", "no-cos"])
# for i in range(1000):
#     pp.update([[np.sin(i / 100), np.sin(i / 100) * 0.1]])
#     time.sleep(0.01)
# pp.finalize()
