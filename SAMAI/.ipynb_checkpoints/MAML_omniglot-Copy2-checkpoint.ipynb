# %%
# class Lambda(nn.Module):

#     def __init__(self, fn):
#         super(Lambda, self).__init__()
#         self.fn = fn

#     def forward(self, x):
#         return self.fn(x)

# %%
import learn2learn as l2l
for name in l2l.vision.benchmarks.list_tasksets():
    print(name)
    if("tiered-imagenet" == name):
        continue
    tasksets = l2l.vision.benchmarks.get_tasksets(name)
# Out:
# omniglot
# Files already downloaded and verified
# Files already downloaded and verified
# mini-imagenet
# tiered-imagenet
# fc100
# cifarfs

# %%
Datasets = [
    "omniglot",]
#             "mini-imagenet", 
#             "fc100", "cifarfs", "tiered-imagenet"]
# WaysAndShots = ["omniglot", "mini-imagenet", "fc100", "cifarfs", "tiered-imagenet"]
#!/usr/bin/env python3

"""
Demonstrates how to:
    * use the MAML wrapper for fast-adaptation,
    * use the benchmark interface to load Omniglot, and
    * sample tasks and split them in adaptation and evaluation sets.
"""

import random
import numpy as np
import torch
import learn2learn as l2l
import matplotlib.pyplot as plt
from torch import nn, optim
import os

# %%
def accuracy(predictions, targets):
    predictions = predictions.argmax(dim=1).view(targets.shape)
    return (predictions == targets).sum().float() / targets.size(0)


def fast_adapt(batch, learner, loss, adaptation_steps, shots, ways, device):
    data, labels = batch
    data, labels = data.to(device), labels.to(device)

    # Separate data into adaptation/evalutation sets
    adaptation_indices = np.zeros(data.size(0), dtype=bool)
    adaptation_indices[np.arange(shots*ways) * 2] = True
    evaluation_indices = torch.from_numpy(~adaptation_indices)
    adaptation_indices = torch.from_numpy(adaptation_indices)
    adaptation_data, adaptation_labels = data[adaptation_indices], labels[adaptation_indices]
    evaluation_data, evaluation_labels = data[evaluation_indices], labels[evaluation_indices]

    # Adapt the model
    for step in range(adaptation_steps):
        train_error = loss(learner(adaptation_data), adaptation_labels)
        learner.adapt(train_error)

    # Evaluate the adapted model
    predictions = learner(evaluation_data)
    valid_error = loss(predictions, evaluation_labels)
    valid_accuracy = accuracy(predictions, evaluation_labels)
    return valid_error, valid_accuracy


def perform_experiment(
        dataset,
        ways=5,
        shots=1,
        meta_lr=0.003,
        fast_lr=0.5,
        meta_batch_size=32,
        adaptation_steps=1,
        num_iterations=64,#60000,
        cuda=True,
        seed=42,
        
):
    print("############### {0} ###############".format(dataset))
    Meta_Train_Accuracy = []
    Meta_Train_Error = []
    Meta_Val_Accuracy = []
    Meta_Val_Error = []
#     Iterations = []
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    device = torch.device('cpu')
    if cuda:
        torch.cuda.manual_seed(seed)
        device = torch.device('cuda')

    # Load train/validation/test tasksets using the benchmark interface
    tasksets = l2l.vision.benchmarks.get_tasksets(dataset,
                                                  train_ways=ways,
                                                  train_samples=2*shots,
                                                  test_ways=ways,
                                                  test_samples=2*shots,
                                                  num_tasks=20000,
                                                  root='~/data',
    )

    #     "omniglot",
#             "mini-imagenet", 
#             "fc100", "cifarfs", "tiered-imagenet"
    # Create model
    if(dataset == "omniglot"):
        model = l2l.vision.models.OmniglotFC(28 ** 2, ways)
    elif(dataset == "mini-imagenet"):
        model = l2l.vision.models.MiniImagenetCNN(ways)
    elif(dataset == "fc100"):
        features = l2l.vision.models.ConvBase(output_size=64, channels=3, max_pool=True)
        features = torch.nn.Sequential(features, Lambda(lambda x: x.view(-1, 256)))
        features.to(device)
        model = torch.nn.Linear(256, ways)
#     elif(dataset = ""):
    else:
        print("Error occured.")
        
    
    model.to(device)
    maml = l2l.algorithms.MAML(model, lr=fast_lr, first_order=False)
    opt = optim.Adam(maml.parameters(), meta_lr)
    loss = nn.CrossEntropyLoss(reduction='mean')

    for iteration in range(num_iterations):
        opt.zero_grad()
        meta_train_error = 0.0
        meta_train_accuracy = 0.0
        meta_valid_error = 0.0
        meta_valid_accuracy = 0.0
        for task in range(meta_batch_size):
            # Compute meta-training loss
            learner = maml.clone()
            batch = tasksets.train.sample()
            evaluation_error, evaluation_accuracy = fast_adapt(batch,
                                                               learner,
                                                               loss,
                                                               adaptation_steps,
                                                               shots,
                                                               ways,
                                                               device)
            evaluation_error.backward()
            meta_train_error += evaluation_error.item()
            meta_train_accuracy += evaluation_accuracy.item()

            # Compute meta-validation loss
            learner = maml.clone()
            batch = tasksets.validation.sample()
            evaluation_error, evaluation_accuracy = fast_adapt(batch,
                                                               learner,
                                                               loss,
                                                               adaptation_steps,
                                                               shots,
                                                               ways,
                                                               device)
            meta_valid_error += evaluation_error.item()
            meta_valid_accuracy += evaluation_accuracy.item()

        # Print some metrics
        
        
        meta_train_error =  meta_train_error / meta_batch_size
        meta_train_accuracy = meta_train_accuracy / meta_batch_size
        meta_val_error =  meta_valid_error / meta_batch_size
        meta_val_accuracy = meta_valid_accuracy / meta_batch_size
        if(iteration % 32 ==0):
            print('\n')
            print('Iteration', iteration)
            print('Meta Train Error', meta_train_error)
            print('Meta Train Accuracy', meta_train_accuracy)
            print('Meta Valid Error', meta_val_error)
            print('Meta Valid Accuracy', meta_val_accuracy)

        Meta_Train_Accuracy.append(meta_train_accuracy)
        Meta_Train_Error.append(meta_train_error)
        Meta_Val_Accuracy.append(meta_val_accuracy)
        Meta_Val_Error.append(meta_val_error)

        # Average the accumulated gradients and optimize
        for p in maml.parameters():
            p.grad.data.mul_(1.0 / meta_batch_size)
        opt.step()

    meta_test_error = 0.0
    meta_test_accuracy = 0.0
    for task in range(meta_batch_size):
        # Compute meta-testing loss
        learner = maml.clone()
        batch = tasksets.test.sample()
        evaluation_error, evaluation_accuracy = fast_adapt(batch,
                                                           learner,
                                                           loss,
                                                           adaptation_steps,
                                                           shots,
                                                           ways,
                                                           device)
        meta_test_error += evaluation_error.item()
        meta_test_accuracy += evaluation_accuracy.item()
    Meta_Test_Error = meta_test_error / meta_batch_size
    print('Meta Test Error', Meta_Test_Error)
    Meta_Test_Accuracy = meta_test_accuracy / meta_batch_size
    print('Meta Test Accuracy', Meta_Test_Accuracy)
    
    if not os.path.exists('plots'):
        os.makedirs('plots')
    if not os.path.exists('plots/acc'):
        os.makedirs('plots/acc')
    if not os.path.exists('plots/loss'):
        os.makedirs('plots/loss')
    ###### Plot Accuracies ######
    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
    fig = plt.figure()
    ax = plt.subplot(111)
    ax.plot(list(range(0, len(Meta_Train_Accuracy))), Meta_Train_Accuracy, label="Meta Train ")
    ax.plot(list(range(0, len(Meta_Val_Accuracy))), Meta_Val_Accuracy, label="Meta Val")
#     ax.text((len(Meta_Val_Accuracy)/2), 0, 'Meta Test:{0}'.format(round(meta_test_accuracy, 2)), style='italic',
#         bbox={'facecolor': 'red', 'alpha': 0.25, 'pad': 5})
    # place a text box in upper left in axes coords
    ax.text(0.05, 0.5, 'Meta Test:{0}'.format(round(Meta_Test_Accuracy, 2)), transform=ax.transAxes, fontsize=14,
            verticalalignment='top', bbox=props)
    plt.title('Adaption')
    plt.xlabel('Iteration')
    plt.ylabel('Meta Accuracy')
    ax.legend()
    plt.savefig('./plots/acc/{0}_ways_{1}_shots_{2}_Acc_I_{3}.png'.format(dataset, ways, shots, iteration), 
                dpi=150)
    ###### Plot Accuracies ######

    ###### Plot Errors ######
    fig = plt.figure()
    ax = plt.subplot(111)
    ax.plot(list(range(0, len(Meta_Train_Error))), Meta_Train_Error, label="Meta Train ")
    ax.plot(list(range(0, len(Meta_Val_Error))), Meta_Val_Accuracy, label="Meta Val Lss")
#     ax.text((len(Meta_Val_Accuracy)/2),0, 'Meta Test Accuracy:{0}  Meta Test Loss:{1}'.format(round(meta_test_accuracy, 2),
#                               round(meta_test_error, 2)), style='italic',
#         bbox={'facecolor': 'red', 'alpha': 0.25, 'pad': 5})
    ax.text(0.05, 0.5, 'MTestAcc:{0}  MTestLoss:{1}'.format(round(Meta_Test_Accuracy, 2),
                                           round(Meta_Test_Error, 2)), transform=ax.transAxes, fontsize=14,
            verticalalignment='top', bbox=props)
    plt.title('Adaption')
    plt.xlabel('Iteration')
    plt.ylabel('Meta Loss')
    ax.legend()
    plt.savefig('./plots/loss/{0}_ways_{1}_shots_{2}_Loss_I_{3}.png'.format(dataset, ways, shots, iteration),
               dpi=150)
    ###### Plot Errors ######


if __name__ == '__main__':
    Ways = [5]
    Shots = [1, 5]
    Iterations = [4, 10000, 60000, 120000]
    for ways in Ways:
        for shots in Shots:
            for iteration in Iterations:
                for dataset in Datasets:
                    perform_experiment(dataset=dataset,
                        ways=ways,
                        shots=shots,
                        meta_lr=0.003,
                        fast_lr=0.5,
                        meta_batch_size=32,
                        adaptation_steps=1,
                        num_iterations=iteration,
                        cuda=True,
                        seed=42)
# Out:
# ############### omniglot ###############
# Files already downloaded and verified
# Files already downloaded and verified
#
#
# Iteration 0
# Meta Train Error 1.5664074830710888
# Meta Train Accuracy 0.33750000735744834
# Meta Valid Error 1.5736553594470024
# Meta Valid Accuracy 0.2875000066123903
# Meta Test Error 1.4665710218250751
# Meta Test Accuracy 0.40000001015141606
# ############### omniglot ###############
# Files already downloaded and verified
# Files already downloaded and verified
#
#
# Iteration 0
# Meta Train Error 1.5664074830710888
# Meta Train Accuracy 0.33750000735744834
# Meta Valid Error 1.5736553594470024
# Meta Valid Accuracy 0.2875000066123903
#
#
# Iteration 32
# Meta Train Error 1.0495170950889587
# Meta Train Accuracy 0.5812500109896064
# Meta Valid Error 1.0092181013897061
# Meta Valid Accuracy 0.6187500106170774
#
#
# Iteration 64
# Meta Train Error 0.8851228686980903
# Meta Train Accuracy 0.7062500067986548
# Meta Valid Error 0.8873503152281046
# Meta Valid Accuracy 0.6437500123865902
#
#
# Iteration 96
# Meta Train Error 0.8296206104569137
# Meta Train Accuracy 0.6687500108964741
# Meta Valid Error 0.6032072734087706
# Meta Valid Accuracy 0.8000000072643161
#
#
# Iteration 128
# Meta Train Error 0.7989718918688595
# Meta Train Accuracy 0.706250011920929
# Meta Valid Error 0.8273054286837578
# Meta Valid Accuracy 0.6937500112690032
#
#
# Iteration 160
# Meta Train Error 0.7038287431932986
# Meta Train Accuracy 0.7062500109896064
# Meta Valid Error 0.9559635068289936
# Meta Valid Accuracy 0.631250012665987
#
#
# Iteration 192
# Meta Train Error 0.7997465545777231
# Meta Train Accuracy 0.7000000141561031
# Meta Valid Error 0.8806346287019551
# Meta Valid Accuracy 0.6500000115483999
#
#
# Iteration 224
# Meta Train Error 0.5317005647812039
# Meta Train Accuracy 0.8312500063329935
# Meta Valid Error 0.5902968600858003
# Meta Valid Accuracy 0.7875000108033419
#
#
# Iteration 256
# Meta Train Error 0.6243581776507199
# Meta Train Accuracy 0.7437500120140612
# Meta Valid Error 0.8009603640530258
# Meta Valid Accuracy 0.7000000113621354
#
#
# Iteration 288
# Meta Train Error 0.5663443538360298
# Meta Train Accuracy 0.7937500081025064
# Meta Valid Error 0.6819326418917626
# Meta Valid Accuracy 0.7687500100582838
#
#
# Iteration 320
# Meta Train Error 0.678454902023077
# Meta Train Accuracy 0.7500000102445483
# Meta Valid Error 0.5447123916819692
# Meta Valid Accuracy 0.8187500084750354
#
#
# Iteration 352
# Meta Train Error 0.57082066568546
# Meta Train Accuracy 0.812500006519258
# Meta Valid Error 0.7762157004326582
# Meta Valid Accuracy 0.7062500114552677
#
#
# Iteration 384
# Meta Train Error 0.5798570988699794
# Meta Train Accuracy 0.7750000087544322
# Meta Valid Error 0.6436044487636536
# Meta Valid Accuracy 0.7562500135973096
#
#
# Iteration 416
# Meta Train Error 0.585617488482967
# Meta Train Accuracy 0.8125000079162419
# Meta Valid Error 0.6156364975031465
# Meta Valid Accuracy 0.7750000073574483
#
#
# Iteration 448
# Meta Train Error 0.6417778329341672
# Meta Train Accuracy 0.7312500099651515
# Meta Valid Error 0.5998254592996091
# Meta Valid Accuracy 0.8312500077299774
#
#
# Iteration 480
# Meta Train Error 0.4808351614046842
# Meta Train Accuracy 0.8250000085681677
# Meta Valid Error 0.7228315072134137
# Meta Valid Accuracy 0.7375000109896064
#
#
# Iteration 512
# Meta Train Error 0.7546625403920189
# Meta Train Accuracy 0.7437500092200935
# Meta Valid Error 0.5594064961187541
# Meta Valid Accuracy 0.8000000091269612
#
#
# Iteration 544
# Meta Train Error 0.5910333250649273
# Meta Train Accuracy 0.8062500087544322
# Meta Valid Error 0.48628955124877393
# Meta Valid Accuracy 0.8625000081956387
#
#
# Iteration 576
# Meta Train Error 0.5540708235930651
# Meta Train Accuracy 0.7750000106170774
# Meta Valid Error 0.6419482603669167
# Meta Valid Accuracy 0.7750000073574483
#
#
# Iteration 608
# Meta Train Error 0.612860580557026
# Meta Train Accuracy 0.7812500093132257
# Meta Valid Error 0.6219240007922053
# Meta Valid Accuracy 0.7875000098720193
#
#
# Iteration 640
# Meta Train Error 0.5067468627821654
# Meta Train Accuracy 0.8187500089406967
# Meta Valid Error 0.5202762624248862
# Meta Valid Accuracy 0.8375000078231096
#
#
# Iteration 672
# Meta Train Error 0.5681113507598639
# Meta Train Accuracy 0.762500012293458
# Meta Valid Error 0.536725104553625
# Meta Valid Accuracy 0.7812500102445483
#
#
# Iteration 704
# Meta Train Error 0.5796293872408569
# Meta Train Accuracy 0.7625000099651515
# Meta Valid Error 0.47941223811358213
# Meta Valid Accuracy 0.8125000083819032
#
#
# Iteration 736
# Meta Train Error 0.5287693062564358
# Meta Train Accuracy 0.7750000115483999
# Meta Valid Error 0.6869863785104826
# Meta Valid Accuracy 0.7750000087544322
#
#
# Iteration 768
# Meta Train Error 0.5252698516706005
# Meta Train Accuracy 0.8625000058673322
# Meta Valid Error 0.5805152216926217
# Meta Valid Accuracy 0.8000000081956387
#
#
# Iteration 800
# Meta Train Error 0.4483661436242983
# Meta Train Accuracy 0.8562500067055225
# Meta Valid Error 0.4405952545348555
# Meta Valid Accuracy 0.8312500081956387
#
#
# Iteration 832
# Meta Train Error 0.5178622332168743
# Meta Train Accuracy 0.8375000078231096
# Meta Valid Error 0.6303352549439296
# Meta Valid Accuracy 0.8125000102445483
#
#
# Iteration 864
# Meta Train Error 0.4821587524784263
# Meta Train Accuracy 0.806250006891787
# Meta Valid Error 0.7349944042507559
# Meta Valid Accuracy 0.7187500107102096
#
#
# Iteration 896
# Meta Train Error 0.5521740387775935
# Meta Train Accuracy 0.8000000063329935
# Meta Valid Error 0.6936243423260748
# Meta Valid Accuracy 0.7187500102445483
#
#
# Iteration 928
# Meta Train Error 0.47216337732970715
# Meta Train Accuracy 0.8500000080093741
# Meta Valid Error 0.4952793038683012
# Meta Valid Accuracy 0.8000000077299774
#
#
# Iteration 960
# Meta Train Error 0.32057240459835157
# Meta Train Accuracy 0.8750000055879354
# Meta Valid Error 0.5396269987686537
# Meta Valid Accuracy 0.7625000085681677
#
#
# Iteration 992
# Meta Train Error 0.42971347749698907
# Meta Train Accuracy 0.8062500087544322
# Meta Valid Error 0.7013846538029611
# Meta Valid Accuracy 0.7687500067986548
#
#
# Iteration 1024
# Meta Train Error 0.4981590313836932
# Meta Train Accuracy 0.8187500075437129
# Meta Valid Error 0.6860339536797255
# Meta Valid Accuracy 0.7687500091269612
#
#
# Iteration 1056
# Meta Train Error 0.469146914081648
# Meta Train Accuracy 0.8312500091269612
# Meta Valid Error 0.5859037831542082
# Meta Valid Accuracy 0.8062500106170774
#
#
# Iteration 1088
# Meta Train Error 0.3861320831638295
# Meta Train Accuracy 0.8437500093132257
# Meta Valid Error 0.5328128705150448
# Meta Valid Accuracy 0.8000000100582838
#
#
# Iteration 1120
# Meta Train Error 0.5688562318682671
# Meta Train Accuracy 0.8187500080093741
# Meta Valid Error 0.6837567051989026
# Meta Valid Accuracy 0.7500000107102096
#
#
# Iteration 1152
# Meta Train Error 0.4495211187750101
# Meta Train Accuracy 0.8625000081956387
# Meta Valid Error 0.4514690792420879
# Meta Valid Accuracy 0.8500000075437129
#
#
# Iteration 1184
# Meta Train Error 0.4424767077434808
# Meta Train Accuracy 0.8250000076368451
# Meta Valid Error 0.5615861495025456
# Meta Valid Accuracy 0.7875000108033419
#
#
# Iteration 1216
# Meta Train Error 0.4319632288534194
# Meta Train Accuracy 0.8500000070780516
# Meta Valid Error 0.6075175291625783
# Meta Valid Accuracy 0.7437500096857548
#
#
# Iteration 1248
# Meta Train Error 0.38497666851617396
# Meta Train Accuracy 0.8750000041909516
# Meta Valid Error 0.6516032522777095
# Meta Valid Accuracy 0.7687500091269612
#
#
# Iteration 1280
# Meta Train Error 0.3751119755906984
# Meta Train Accuracy 0.8687500059604645
# Meta Valid Error 0.4255412964266725
# Meta Valid Accuracy 0.8312500091269612
#
#
# Iteration 1312
# Meta Train Error 0.3432060891063884
# Meta Train Accuracy 0.9125000052154064
# Meta Valid Error 0.8850269683171064
# Meta Valid Accuracy 0.6937500112690032
#
#
# Iteration 1344
# Meta Train Error 0.3924940002616495
# Meta Train Accuracy 0.8500000089406967
# Meta Valid Error 0.77918092609616
# Meta Valid Accuracy 0.731250009033829
#
#
# Iteration 1376
# Meta Train Error 0.37272869172738865
# Meta Train Accuracy 0.8437500069849193
# Meta Valid Error 0.5163147261482663
# Meta Valid Accuracy 0.8000000095926225
#
#
# Iteration 1408
# Meta Train Error 0.3131898524297867
# Meta Train Accuracy 0.8687500078231096
# Meta Valid Error 0.578666178684216
# Meta Valid Accuracy 0.768750011920929
#
#
# Iteration 1440
# Meta Train Error 0.503362708579516
# Meta Train Accuracy 0.8125000093132257
# Meta Valid Error 0.49153817421756685
# Meta Valid Accuracy 0.8125000083819032
#
#
# Iteration 1472
# Meta Train Error 0.5212131658336148
# Meta Train Accuracy 0.8187500108033419
# Meta Valid Error 0.48291509703267366
# Meta Valid Accuracy 0.8250000094994903
# Iteration 1504
# Meta Train Error 0.5412105966825038
# Meta Train Accuracy 0.8375000096857548
# Meta Valid Error 0.6012511947192252
# Meta Valid Accuracy 0.7687500109896064
#
#
# Iteration 1536
# Meta Train Error 0.3557261471869424
# Meta Train Accuracy 0.881250006146729
# Meta Valid Error 0.651502821885515
# Meta Valid Accuracy 0.7937500081025064
#
#
# Iteration 1568
# Meta Train Error 0.35382211979595013
# Meta Train Accuracy 0.8937500054016709
# Meta Valid Error 0.5510690115625039
# Meta Valid Accuracy 0.8125000088475645
#
#
# Iteration 1600
# Meta Train Error 0.40108009419054724
# Meta Train Accuracy 0.8625000081956387
# Meta Valid Error 0.5478337859967723
# Meta Valid Accuracy 0.8187500080093741
#
#
# Iteration 1632
# Meta Train Error 0.2796904150163755
# Meta Train Accuracy 0.9062500046566129
# Meta Valid Error 0.6500916181830689
# Meta Valid Accuracy 0.7812500093132257
#
#
# Iteration 1664
# Meta Train Error 0.30468067739275284
# Meta Train Accuracy 0.9062500055879354
# Meta Valid Error 0.5832514310022816
# Meta Valid Accuracy 0.7687500114552677
#
#
# Iteration 1696
# Meta Train Error 0.37323957588523626
# Meta Train Accuracy 0.8625000063329935
# Meta Valid Error 0.6142135865520686
# Meta Valid Accuracy 0.8125000102445483
#
#
# Iteration 1728
# Meta Train Error 0.29901912665809505
# Meta Train Accuracy 0.9000000059604645
# Meta Valid Error 0.8687309122178704
# Meta Valid Accuracy 0.718750013038516
#
#
# Iteration 1760
# Meta Train Error 0.5030659144977108
# Meta Train Accuracy 0.8375000078231096
# Meta Valid Error 0.6000041811494157
# Meta Valid Accuracy 0.7562500103376806
#
#
# Iteration 1792
# Meta Train Error 0.5367568376823328
# Meta Train Accuracy 0.8000000100582838
# Meta Valid Error 0.7185037143644877
# Meta Valid Accuracy 0.7500000093132257
#
#
# Iteration 1824
# Meta Train Error 0.531529997009784
# Meta Train Accuracy 0.8125000051222742
# Meta Valid Error 0.36907809134572744
# Meta Valid Accuracy 0.8562500085681677
#
#
# Iteration 1856
# Meta Train Error 0.4644775766064413
# Meta Train Accuracy 0.8437500069849193
# Meta Valid Error 0.6834039184032008
# Meta Valid Accuracy 0.7375000114552677
#
#
# Iteration 1888
# Meta Train Error 0.34553647559368983
# Meta Train Accuracy 0.8812500070780516
# Meta Valid Error 0.6118021649890579
# Meta Valid Accuracy 0.8125000102445483
#
#
# Iteration 1920
# Meta Train Error 0.2641860615112819
# Meta Train Accuracy 0.9125000052154064
# Meta Valid Error 0.5457737531978637
# Meta Valid Accuracy 0.8000000086612999
#
#
# Iteration 1952
# Meta Train Error 0.3852563129912596
# Meta Train Accuracy 0.8687500059604645
# Meta Valid Error 0.360772906569764
# Meta Valid Accuracy 0.8500000089406967
#
#
# Iteration 1984
# Meta Train Error 0.30293602409074083
# Meta Train Accuracy 0.8750000074505806
# Meta Valid Error 0.37133103917585686
# Meta Valid Accuracy 0.868750006891787
#
#
# Iteration 2016
# Meta Train Error 0.3161081114085391
# Meta Train Accuracy 0.875000006519258
# Meta Valid Error 0.5175316261011176
# Meta Valid Accuracy 0.8062500096857548
#
#
# Iteration 2048
# Meta Train Error 0.28302297487971373
# Meta Train Accuracy 0.9062500055879354
# Meta Valid Error 0.5208869192574639
# Meta Valid Accuracy 0.8000000081956387
#
#
# Iteration 2080
# Meta Train Error 0.32051648397464305
# Meta Train Accuracy 0.9000000045634806
# Meta Valid Error 0.3250791371538071
# Meta Valid Accuracy 0.8937500054016709
#
#
# Iteration 2112
# Meta Train Error 0.31473687302786857
# Meta Train Accuracy 0.9062500055879354
# Meta Valid Error 0.4701252206286881
# Meta Valid Accuracy 0.8625000063329935
#
#
# Iteration 2144
# Meta Train Error 0.3455296085739974
# Meta Train Accuracy 0.868750006891787
# Meta Valid Error 0.7276822987478226
# Meta Valid Accuracy 0.7562500098720193
#
#
# Iteration 2176
# Meta Train Error 0.3816915583447553
# Meta Train Accuracy 0.8562500076368451
# Meta Valid Error 0.5533852710505016
# Meta Valid Accuracy 0.8125000060535967
#
#
# Iteration 2208
# Meta Train Error 0.7059249028679915
# Meta Train Accuracy 0.8062500059604645
# Meta Valid Error 0.5766187040426303
# Meta Valid Accuracy 0.7687500109896064
#
#
# Iteration 2240
# Meta Train Error 0.4580793285276741
# Meta Train Accuracy 0.8437500093132257
# Meta Valid Error 0.7909427545964718
# Meta Valid Accuracy 0.700000009033829
#
#
# Iteration 2272
# Meta Train Error 0.44484230331727304
# Meta Train Accuracy 0.8562500071711838
# Meta Valid Error 0.6229885923676193
# Meta Valid Accuracy 0.8000000095926225
#
#
# Iteration 2304
# Meta Train Error 0.3943318322417326
# Meta Train Accuracy 0.868750006891787
# Meta Valid Error 0.6268529271765146
# Meta Valid Accuracy 0.8250000057742
#
#
# Iteration 2336
# Meta Train Error 0.27250944287516177
# Meta Train Accuracy 0.9250000035390258
# Meta Valid Error 0.5052649304852821
# Meta Valid Accuracy 0.8250000062398612
#
#
# Iteration 2368
# Meta Train Error 0.40585304450360127
# Meta Train Accuracy 0.8625000058673322
# Meta Valid Error 0.5965671291342005
# Meta Valid Accuracy 0.8125000083819032
#
#
# Iteration 2400
# Meta Train Error 0.2737711653171573
# Meta Train Accuracy 0.9062500055879354
# Meta Valid Error 0.5451041006745072
# Meta Valid Accuracy 0.8000000095926225
#
#
# Iteration 2432
# Meta Train Error 0.4384369587060064
# Meta Train Accuracy 0.8562500067055225
# Meta Valid Error 0.4233672061818652
# Meta Valid Accuracy 0.8500000080093741
#
#
# Iteration 2464
# Meta Train Error 0.3128970703401137
# Meta Train Accuracy 0.9000000045634806
# Meta Valid Error 0.7019080403260887
# Meta Valid Accuracy 0.768750011920929
#
#
# Iteration 2496
# Meta Train Error 0.2793673941050656
# Meta Train Accuracy 0.881250006146729
# Meta Valid Error 0.6511763715534471
# Meta Valid Accuracy 0.756250009406358
#
#
# Iteration 2528
# Meta Train Error 0.2308707476768177
# Meta Train Accuracy 0.9187500048428774
# Meta Valid Error 0.6861176325764973
# Meta Valid Accuracy 0.7812500088475645
#
#
# Iteration 2560
# Meta Train Error 0.294451576017309
# Meta Train Accuracy 0.8812500070780516
# Meta Valid Error 0.6451347171096131
# Meta Valid Accuracy 0.7562500098720193
#
#
# Iteration 2592
# Meta Train Error 0.34823671719641425
# Meta Train Accuracy 0.9187500048428774
# Meta Valid Error 0.6312174992635846
# Meta Valid Accuracy 0.8062500087544322
#
#
# Iteration 2624
# Meta Train Error 0.20109345031960402
# Meta Train Accuracy 0.9375000037252903
# Meta Valid Error 0.5486557870463002
# Meta Valid Accuracy 0.7937500085681677
#
#
# Iteration 2656
# Meta Train Error 0.30651047691935673
# Meta Train Accuracy 0.9187500048428774
# Meta Valid Error 0.5492143466399284
# Meta Valid Accuracy 0.8062500078231096
#
#
# Iteration 2688
# Meta Train Error 0.27644648584828246
# Meta Train Accuracy 0.8937500054016709
# Meta Valid Error 0.39992349690874107
# Meta Valid Accuracy 0.868750006891787
#
#
# Iteration 2720
# Meta Train Error 0.411871053831419
# Meta Train Accuracy 0.8687500078231096
# Meta Valid Error 0.7862410908564925
# Meta Valid Accuracy 0.7562500103376806
#
#
# Iteration 2752
# Meta Train Error 0.28967569644737523
# Meta Train Accuracy 0.8937500044703484
# Meta Valid Error 0.5366525650169933
# Meta Valid Accuracy 0.8062500106170774
#
#
# Iteration 2784
# Meta Train Error 0.24061019869986922
# Meta Train Accuracy 0.9125000033527613
# Meta Valid Error 0.5195888270827709
# Meta Valid Accuracy 0.7875000070780516
#
#
# Iteration 2816
# Meta Train Error 0.2778227408998646
# Meta Train Accuracy 0.9250000035390258
# Meta Valid Error 0.6551152655447368
# Meta Valid Accuracy 0.8000000095926225
#
#
# Iteration 2848
# Meta Train Error 0.36815918851061724
# Meta Train Accuracy 0.8812500070780516
# Meta Valid Error 0.6820499119348824
# Meta Valid Accuracy 0.7812500102445483
#
#
# Iteration 2880
# Meta Train Error 0.26848458833410405
# Meta Train Accuracy 0.9187500039115548
# Meta Valid Error 0.3546095956407953
# Meta Valid Accuracy 0.8562500057742
#
#
# Iteration 2912
# Meta Train Error 0.34290934648015536
# Meta Train Accuracy 0.8937500063329935
# Meta Valid Error 0.5942980423569679
# Meta Valid Accuracy 0.8062500096857548
#
#
# Iteration 2944
# Meta Train Error 0.26754625991452485
# Meta Train Accuracy 0.9187500048428774
# Meta Valid Error 0.5276544245571131
# Meta Valid Accuracy 0.8062500087544322
#
#
# Iteration 2976
# Meta Train Error 0.28652245609555393
# Meta Train Accuracy 0.9062500037252903
# Meta Valid Error 0.8238518396974541
# Meta Valid Accuracy 0.7375000086612999
#
#
# Iteration 3008
# Meta Train Error 0.35607200213416945
# Meta Train Accuracy 0.875000006519258
# Meta Valid Error 0.5373479297268204
# Meta Valid Accuracy 0.837500006891787
#
#
# Iteration 3040
# Meta Train Error 0.44177960958040785
# Meta Train Accuracy 0.8562500057742
# Meta Valid Error 0.4432955605298048
# Meta Valid Accuracy 0.8312500081956387
#
#
# Iteration 3072
# Meta Train Error 0.19048525994003285
# Meta Train Accuracy 0.9375000018626451
# Meta Valid Error 0.8081229864037596
# Meta Valid Accuracy 0.7500000107102096
# Iteration 3104
# Meta Train Error 0.22762848099227995
# Meta Train Accuracy 0.9312500040978193
# Meta Valid Error 0.43065642939473037
# Meta Valid Accuracy 0.8125000083819032
#
#
# Iteration 3136
# Meta Train Error 0.37946719134924933
# Meta Train Accuracy 0.8812500056810677
# Meta Valid Error 0.4387490069930209
# Meta Valid Accuracy 0.8500000056810677
#
#
# Iteration 3168
# Meta Train Error 0.2716171563079115
# Meta Train Accuracy 0.9500000029802322
# Meta Valid Error 0.5165858120890334
# Meta Valid Accuracy 0.8125000111758709
#
#
# Iteration 3200
# Meta Train Error 0.22879904832370812
# Meta Train Accuracy 0.9125000042840838
# Meta Valid Error 0.5828458368196152
# Meta Valid Accuracy 0.8250000062398612
#
#
# Iteration 3232
# Meta Train Error 0.13881125921034254
# Meta Train Accuracy 0.9625000022351742
# Meta Valid Error 0.5125931061338633
# Meta Valid Accuracy 0.8250000085681677
#
#
# Iteration 3264
# Meta Train Error 0.2684790272178361
# Meta Train Accuracy 0.9062500037252903
# Meta Valid Error 0.5180579173756996
# Meta Valid Accuracy 0.8375000087544322
#
#
# Iteration 3296
# Meta Train Error 0.3080622931593098
# Meta Train Accuracy 0.8937500054016709
# Meta Valid Error 0.4319497807591688
# Meta Valid Accuracy 0.8500000080093741
#
#
# Iteration 3328
# Meta Train Error 0.4719701656285906
# Meta Train Accuracy 0.8562500053085387
# Meta Valid Error 0.6984122866997495
# Meta Valid Accuracy 0.781250009778887
#
#
# Iteration 3360
# Meta Train Error 0.2884239756676834
# Meta Train Accuracy 0.8937500054016709
# Meta Valid Error 0.5352855215314776
# Meta Valid Accuracy 0.8250000085681677
#
#
# Iteration 3392
# Meta Train Error 0.3450799557613209
# Meta Train Accuracy 0.8875000057742
# Meta Valid Error 0.6762464583734982
# Meta Valid Accuracy 0.7687500086612999
#
#
# Iteration 3424
# Meta Train Error 0.42048217680712696
# Meta Train Accuracy 0.8500000080093741
# Meta Valid Error 0.5479452612780733
# Meta Valid Accuracy 0.8062500064261258
#
#
# Iteration 3456
# Meta Train Error 0.336327603974496
# Meta Train Accuracy 0.8750000037252903
# Meta Valid Error 0.4594151654309826
# Meta Valid Accuracy 0.8312500072643161
#
#
# Iteration 3488
# Meta Train Error 0.2225357873539906
# Meta Train Accuracy 0.9187500048428774
# Meta Valid Error 0.5056141220848076
# Meta Valid Accuracy 0.8562500062398612
#
#
# Iteration 3520
# Meta Train Error 0.29650577131542377
# Meta Train Accuracy 0.8812500056810677
# Meta Valid Error 0.7829767177609028
# Meta Valid Accuracy 0.7500000107102096
#
#
# Iteration 3552
# Meta Train Error 0.2076754170411732
# Meta Train Accuracy 0.9250000044703484
# Meta Valid Error 0.48933632993430365
# Meta Valid Accuracy 0.8062500096857548
#
#
# Iteration 3584
# Meta Train Error 0.182437473864411
# Meta Train Accuracy 0.9437500033527613
# Meta Valid Error 0.6077528949681437
# Meta Valid Accuracy 0.7937500081025064
#
#
# Iteration 3616
# Meta Train Error 0.31215562246507034
# Meta Train Accuracy 0.9000000059604645
# Meta Valid Error 0.5501520772231743
# Meta Valid Accuracy 0.8312500086612999
#
#
# Iteration 3648
# Meta Train Error 0.37231357881682925
# Meta Train Accuracy 0.868750006891787
# Meta Valid Error 0.5542770870961249
# Meta Valid Accuracy 0.8312500081956387
#
#
# Iteration 3680
# Meta Train Error 0.2811370378913125
# Meta Train Accuracy 0.9062500055879354
# Meta Valid Error 0.6045900029275799
# Meta Valid Accuracy 0.7812500079162419
#
#
# Iteration 3712
# Meta Train Error 0.31231121279415675
# Meta Train Accuracy 0.8937500054016709
# Meta Valid Error 0.5551907237968408
# Meta Valid Accuracy 0.8187500084750354
#
#
# Iteration 3744
# Meta Train Error 0.3087978938856395
# Meta Train Accuracy 0.900000003632158
# Meta Valid Error 0.5291702045942657
# Meta Valid Accuracy 0.8375000087544322
#
#
# Iteration 3776
# Meta Train Error 0.277680592800607
# Meta Train Accuracy 0.9187500039115548
# Meta Valid Error 0.5830465425970033
# Meta Valid Accuracy 0.8062500087544322
#
#
# Iteration 3808
# Meta Train Error 0.38286080688703805
# Meta Train Accuracy 0.8625000067986548
# Meta Valid Error 0.6100700865063118
# Meta Valid Accuracy 0.7812500074505806
#
#
# Iteration 3840
# Meta Train Error 0.36685777103411965
# Meta Train Accuracy 0.8937500054016709
# Meta Valid Error 0.7942911319696577
# Meta Valid Accuracy 0.7500000083819032
#
#
# Iteration 3872
# Meta Train Error 0.2344699508685153
# Meta Train Accuracy 0.9187500048428774
# Meta Valid Error 0.3658188013068866
# Meta Valid Accuracy 0.8500000070780516
#
#
# Iteration 3904
# Meta Train Error 0.24298309133155271
# Meta Train Accuracy 0.9250000044703484
# Meta Valid Error 0.7253127775038593
# Meta Valid Accuracy 0.7750000087544322
#
#
# Iteration 3936
# Meta Train Error 0.33711076629697345
# Meta Train Accuracy 0.8750000046566129
# Meta Valid Error 0.8999281560827512
# Meta Valid Accuracy 0.718750013038516
#
#
# Iteration 3968
# Meta Train Error 0.2704048444138607
# Meta Train Accuracy 0.9250000035390258
# Meta Valid Error 0.7266308248508722
# Meta Valid Accuracy 0.7937500067055225
#
#
# Iteration 4000
# Meta Train Error 0.1528521641594125
# Meta Train Accuracy 0.9375000037252903
# Meta Valid Error 0.6970107301604003
# Meta Valid Accuracy 0.7562500089406967
#
#
# Iteration 4032
# Meta Train Error 0.2099579133791849
# Meta Train Accuracy 0.9250000044703484
# Meta Valid Error 0.4467252497852314
# Meta Valid Accuracy 0.8500000052154064
#
#
# Iteration 4064
# Meta Train Error 0.27724894194398075
# Meta Train Accuracy 0.8937500063329935
# Meta Valid Error 0.5523192357213702
# Meta Valid Accuracy 0.8000000081956387
#
#
# Iteration 4096
# Meta Train Error 0.22987149933032924
# Meta Train Accuracy 0.9187500039115548
# Meta Valid Error 0.648341569583863
# Meta Valid Accuracy 0.8000000100582838
#
#
# Iteration 4128
# Meta Train Error 0.1876034079468809
# Meta Train Accuracy 0.9375000037252903
# Meta Valid Error 0.6387442543054931
# Meta Valid Accuracy 0.7937500085681677
#
#
# Iteration 4160
# Meta Train Error 0.2348294069961412
# Meta Train Accuracy 0.9375000037252903
# Meta Valid Error 0.7414994594728341
# Meta Valid Accuracy 0.762500009033829
#
#
# Iteration 4192
# Meta Train Error 0.23697073833318427
# Meta Train Accuracy 0.9187500039115548
# Meta Valid Error 0.7691205088485731
# Meta Valid Accuracy 0.7875000075437129
#
#
# Iteration 4224
# Meta Train Error 0.19067339980392717
# Meta Train Accuracy 0.9375000037252903
# Meta Valid Error 0.5673918849788606
# Meta Valid Accuracy 0.7875000075437129
#
#
# Iteration 4256
# Meta Train Error 0.2998716006113682
# Meta Train Accuracy 0.8875000057742
# Meta Valid Error 0.6082266408629948
# Meta Valid Accuracy 0.8250000076368451
#
#
# Iteration 4288
# Meta Train Error 0.15515396250702906
# Meta Train Accuracy 0.9375000037252903
# Meta Valid Error 0.45091530050558504
# Meta Valid Accuracy 0.8625000072643161
#
#
# Iteration 4320
# Meta Train Error 0.19643551579065388
# Meta Train Accuracy 0.9500000029802322
# Meta Valid Error 0.5412044020995381
# Meta Valid Accuracy 0.8375000073574483
#
#
# Iteration 4352
# Meta Train Error 0.4738729616510682
# Meta Train Accuracy 0.8500000070780516
# Meta Valid Error 0.5200272060319548
# Meta Valid Accuracy 0.8312500067986548
#
#
# Iteration 4384
# Meta Train Error 0.1946386661293218
# Meta Train Accuracy 0.9437500033527613
# Meta Valid Error 0.5434437605726998
# Meta Valid Accuracy 0.8312500091269612
#
#
# Iteration 4416
# Meta Train Error 0.235851300865761
# Meta Train Accuracy 0.9250000035390258
# Meta Valid Error 0.581610676861601
# Meta Valid Accuracy 0.8187500056810677
#
#
# Iteration 4448
# Meta Train Error 0.40494814740668517
# Meta Train Accuracy 0.8562500057742
# Meta Valid Error 0.4464829028074746
# Meta Valid Accuracy 0.8562500085681677
#
#
# Iteration 4480
# Meta Train Error 0.27450978339038556
# Meta Train Accuracy 0.9187500048428774
# Meta Valid Error 0.43984649860067293
# Meta Valid Accuracy 0.8500000080093741
#
#
# Iteration 4512
# Meta Train Error 0.3075644215277862
# Meta Train Accuracy 0.8937500063329935
# Meta Valid Error 0.38796655501937494
# Meta Valid Accuracy 0.8687500050291419
#
#
# Iteration 4544
# Meta Train Error 0.2721020165772643
# Meta Train Accuracy 0.9187500039115548
# Meta Valid Error 0.6367962106596678
# Meta Valid Accuracy 0.8125000083819032
#
#
# Iteration 4576
# Meta Train Error 0.2488256169599481
# Meta Train Accuracy 0.9187500048428774
# Meta Valid Error 0.34072549162374344
# Meta Valid Accuracy 0.9062500046566129
#
#
# Iteration 4608
# Meta Train Error 0.22367228922666982
# Meta Train Accuracy 0.9312500040978193
# Meta Valid Error 0.5981665939325467
# Meta Valid Accuracy 0.7937500094994903
#
#
# Iteration 4640
# Meta Train Error 0.19957614583836403
# Meta Train Accuracy 0.9312500040978193
# Meta Valid Error 0.6918806105386466
# Meta Valid Accuracy 0.7750000092200935
#
#
# Iteration 4672
# Meta Train Error 0.4623030859802384
# Meta Train Accuracy 0.8687500054948032
# Meta Valid Error 0.6420437700726325
# Meta Valid Accuracy 0.7875000084750354
# Iteration 4704
# Meta Train Error 0.263363651567488
# Meta Train Accuracy 0.9125000052154064
# Meta Valid Error 0.5988637749833288
# Meta Valid Accuracy 0.806250006891787
#
#
# Iteration 4736
# Meta Train Error 0.21821369258395862
# Meta Train Accuracy 0.9375000027939677
# Meta Valid Error 0.7275202692107996
# Meta Valid Accuracy 0.8000000072643161
#
#
# Iteration 4768
# Meta Train Error 0.2885989610658726
# Meta Train Accuracy 0.8937500044703484
# Meta Valid Error 0.6608448164552101
# Meta Valid Accuracy 0.7812500121071935
#
#
# Iteration 4800
# Meta Train Error 0.12770201452076435
# Meta Train Accuracy 0.9562500026077032
# Meta Valid Error 0.46346345572237624
# Meta Valid Accuracy 0.8312500081956387
#
#
# Iteration 4832
# Meta Train Error 0.39328322056826437
# Meta Train Accuracy 0.8687500040978193
# Meta Valid Error 0.5545437585533364
# Meta Valid Accuracy 0.7625000099651515
#
#
# Iteration 4864
# Meta Train Error 0.34250658004020806
# Meta Train Accuracy 0.881250006146729
# Meta Valid Error 0.5229511756042484
# Meta Valid Accuracy 0.8125000088475645
#
#
# Iteration 4896
# Meta Train Error 0.15345955981320003
# Meta Train Accuracy 0.9500000029802322
# Meta Valid Error 0.5154648759635165
# Meta Valid Accuracy 0.8312500067986548
#
#
# Iteration 4928
# Meta Train Error 0.2727426942437887
# Meta Train Accuracy 0.9125000052154064
# Meta Valid Error 0.6815115047065774
# Meta Valid Accuracy 0.8125000102445483
#
#
# Iteration 4960
# Meta Train Error 0.2686304245798965
# Meta Train Accuracy 0.9187500039115548
# Meta Valid Error 0.4900908590570907
# Meta Valid Accuracy 0.8250000104308128
#
#
# Iteration 4992
# Meta Train Error 0.16003335019922815
# Meta Train Accuracy 0.9500000029802322
# Meta Valid Error 0.4743884374911431
# Meta Valid Accuracy 0.8437500083819032
#
#
# Iteration 5024
# Meta Train Error 0.2420745277486276
# Meta Train Accuracy 0.9437500024214387
# Meta Valid Error 0.49064337137679104
# Meta Valid Accuracy 0.868750006891787
#
#
# Iteration 5056
# Meta Train Error 0.15970776944595855
# Meta Train Accuracy 0.9625000022351742
# Meta Valid Error 0.7823276121052913
# Meta Valid Accuracy 0.7562500103376806
#
#
# Iteration 5088
# Meta Train Error 0.18751306592821493
# Meta Train Accuracy 0.9187500048428774
# Meta Valid Error 0.5452652434323682
# Meta Valid Accuracy 0.8312500072643161
#
#
# Iteration 5120
# Meta Train Error 0.1815628593758447
# Meta Train Accuracy 0.9500000029802322
# Meta Valid Error 0.6148412659240421
# Meta Valid Accuracy 0.7875000084750354
#
#
# Iteration 5152
# Meta Train Error 0.237741455930518
# Meta Train Accuracy 0.9187500039115548
# Meta Valid Error 0.5746586669993121
# Meta Valid Accuracy 0.8562500062398612
#
#
# Iteration 5184
# Meta Train Error 0.135367052978836
# Meta Train Accuracy 0.9500000029802322
# Meta Valid Error 0.5498247193754651
# Meta Valid Accuracy 0.8125000055879354
#
#
# Iteration 5216
# Meta Train Error 0.24744475117040565
# Meta Train Accuracy 0.9187500039115548
# Meta Valid Error 0.5445084766543005
# Meta Valid Accuracy 0.8437500069849193
#
#
# Iteration 5248
# Meta Train Error 0.1287238564909785
# Meta Train Accuracy 0.9625000022351742
# Meta Valid Error 0.5177395123901078
# Meta Valid Accuracy 0.8312500081956387
#
#
# Iteration 5280
# Meta Train Error 0.2431072487597703
# Meta Train Accuracy 0.9000000050291419
# Meta Valid Error 0.382461365807103
# Meta Valid Accuracy 0.8937500054016709
#
#
# Iteration 5312
# Meta Train Error 0.38399532422045013
# Meta Train Accuracy 0.8812500038184226
# Meta Valid Error 0.3436816337998607
# Meta Valid Accuracy 0.8687500078231096
#
#
# Iteration 5344
# Meta Train Error 0.3445529637610889
# Meta Train Accuracy 0.9125000052154064
# Meta Valid Error 0.6503984437149484
# Meta Valid Accuracy 0.8000000081956387
#
#
# Iteration 5376
# Meta Train Error 0.1975389452127274
# Meta Train Accuracy 0.9437500033527613
# Meta Valid Error 0.5024155867868103
# Meta Valid Accuracy 0.850000006146729
#
#
# Iteration 5408
# Meta Train Error 0.1951024662121199
# Meta Train Accuracy 0.9187500048428774
# Meta Valid Error 0.5281444860702322
# Meta Valid Accuracy 0.8312500067986548
#
#
# Iteration 5440
# Meta Train Error 0.26029646456299815
# Meta Train Accuracy 0.8937500063329935
# Meta Valid Error 0.6953835595049895
# Meta Valid Accuracy 0.7875000103376806
#
#
# Iteration 5472
# Meta Train Error 0.26374953349659336
# Meta Train Accuracy 0.906250003259629
# Meta Valid Error 0.5117376649868675
# Meta Valid Accuracy 0.8562500076368451
#
#
# Iteration 5504
# Meta Train Error 0.22482600540388376
# Meta Train Accuracy 0.9312500040978193
# Meta Valid Error 0.4694992453514715
# Meta Valid Accuracy 0.8312500091269612
#
#
# Iteration 5536
# Meta Train Error 0.19152135036711115
# Meta Train Accuracy 0.9375000037252903
# Meta Valid Error 0.7346173403639114
# Meta Valid Accuracy 0.7625000067055225
#
#
# Iteration 5568
# Meta Train Error 0.16729191199556226
# Meta Train Accuracy 0.9562500012107193
# Meta Valid Error 0.566824908284616
# Meta Valid Accuracy 0.8500000070780516
#
#
# Iteration 5600
# Meta Train Error 0.25429218456702074
# Meta Train Accuracy 0.9250000044703484
# Meta Valid Error 0.6404807592443831
# Meta Valid Accuracy 0.8187500098720193
#
#
# Iteration 5632
# Meta Train Error 0.2632823050225852
# Meta Train Accuracy 0.9250000044703484
# Meta Valid Error 0.6101347275689477
# Meta Valid Accuracy 0.8187500066123903
#
#
# Iteration 5664
# Meta Train Error 0.25412210304057226
# Meta Train Accuracy 0.9000000059604645
# Meta Valid Error 0.6788200226874324
# Meta Valid Accuracy 0.8062500078231096
#
#
# Iteration 5696
# Meta Train Error 0.37485862170069595
# Meta Train Accuracy 0.881250006146729
# Meta Valid Error 0.5721322230965598
# Meta Valid Accuracy 0.8125000088475645
#
#
# Iteration 5728
# Meta Train Error 0.3349760042692651
# Meta Train Accuracy 0.8937500054016709
# Meta Valid Error 0.7255284021302941
# Meta Valid Accuracy 0.8062500092200935
#
#
# Iteration 5760
# Meta Train Error 0.2662892409716733
# Meta Train Accuracy 0.9187500034458935
# Meta Valid Error 0.5375365114305168
# Meta Valid Accuracy 0.8312500077299774
#
#
# Iteration 5792
# Meta Train Error 0.16848001434846083
# Meta Train Accuracy 0.9500000020489097
# Meta Valid Error 0.5059123268292751
# Meta Valid Accuracy 0.8375000082887709
#
#
# Iteration 5824
# Meta Train Error 0.2323994440084789
# Meta Train Accuracy 0.9125000042840838
# Meta Valid Error 0.47797083434124943
# Meta Valid Accuracy 0.8250000076368451
#
#
# Iteration 5856
# Meta Train Error 0.21901061006064992
# Meta Train Accuracy 0.9312500031664968
# Meta Valid Error 0.6109929445301532
# Meta Valid Accuracy 0.7937500085681677
#
#
# Iteration 5888
# Meta Train Error 0.2660161353269359
# Meta Train Accuracy 0.9125000052154064
# Meta Valid Error 0.762361198925646
# Meta Valid Accuracy 0.8187500070780516
#
#
# Iteration 5920
# Meta Train Error 0.28500401968631195
# Meta Train Accuracy 0.9062500055879354
# Meta Valid Error 0.727710455423221
# Meta Valid Accuracy 0.7875000117346644
#
#
# Iteration 5952
# Meta Train Error 0.19594164357840782
# Meta Train Accuracy 0.9312500040978193
# Meta Valid Error 0.5303490906080697
# Meta Valid Accuracy 0.8250000076368451
#
#
# Iteration 5984
# Meta Train Error 0.1721605571328837
# Meta Train Accuracy 0.9250000035390258
# Meta Valid Error 0.8660900956565456
# Meta Valid Accuracy 0.7250000122003257
#
#
# Iteration 6016
# Meta Train Error 0.20261667779413983
# Meta Train Accuracy 0.9500000029802322
# Meta Valid Error 0.4056808041059412
# Meta Valid Accuracy 0.868750006891787
#
#
# Iteration 6048
# Meta Train Error 0.09991484673810191
# Meta Train Accuracy 0.9750000014901161
# Meta Valid Error 0.594830568828911
# Meta Valid Accuracy 0.8000000081956387
#
#
# Iteration 6080
# Meta Train Error 0.21355288611448486
# Meta Train Accuracy 0.9312500040978193
# Meta Valid Error 0.74766882431868
# Meta Valid Accuracy 0.8000000086612999
#
#
# Iteration 6112
# Meta Train Error 0.30189370902371593
# Meta Train Accuracy 0.8937500049360096
# Meta Valid Error 0.6544135092990473
# Meta Valid Accuracy 0.7875000070780516
#
#
# Iteration 6144
# Meta Train Error 0.28954422056267504
# Meta Train Accuracy 0.9125000052154064
# Meta Valid Error 0.4475237774895504
# Meta Valid Accuracy 0.881250006146729
#
#
# Iteration 6176
# Meta Train Error 0.2750706297811121
# Meta Train Accuracy 0.9062500046566129
# Meta Valid Error 0.7404260510666063
# Meta Valid Accuracy 0.8062500087544322
#
#
# Iteration 6208
# Meta Train Error 0.2189648878556909
# Meta Train Accuracy 0.9437500033527613
# Meta Valid Error 0.7539802400715416
# Meta Valid Accuracy 0.8125000079162419
#
#
# Iteration 6240
# Meta Train Error 0.2126110371609684
# Meta Train Accuracy 0.9250000044703484
# Meta Valid Error 0.450489195096452
# Meta Valid Accuracy 0.8562500062398612
# Iteration 6272
# Meta Train Error 0.16197248759272043
# Meta Train Accuracy 0.9312500040978193
# Meta Valid Error 0.5436400976686855
# Meta Valid Accuracy 0.8187500080093741
#
#
# Iteration 6304
# Meta Train Error 0.27757149179524276
# Meta Train Accuracy 0.9250000035390258
# Meta Valid Error 0.5154319368302822
# Meta Valid Accuracy 0.8875000057742
#
#
# Iteration 6336
# Meta Train Error 0.29894694277027156
# Meta Train Accuracy 0.900000003632158
# Meta Valid Error 0.6459072077414021
# Meta Valid Accuracy 0.8187500066123903
#
#
# Iteration 6368
# Meta Train Error 0.2124919537018286
# Meta Train Accuracy 0.9437500033527613
# Meta Valid Error 0.6472244468095596
# Meta Valid Accuracy 0.8062500092200935
#
#
# Iteration 6400
# Meta Train Error 0.19792227474681567
# Meta Train Accuracy 0.9312500031664968
# Meta Valid Error 0.32714788353041513
# Meta Valid Accuracy 0.875000006519258
#
#
# Iteration 6432
# Meta Train Error 0.2733585821079032
# Meta Train Accuracy 0.9125000052154064
# Meta Valid Error 0.5353367503776099
# Meta Valid Accuracy 0.8250000067055225
#
#
# Iteration 6464
# Meta Train Error 0.20728183028040803
# Meta Train Accuracy 0.9437500033527613
# Meta Valid Error 0.9005522586303414
# Meta Valid Accuracy 0.7562500117346644
#
#
# Iteration 6496
# Meta Train Error 0.1229434194683563
# Meta Train Accuracy 0.9750000014901161
# Meta Valid Error 0.6611106268246658
# Meta Valid Accuracy 0.7875000089406967
#
#
# Iteration 6528
# Meta Train Error 0.14718561136396602
# Meta Train Accuracy 0.9625000022351742
# Meta Valid Error 0.4793757703337178
# Meta Valid Accuracy 0.8125000083819032
#
#
# Iteration 6560
# Meta Train Error 0.21690614515318885
# Meta Train Accuracy 0.9375000037252903
# Meta Valid Error 0.5867627590196207
# Meta Valid Accuracy 0.8000000100582838
#
#
# Iteration 6592
# Meta Train Error 0.2775866184019833
# Meta Train Accuracy 0.9312500040978193
# Meta Valid Error 0.3754141047975281
# Meta Valid Accuracy 0.875000006519258
#
#
# Iteration 6624
# Meta Train Error 0.21841621125349775
# Meta Train Accuracy 0.9250000044703484
# Meta Valid Error 0.6008344182337169
# Meta Valid Accuracy 0.8312500054016709
#
#
# Iteration 6656
# Meta Train Error 0.10437181929592043
# Meta Train Accuracy 0.9625000022351742
# Meta Valid Error 0.571009752486134
# Meta Valid Accuracy 0.8125000041909516
#
#
# Iteration 6688
# Meta Train Error 0.24046950476622442
# Meta Train Accuracy 0.9187500048428774
# Meta Valid Error 0.7779918294545496
# Meta Valid Accuracy 0.7937500099651515
#
#
# Iteration 6720
# Meta Train Error 0.15856561779219192
# Meta Train Accuracy 0.9625000022351742
# Meta Valid Error 0.9617437518027145
# Meta Valid Accuracy 0.7375000100582838
#
#
# Iteration 6752
# Meta Train Error 0.09952015915041557
# Meta Train Accuracy 0.9562500026077032
# Meta Valid Error 0.5733485452656168
# Meta Valid Accuracy 0.8375000087544322
#
#
# Iteration 6784
# Meta Train Error 0.15872920523179346
# Meta Train Accuracy 0.9312500031664968
# Meta Valid Error 0.6598624706966802
# Meta Valid Accuracy 0.7812500088475645
#
#
# Iteration 6816
# Meta Train Error 0.16881807723257225
# Meta Train Accuracy 0.9375000037252903
# Meta Valid Error 0.5053192400227999
# Meta Valid Accuracy 0.8125000079162419
#
#
# Iteration 6848
# Meta Train Error 0.22945219571556663
# Meta Train Accuracy 0.9312500040978193
# Meta Valid Error 0.6334861101677234
# Meta Valid Accuracy 0.7812500111758709
#
#
# Iteration 6880
# Meta Train Error 0.3307705212937435
# Meta Train Accuracy 0.918750002514571
# Meta Valid Error 0.6260124756299774
# Meta Valid Accuracy 0.8062500087544322
#
#
# Iteration 6912
# Meta Train Error 0.11438154723873595
# Meta Train Accuracy 0.9750000014901161
# Meta Valid Error 0.5566389555897331
# Meta Valid Accuracy 0.8437500055879354
#
#
# Iteration 6944
# Meta Train Error 0.16881538609595736
# Meta Train Accuracy 0.9375000037252903
# Meta Valid Error 0.5216715305032267
# Meta Valid Accuracy 0.8437500055879354
#
#
# Iteration 6976
# Meta Train Error 0.18591879350788076
# Meta Train Accuracy 0.9375000037252903
# Meta Valid Error 0.6242126292017929
# Meta Valid Accuracy 0.8500000066123903
#
#
# Iteration 7008
# Meta Train Error 0.1723990918144409
# Meta Train Accuracy 0.9562500026077032
# Meta Valid Error 0.33946352389284584
# Meta Valid Accuracy 0.8687500078231096
#
#
# Iteration 7040
# Meta Train Error 0.13855849886749638
# Meta Train Accuracy 0.9625000022351742
# Meta Valid Error 0.640172795363469
# Meta Valid Accuracy 0.7937500113621354
#
#
# Iteration 7072
# Meta Train Error 0.14940725607812055
# Meta Train Accuracy 0.9625000022351742
# Meta Valid Error 0.6715714575548191
# Meta Valid Accuracy 0.8000000105239451
#
#
# Iteration 7104
# Meta Train Error 0.10595462129276711
# Meta Train Accuracy 0.9750000014901161
# Meta Valid Error 0.5244311104543158
# Meta Valid Accuracy 0.875000006519258
#
#
# Iteration 7136
# Meta Train Error 0.16272475872028735
# Meta Train Accuracy 0.9437500033527613
# Meta Valid Error 0.6218825317373557
# Meta Valid Accuracy 0.8250000057742
#
#
# Iteration 7168
# Meta Train Error 0.17420843963191146
# Meta Train Accuracy 0.9500000029802322
# Meta Valid Error 0.5523069718183251
# Meta Valid Accuracy 0.8437500074505806
#
#
# Iteration 7200
# Meta Train Error 0.14213078525062883
# Meta Train Accuracy 0.9625000022351742
# Meta Valid Error 0.5455249369115336
# Meta Valid Accuracy 0.8375000078231096
#
#
# Iteration 7232
# Meta Train Error 0.09992280530786957
# Meta Train Accuracy 0.9750000014901161
# Meta Valid Error 0.6023167948005721
# Meta Valid Accuracy 0.8562500062398612
#
#
# Iteration 7264
# Meta Train Error 0.18312408900237642
# Meta Train Accuracy 0.9375000027939677
# Meta Valid Error 0.6857806108819204
# Meta Valid Accuracy 0.7937500085681677
#
#
# Iteration 7296
# Meta Train Error 0.1922008053661557
# Meta Train Accuracy 0.9625000022351742
# Meta Valid Error 0.622566330821428
# Meta Valid Accuracy 0.7812500111758709
#
#
# Iteration 7328
# Meta Train Error 0.06695690849301172
# Meta Train Accuracy 0.9812500011175871
# Meta Valid Error 0.5358093582217407
# Meta Valid Accuracy 0.8000000077299774
#
#
# Iteration 7360
# Meta Train Error 0.08424946983723203
# Meta Train Accuracy 0.9812500011175871
# Meta Valid Error 0.8867378196955542
# Meta Valid Accuracy 0.7750000073574483
#
#
# Iteration 7392
# Meta Train Error 0.1686433177383151
# Meta Train Accuracy 0.9500000020489097
# Meta Valid Error 0.721296821240685
# Meta Valid Accuracy 0.818750009406358
#
#
# Iteration 7424
# Meta Train Error 0.14643127930230548
# Meta Train Accuracy 0.9437500019557774
# Meta Valid Error 0.49999027597550594
# Meta Valid Accuracy 0.8187500075437129
#
#
# Iteration 7456
# Meta Train Error 0.1396250324032735
# Meta Train Accuracy 0.9750000014901161
# Meta Valid Error 0.5301130799452949
# Meta Valid Accuracy 0.850000006146729
#
#
# Iteration 7488
# Meta Train Error 0.19905644733080408
# Meta Train Accuracy 0.9437500033527613
# Meta Valid Error 0.3681050948398479
# Meta Valid Accuracy 0.9125000052154064
#
#
# Iteration 7520
# Meta Train Error 0.13364341214764863
# Meta Train Accuracy 0.9625000022351742
# Meta Valid Error 0.6689115064727957
# Meta Valid Accuracy 0.8312500081956387
#
#
# Iteration 7552
# Meta Train Error 0.09804023340984713
# Meta Train Accuracy 0.9687500018626451
# Meta Valid Error 0.5375767546538555
# Meta Valid Accuracy 0.8562500048428774
#
#
# Iteration 7584
# Meta Train Error 0.1945817513842485
# Meta Train Accuracy 0.9250000035390258
# Meta Valid Error 0.5333182906542788
# Meta Valid Accuracy 0.8250000085681677
#
#
# Iteration 7616
# Meta Train Error 0.1139312082741526
# Meta Train Accuracy 0.9687500018626451
# Meta Valid Error 0.8193065622763243
# Meta Valid Accuracy 0.8000000081956387
#
#
# Iteration 7648
# Meta Train Error 0.1378038164548343
# Meta Train Accuracy 0.9500000020489097
# Meta Valid Error 0.557259499997599
# Meta Valid Accuracy 0.8312500081956387
#
#
# Iteration 7680
# Meta Train Error 0.17659829849435482
# Meta Train Accuracy 0.9562500026077032
# Meta Valid Error 0.2853323254385032
# Meta Valid Accuracy 0.8875000057742
#
#
# Iteration 7712
# Meta Train Error 0.1391428341739811
# Meta Train Accuracy 0.9687500018626451
# Meta Valid Error 0.586278975562891
# Meta Valid Accuracy 0.8437500083819032
#
#
# Iteration 7744
# Meta Train Error 0.19276550386712188
# Meta Train Accuracy 0.9437500024214387
# Meta Valid Error 0.5656336058400484
# Meta Valid Accuracy 0.8437500069849193
#
#
# Iteration 7776
# Meta Train Error 0.14889625119394623
# Meta Train Accuracy 0.9562500026077032
# Meta Valid Error 0.5290402874816209
# Meta Valid Accuracy 0.8375000082887709
#
#
# Iteration 7808
# Meta Train Error 0.1282460924994666
# Meta Train Accuracy 0.9625000022351742
# Meta Valid Error 0.5208382173059363
# Meta Valid Accuracy 0.8375000096857548
# Iteration 7840
# Meta Train Error 0.1754266194147931
# Meta Train Accuracy 0.9625000022351742
# Meta Valid Error 0.7148125932399125
# Meta Valid Accuracy 0.7937500085681677
#
#
# Iteration 7872
# Meta Train Error 0.16607465182460146
# Meta Train Accuracy 0.9375000037252903
# Meta Valid Error 0.4910002810684091
# Meta Valid Accuracy 0.8250000081025064
#
#
# Iteration 7904
# Meta Train Error 0.14423053525024443
# Meta Train Accuracy 0.9437500033527613
# Meta Valid Error 0.8710413045628229
# Meta Valid Accuracy 0.7937500081025064
#
#
# Iteration 7936
# Meta Train Error 0.2049615903488302
# Meta Train Accuracy 0.9187500039115548
# Meta Valid Error 0.9338465246546548
# Meta Valid Accuracy 0.7562500098720193
#
#
# Iteration 7968
# Meta Train Error 0.208970341092936
# Meta Train Accuracy 0.9437500033527613
# Meta Valid Error 0.4151151303376537
# Meta Valid Accuracy 0.868750006891787
#
#
# Iteration 8000
# Meta Train Error 0.13383999886536913
# Meta Train Accuracy 0.9750000014901161
# Meta Valid Error 0.5392556371079991
# Meta Valid Accuracy 0.8062500082887709
#
#
# Iteration 8032
# Meta Train Error 0.3028626468949369
# Meta Train Accuracy 0.8812500052154064
# Meta Valid Error 0.7416115431005892
# Meta Valid Accuracy 0.7937500104308128
#
#
# Iteration 8064
# Meta Train Error 0.24700591462897137
# Meta Train Accuracy 0.9250000044703484
# Meta Valid Error 0.8482627909397706
# Meta Valid Accuracy 0.7687500109896064
#
#
# Iteration 8096
# Meta Train Error 0.12023571854660986
# Meta Train Accuracy 0.9562500026077032
# Meta Valid Error 0.40615050356427673
# Meta Valid Accuracy 0.8375000096857548
#
#
# Iteration 8128
# Meta Train Error 0.11656487977234065
# Meta Train Accuracy 0.9375000037252903
# Meta Valid Error 0.6125671154659358
# Meta Valid Accuracy 0.8062500078231096
#
#
# Iteration 8160
# Meta Train Error 0.13863258013589075
# Meta Train Accuracy 0.9562500026077032
# Meta Valid Error 0.75863690461847
# Meta Valid Accuracy 0.7500000102445483
#
#
# Iteration 8192
# Meta Train Error 0.183443685513339
# Meta Train Accuracy 0.9500000020489097
# Meta Valid Error 0.5900613557168981
# Meta Valid Accuracy 0.8062500087544322
#
#
# Iteration 8224
# Meta Train Error 0.1347709448345995
# Meta Train Accuracy 0.9625000022351742
# Meta Valid Error 0.6976870582147967
# Meta Valid Accuracy 0.7687500095926225
#
#
# Iteration 8256
# Meta Train Error 0.21661495834268862
# Meta Train Accuracy 0.9375000037252903
# Meta Valid Error 0.7134109216349316
# Meta Valid Accuracy 0.8062500096857548
#
#
# Iteration 8288
# Meta Train Error 0.15040556484746048
# Meta Train Accuracy 0.9250000044703484
# Meta Valid Error 0.7167372160092782
# Meta Valid Accuracy 0.7875000098720193
#
#
# Iteration 8320
# Meta Train Error 0.13682613425771706
# Meta Train Accuracy 0.9687500018626451
# Meta Valid Error 0.8186762005934725
# Meta Valid Accuracy 0.7687500081956387
#
#
# Iteration 8352
# Meta Train Error 0.1615474617028667
# Meta Train Accuracy 0.9375000037252903
# Meta Valid Error 0.761654647103569
# Meta Valid Accuracy 0.8000000077299774
#
#
# Iteration 8384
# Meta Train Error 0.1219926546109491
# Meta Train Accuracy 0.9625000022351742
# Meta Valid Error 0.8271748585248133
# Meta Valid Accuracy 0.7687500105239451
#
#
# Iteration 8416
# Meta Train Error 0.15337180141614226
# Meta Train Accuracy 0.9562500026077032
# Meta Valid Error 0.8762042968883179
# Meta Valid Accuracy 0.7812500111758709
#
#
# Iteration 8448
# Meta Train Error 0.12367681480282045
# Meta Train Accuracy 0.9562500026077032
# Meta Valid Error 0.4055777447156288
# Meta Valid Accuracy 0.8562500085681677
#
#
# Iteration 8480
# Meta Train Error 0.14643190742935985
# Meta Train Accuracy 0.9625000022351742
# Meta Valid Error 0.38456423513707705
# Meta Valid Accuracy 0.8687500078231096
#
#
# Iteration 8512
# Meta Train Error 0.0969244430816616
# Meta Train Accuracy 0.9750000014901161
# Meta Valid Error 0.5778860494283435
# Meta Valid Accuracy 0.8250000085681677
#
#
# Iteration 8544
# Meta Train Error 0.12296910126678995
# Meta Train Accuracy 0.9562500026077032
# Meta Valid Error 0.5431625237433764
# Meta Valid Accuracy 0.837500006891787
#
#
# Iteration 8576
# Meta Train Error 0.11695155353299924
# Meta Train Accuracy 0.9625000022351742
# Meta Valid Error 0.7901593928363582
# Meta Valid Accuracy 0.8125000093132257
#
#
# Iteration 8608
# Meta Train Error 0.13693670807333547
# Meta Train Accuracy 0.9750000014901161
# Meta Valid Error 0.495626658310357
# Meta Valid Accuracy 0.8750000074505806
#
#
# Iteration 8640
# Meta Train Error 0.2118528640603472
# Meta Train Accuracy 0.9187500048428774
# Meta Valid Error 0.6021796058048494
# Meta Valid Accuracy 0.8125000069849193
#
#
# Iteration 8672
# Meta Train Error 0.08922656522736361
# Meta Train Accuracy 0.9625000022351742
# Meta Valid Error 0.8876184608307085
# Meta Valid Accuracy 0.7312500085681677
#
#
# Iteration 8704
# Meta Train Error 0.19948823277809424
# Meta Train Accuracy 0.9375000027939677
# Meta Valid Error 0.4243166755004495
# Meta Valid Accuracy 0.8750000055879354
#
#
# Iteration 8736
# Meta Train Error 0.16266375394479837
# Meta Train Accuracy 0.9562500026077032
# Meta Valid Error 0.8043310409484548
# Meta Valid Accuracy 0.7625000108964741
#
#
# Iteration 8768
# Meta Train Error 0.17564826897796593
# Meta Train Accuracy 0.9687500018626451
# Meta Valid Error 0.6475665782745637
# Meta Valid Accuracy 0.8562500048428774
#
#
# Iteration 8800
# Meta Train Error 0.10465307768754428
# Meta Train Accuracy 0.9500000020489097
# Meta Valid Error 0.5411675373688922
# Meta Valid Accuracy 0.8437500069849193
#
#
# Iteration 8832
# Meta Train Error 0.07719012641973677
# Meta Train Accuracy 0.9625000022351742
# Meta Valid Error 0.7915176527694712
# Meta Valid Accuracy 0.7875000066123903
#
#
# Iteration 8864
# Meta Train Error 0.16153013586153975
# Meta Train Accuracy 0.9437500033527613
# Meta Valid Error 0.8501686891468125
# Meta Valid Accuracy 0.7625000094994903
#
#
# Iteration 8896
# Meta Train Error 0.15125840132895974
# Meta Train Accuracy 0.9500000029802322
# Meta Valid Error 0.3516029822458222
# Meta Valid Accuracy 0.9187500048428774
#
#
# Iteration 8928
# Meta Train Error 0.16962386792329198
# Meta Train Accuracy 0.9687500018626451
# Meta Valid Error 0.36726480585275567
# Meta Valid Accuracy 0.9125000042840838
#
#
# Iteration 8960
# Meta Train Error 0.17667612976947566
# Meta Train Accuracy 0.9375000023283064
# Meta Valid Error 0.8107063593051862
# Meta Valid Accuracy 0.7750000101514161
#
#
# Iteration 8992
# Meta Train Error 0.08757242426872835
# Meta Train Accuracy 0.9812500011175871
# Meta Valid Error 0.6894507850156515
# Meta Valid Accuracy 0.8000000091269612
#
#
# Iteration 9024
# Meta Train Error 0.11538251539968769
# Meta Train Accuracy 0.9687500018626451
# Meta Valid Error 0.662843013251404
# Meta Valid Accuracy 0.7875000103376806
#
#
# Iteration 9056
# Meta Train Error 0.1070987043203786
# Meta Train Accuracy 0.9625000022351742
# Meta Valid Error 0.5993666524300352
# Meta Valid Accuracy 0.8562500067055225
#
#
# Iteration 9088
# Meta Train Error 0.1480742699750408
# Meta Train Accuracy 0.9625000022351742
# ...
# Meta Valid Error 0.41773728118823783
# Meta Valid Accuracy 0.9062500055879354
#
#
# Iteration 18752
# Meta Train Error 0.016655925273880712
# Meta Train Accuracy 1.0
# Meta Valid Error 0.4523601899336427
# Meta Valid Accuracy 0.8875000057742
#
#
# Iteration 18784
# Meta Train Error 0.12245293187845618
# Meta Train Accuracy 0.9625000022351742
# Meta Valid Error 0.31282415877149106
# Meta Valid Accuracy 0.9250000044703484
#
#
# Iteration 18816
# Meta Train Error 0.0436632090996909
# Meta Train Accuracy 0.9875000007450581
# Meta Valid Error 1.1208338236006057
# Meta Valid Accuracy 0.8125000088475645
#
#
# Iteration 18848
# Meta Train Error 0.04893200914193585
# Meta Train Accuracy 0.993750000372529
# Meta Valid Error 1.0635797602590173
# Meta Valid Accuracy 0.7562500089406967
#
#
# Iteration 18880
# Meta Train Error 0.013769800662430498
# Meta Train Accuracy 1.0
# Meta Valid Error 0.634540454526018
# Meta Valid Accuracy 0.8500000089406967
#
#
# Iteration 18912
# Meta Train Error 0.07400191268970957
# Meta Train Accuracy 0.9812500011175871
# Meta Valid Error 0.7394893341747775
# Meta Valid Accuracy 0.8375000073574483
#
#
# Iteration 18944
# Meta Train Error 0.03646427099954508
# Meta Train Accuracy 0.9875000007450581
# Meta Valid Error 0.72926300396648
# Meta Valid Accuracy 0.8625000063329935
#
#
# Iteration 18976
# Meta Train Error 0.055475439339716104
# Meta Train Accuracy 0.9875000007450581
# Meta Valid Error 0.7748586839094287
# Meta Valid Accuracy 0.7812500102445483
#
#
# Iteration 19008
# Meta Train Error 0.0798451429304805
# Meta Train Accuracy 0.9750000014901161
# Meta Valid Error 0.8686685462216701
# Meta Valid Accuracy 0.7812500088475645
#
#
# Iteration 19040
# Meta Train Error 0.062259065495709365
# Meta Train Accuracy 0.9812500011175871
# Meta Valid Error 0.552685992185161
# Meta Valid Accuracy 0.8687500078231096
#
#
# Iteration 19072
# Meta Train Error 0.04535393808396293
# Meta Train Accuracy 0.9875000007450581
# Meta Valid Error 0.8343199765199643
# Meta Valid Accuracy 0.8000000077299774
#
#
# Iteration 19104
# Meta Train Error 0.0610233576326209
# Meta Train Accuracy 0.9875000007450581
# Meta Valid Error 0.5043445565554521
# Meta Valid Accuracy 0.8500000070780516
#
#
# Iteration 19136
# Meta Train Error 0.041154326491323445
# Meta Train Accuracy 0.9812500011175871
# Meta Valid Error 0.5572259704322278
# Meta Valid Accuracy 0.8500000080093741
#
#
# Iteration 19168
# Meta Train Error 0.0290757259667771
# Meta Train Accuracy 0.993750000372529
# Meta Valid Error 1.1150344383618176
# Meta Valid Accuracy 0.7375000077299774
#
#
# Iteration 19200
# Meta Train Error 0.09083551436378912
# Meta Train Accuracy 0.9687500018626451
# Meta Valid Error 1.0581901608165936
# Meta Valid Accuracy 0.7750000092200935
#
#
# Iteration 19232
# Meta Train Error 0.022460111933469307
# Meta Train Accuracy 0.993750000372529
# Meta Valid Error 0.8720006015395256
# Meta Valid Accuracy 0.8125000069849193
#
#
# Iteration 19264
# Meta Train Error 0.017646089399022458
# Meta Train Accuracy 0.993750000372529
# Meta Valid Error 0.5979860874954284
# Meta Valid Accuracy 0.8500000080093741
#
#
# Iteration 19296
# Meta Train Error 0.04008660811177833
# Meta Train Accuracy 0.993750000372529
# Meta Valid Error 0.5892191466241457
# Meta Valid Accuracy 0.8687500040978193
#
#
# Iteration 19328
# Meta Train Error 0.059489261813382655
# Meta Train Accuracy 0.9812500011175871
# Meta Valid Error 0.7038442615678377
# Meta Valid Accuracy 0.8062500064261258
#
#
# Iteration 19360
# Meta Train Error 0.04683326381746156
# Meta Train Accuracy 0.993750000372529
# Meta Valid Error 0.7906524804102446
# Meta Valid Accuracy 0.8250000076368451
#
#
# Iteration 19392
# Meta Train Error 0.08328326111450224
# Meta Train Accuracy 0.9625000022351742
# Meta Valid Error 0.685004706437212
# Meta Valid Accuracy 0.8250000085681677
#
#
# Iteration 19424
# Meta Train Error 0.024004844151932048
# Meta Train Accuracy 0.993750000372529
# Meta Valid Error 0.808149794336714
# Meta Valid Accuracy 0.8312500081956387
#
#
# Iteration 19456
# Meta Train Error 0.04783323063065836
# Meta Train Accuracy 0.9875000007450581
# Meta Valid Error 0.9299056694401315
# Meta Valid Accuracy 0.8125000060535967
#
#
# Iteration 19488
# Meta Train Error 0.03881271884574744
# Meta Train Accuracy 0.9875000007450581
# Meta Valid Error 0.4363772452518333
# Meta Valid Accuracy 0.881250006146729
#
#
# Iteration 19520
# Meta Train Error 0.10109287808791123
# Meta Train Accuracy 0.9562500026077032
# Meta Valid Error 0.6505558045409998
# Meta Valid Accuracy 0.8500000075437129
#
#
# Iteration 19552
# Meta Train Error 0.02865285336827128
# Meta Train Accuracy 0.9875000007450581
# Meta Valid Error 0.9736853040049027
# Meta Valid Accuracy 0.7937500076368451
#
#
# Iteration 19584
# Meta Train Error 0.041468301289569354
# Meta Train Accuracy 0.9875000007450581
# Meta Valid Error 0.6840240939385467
# Meta Valid Accuracy 0.8437500051222742
#
#
# Iteration 19616
# Meta Train Error 0.04288529479299541
# Meta Train Accuracy 0.9875000007450581
# Meta Valid Error 1.2701899279061308
# Meta Valid Accuracy 0.7687500091269612
#
#
# Iteration 19648
# Meta Train Error 0.04589416447925032
# Meta Train Accuracy 0.9812500011175871
# Meta Valid Error 0.7949041373158252
# Meta Valid Accuracy 0.887500002514571
#
#
# Iteration 19680
# Meta Train Error 0.10746765055500873
# Meta Train Accuracy 0.9750000014901161
# Meta Valid Error 0.7365392434739988
# Meta Valid Accuracy 0.812500006519258
#
#
# Iteration 19712
# Meta Train Error 0.01941254737289455
# Meta Train Accuracy 0.993750000372529
# Meta Valid Error 0.9400692542071738
# Meta Valid Accuracy 0.812500006519258
#
#
# Iteration 19744
# Meta Train Error 0.053308797248064366
# Meta Train Accuracy 0.9812500011175871
# Meta Valid Error 0.8342035750080754
# Meta Valid Accuracy 0.8187500080093741
#
#
# Iteration 19776
# Meta Train Error 0.055899613537803816
# Meta Train Accuracy 0.9812500011175871
# Meta Valid Error 0.9606850450173852
# Meta Valid Accuracy 0.8000000072643161
#
#
# Iteration 19808
# Meta Train Error 0.046093921766669155
# Meta Train Accuracy 0.993750000372529
# Meta Valid Error 1.0065869909467438
# Meta Valid Accuracy 0.8000000072643161
#
#
# Iteration 19840
# Meta Train Error 0.013175097015391657
# Meta Train Accuracy 1.0
# Meta Valid Error 0.7194329464171005
# Meta Valid Accuracy 0.8500000070780516
#
#
# Iteration 19872
# Meta Train Error 0.10747236517931924
# Meta Train Accuracy 0.9750000014901161
# Meta Valid Error 0.9143032751674127
# Meta Valid Accuracy 0.8000000091269612
#
#
# Iteration 19904
# Meta Train Error 0.04850747125078669
# Meta Train Accuracy 0.9812500011175871
# Meta Valid Error 0.8696647982769719
# Meta Valid Accuracy 0.8375000073574483
#
#
# Iteration 19936
# Meta Train Error 0.034260643088146026
# Meta Train Accuracy 0.9875000007450581
# Meta Valid Error 0.5623534450735406
# Meta Valid Accuracy 0.8125000088475645
#
#
# Iteration 19968
# Meta Train Error 0.04847584217463918
# Meta Train Accuracy 0.9750000014901161
# Meta Valid Error 1.3420032037547571
# Meta Valid Accuracy 0.756250009406358
#
#
# Iteration 20000
# Meta Train Error 0.06029493367532268
# Meta Train Accuracy 0.9812500011175871
# Meta Valid Error 0.33908472757116215
# Meta Valid Accuracy 0.9062500055879354
#
#
# Iteration 20032
# Meta Train Error 0.07259755148606928
# Meta Train Accuracy 0.993750000372529
# Meta Valid Error 0.7286838685178623
# Meta Valid Accuracy 0.8312500077299774
#
#
# Iteration 20064
# Meta Train Error 0.01244922946261795
# Meta Train Accuracy 1.0
# Meta Valid Error 0.8051326541772141
# Meta Valid Accuracy 0.8000000081956387
#
#
# Iteration 20096
# Meta Train Error 0.04181989688413523
# Meta Train Accuracy 0.9875000007450581
# Meta Valid Error 0.6854138619710284
# Meta Valid Accuracy 0.8312500058673322
#
#
# Iteration 20128
# Meta Train Error 0.06415619536483064
# Meta Train Accuracy 0.9875000007450581
# Meta Valid Error 0.967535164572837
# Meta Valid Accuracy 0.8000000091269612
#
#
# Iteration 20160
# Meta Train Error 0.01968851178503428
# Meta Train Accuracy 1.0
# Meta Valid Error 0.893001600375328
# Meta Valid Accuracy 0.8375000078231096
#
#
# Iteration 20192
# Meta Train Error 0.01798612893526297
# Meta Train Accuracy 0.993750000372529
# Meta Valid Error 0.7371518828504122
# Meta Valid Accuracy 0.8187500075437129
#
#
# Iteration 20224
# Meta Train Error 0.05323762891930528
# Meta Train Accuracy 0.9812500011175871
# Meta Valid Error 0.6255752234025067
# Meta Valid Accuracy 0.8187500052154064
#
#
# Iteration 20256
# Meta Train Error 0.11556192504474438
# Meta Train Accuracy 0.9812500011175871
# Meta Valid Error 0.7299675526774081
# Meta Valid Accuracy 0.8000000058673322
# Iteration 20288
# Meta Train Error 0.06685965269821281
# Meta Train Accuracy 0.9875000007450581
# Meta Valid Error 0.5559325921767595
# Meta Valid Accuracy 0.8875000057742
#
#
# Iteration 20320
# Meta Train Error 0.0554979955802537
# Meta Train Accuracy 0.9750000014901161
# Meta Valid Error 0.869456194587201
# Meta Valid Accuracy 0.843750003259629
#
#
# Iteration 20352
# Meta Train Error 0.07927300337360066
# Meta Train Accuracy 0.9625000013038516
# Meta Valid Error 0.7289411036231286
# Meta Valid Accuracy 0.8187500084750354
#
#
# Iteration 20384
# Meta Train Error 0.09388033216646363
# Meta Train Accuracy 0.9687500018626451
# Meta Valid Error 0.30643622996649356
# Meta Valid Accuracy 0.9125000052154064
#
#
# Iteration 20416
# Meta Train Error 0.0592112473339057
# Meta Train Accuracy 0.9875000007450581
# Meta Valid Error 1.1790050815134236
# Meta Valid Accuracy 0.7812500093132257
#
#
# Iteration 20448
# Meta Train Error 0.030083353498184806
# Meta Train Accuracy 0.993750000372529
# Meta Valid Error 1.3230486006333422
# Meta Valid Accuracy 0.7375000114552677
#
#
# Iteration 20480
# Meta Train Error 0.11675682664736087
# Meta Train Accuracy 0.9562500026077032
# Meta Valid Error 0.7985406424413668
# Meta Valid Accuracy 0.7937500081025064
#
#
# Iteration 20512
# Meta Train Error 0.03706395500239523
# Meta Train Accuracy 0.9812500011175871
# Meta Valid Error 1.1033439099053908
# Meta Valid Accuracy 0.7375000086612999
#
#
# Iteration 20544
# Meta Train Error 0.06890026676137495
# Meta Train Accuracy 0.9750000014901161
# Meta Valid Error 0.7759374636461871
# Meta Valid Accuracy 0.8000000100582838
#
#
# Iteration 20576
# Meta Train Error 0.08722074649813294
# Meta Train Accuracy 0.9687500018626451
# Meta Valid Error 0.9225349089374504
# Meta Valid Accuracy 0.8187500084750354
#
#
# Iteration 20608
# Meta Train Error 0.08611777464648185
# Meta Train Accuracy 0.9625000022351742
# Meta Valid Error 0.515978590564373
# Meta Valid Accuracy 0.8750000060535967
#
#
# Iteration 20640
# Meta Train Error 0.04951924810274022
# Meta Train Accuracy 0.9875000007450581
# Meta Valid Error 1.1170147116545195
# Meta Valid Accuracy 0.7500000088475645
#
#
# Iteration 20672
# Meta Train Error 0.09783124034197499
# Meta Train Accuracy 0.9562500026077032
# Meta Valid Error 0.9456053523076662
# Meta Valid Accuracy 0.8187500066123903
#
#
# Iteration 20704
# Meta Train Error 0.0420092604307456
# Meta Train Accuracy 0.9812500011175871
# Meta Valid Error 0.7810753505946195
# Meta Valid Accuracy 0.8187500066123903
#
#
# Iteration 20736
# Meta Train Error 0.056800054612722306
# Meta Train Accuracy 0.9812500011175871
# Meta Valid Error 1.1198978164313758
# Meta Valid Accuracy 0.7437500078231096
#
#
# Iteration 20768
# Meta Train Error 0.129814178588731
# Meta Train Accuracy 0.9750000014901161
# Meta Valid Error 0.577539026847262
# Meta Valid Accuracy 0.8562500057742
#
#
# Iteration 20800
# Meta Train Error 0.04671085324230262
# Meta Train Accuracy 0.9812500011175871
# Meta Valid Error 0.576027732444345
# Meta Valid Accuracy 0.8625000072643161
#
#
# Iteration 20832
# Meta Train Error 0.05633209886491386
# Meta Train Accuracy 0.9812500011175871
# Meta Valid Error 1.1596033976002218
# Meta Valid Accuracy 0.7625000113621354
#
#
# Iteration 20864
# Meta Train Error 0.04708343705192419
# Meta Train Accuracy 0.993750000372529
# Meta Valid Error 0.4674408052811714
# Meta Valid Accuracy 0.875000006519258
#
#
# Iteration 20896
# Meta Train Error 0.025172646264536525
# Meta Train Accuracy 0.993750000372529
# Meta Valid Error 0.5420830408584152
# Meta Valid Accuracy 0.843750006519258
#
#
# Iteration 20928
# Meta Train Error 0.03372407720371484
# Meta Train Accuracy 0.993750000372529
# Meta Valid Error 0.6524867725129297
# Meta Valid Accuracy 0.868750006891787
#
#
# Iteration 20960
# Meta Train Error 0.040649170642154786
# Meta Train Accuracy 0.9812500011175871
# Meta Valid Error 1.1675181316632006
# Meta Valid Accuracy 0.7812500111758709
#
#
# Iteration 20992
# Meta Train Error 0.040364696441997694
# Meta Train Accuracy 0.9875000007450581
# Meta Valid Error 0.3339357477198064
# Meta Valid Accuracy 0.9250000044703484
#
#
# Iteration 21024
# Meta Train Error 0.06681888792036261
# Meta Train Accuracy 0.9812500011175871
# Meta Valid Error 0.8024987055014208
# Meta Valid Accuracy 0.8187500089406967
#
#
# Iteration 21056
# Meta Train Error 0.03541981081889389
# Meta Train Accuracy 0.9875000007450581
# Meta Valid Error 0.7099551627497931
# Meta Valid Accuracy 0.8312500072643161
#
#
# Iteration 21088
# Meta Train Error 0.03547140674754701
# Meta Train Accuracy 0.993750000372529
# Meta Valid Error 0.5402750317431924
# Meta Valid Accuracy 0.8875000067055225
#
#
# Iteration 21120
# Meta Train Error 0.0433251994290913
# Meta Train Accuracy 0.9875000007450581
# Meta Valid Error 0.605541332029361
# Meta Valid Accuracy 0.843750006519258
#
#
# Iteration 21152
# Meta Train Error 0.027373714112400194
# Meta Train Accuracy 0.9875000007450581
# Meta Valid Error 0.8624725184508861
# Meta Valid Accuracy 0.8000000081956387
#
#
# Iteration 21184
# Meta Train Error 0.03346842644100434
# Meta Train Accuracy 0.9875000007450581
# Meta Valid Error 0.8201733986179534
# Meta Valid Accuracy 0.8062500106170774
#
#
# Iteration 21216
# Meta Train Error 0.15969351801595622
# Meta Train Accuracy 0.9562500016763806
# Meta Valid Error 0.5205022341693848
# Meta Valid Accuracy 0.881250006146729
#
#
# Iteration 21248
# Meta Train Error 0.0759705465393381
# Meta Train Accuracy 0.9812500011175871
# Meta Valid Error 0.9732962661855709
# Meta Valid Accuracy 0.7937500085681677
#
#
# Iteration 21280
# Meta Train Error 0.11789930338977683
# Meta Train Accuracy 0.9625000022351742
# Meta Valid Error 0.8348147454335617
# Meta Valid Accuracy 0.8187500070780516
#
#
# Iteration 21312
# Meta Train Error 0.010146629813448271
# Meta Train Accuracy 1.0
# Meta Valid Error 0.7149128168239258
# Meta Valid Accuracy 0.8250000076368451
#
#
# Iteration 21344
# Meta Train Error 0.09901747107869596
# Meta Train Accuracy 0.9750000014901161
# Meta Valid Error 0.6155298468872843
# Meta Valid Accuracy 0.8812500070780516
#
#
# Iteration 21376
# Meta Train Error 0.05285131252867359
# Meta Train Accuracy 0.993750000372529
# Meta Valid Error 0.5422207161886945
# Meta Valid Accuracy 0.8437500074505806
#
#
# Iteration 21408
# Meta Train Error 0.05875699560488101
# Meta Train Accuracy 0.9750000005587935
# Meta Valid Error 0.6279865793270858
# Meta Valid Accuracy 0.8187500084750354
#
#
# Iteration 21440
# Meta Train Error 0.09128052465712244
# Meta Train Accuracy 0.9812500011175871
# Meta Valid Error 0.352079602871072
# Meta Valid Accuracy 0.9125000042840838
#
#
# Iteration 21472
# Meta Train Error 0.015373848971421467
# Meta Train Accuracy 0.993750000372529
# Meta Valid Error 0.7789899834326661
# Meta Valid Accuracy 0.8187500066123903
#
#
# Iteration 21504
# Meta Train Error 0.03715579990387141
# Meta Train Accuracy 0.993750000372529
# Meta Valid Error 0.5153321577199677
# Meta Valid Accuracy 0.8500000070780516
#
#
# Iteration 21536
# Meta Train Error 0.14725512861195966
# Meta Train Accuracy 0.9562500026077032
# Meta Valid Error 0.893482036784917
# Meta Valid Accuracy 0.7875000084750354
#
#
# Iteration 21568
# Meta Train Error 0.012880429673941762
# Meta Train Accuracy 1.0
# Meta Valid Error 1.2313163863004775
# Meta Valid Accuracy 0.8000000067986548
#
#
# Iteration 21600
# Meta Train Error 0.12915365917547206
# Meta Train Accuracy 0.9562500026077032
# Meta Valid Error 0.8838620403075765
# Meta Valid Accuracy 0.8312500081956387
#
#
# Iteration 21632
# Meta Train Error 0.017213404270705723
# Meta Train Accuracy 0.993750000372529
# Meta Valid Error 0.8722398319791864
# Meta Valid Accuracy 0.8312500063329935
#
#
# Iteration 21664
# Meta Train Error 0.038736711233923415
# Meta Train Accuracy 0.9812500011175871
# Meta Valid Error 0.5868421215943727
# Meta Valid Accuracy 0.8687500078231096
#
#
# Iteration 21696
# Meta Train Error 0.04272582145006254
# Meta Train Accuracy 0.9812500011175871
# Meta Valid Error 1.0517249479307793
# Meta Valid Accuracy 0.8000000077299774
#
#
# Iteration 21728
# Meta Train Error 0.06319138555886639
# Meta Train Accuracy 0.9625000022351742
# Meta Valid Error 0.9574302626497229
# Meta Valid Accuracy 0.8250000085681677
#
#
# Iteration 21760
# Meta Train Error 0.04760273685189986
# Meta Train Accuracy 0.9875000007450581
# Meta Valid Error 0.9951732301533411
# Meta Valid Accuracy 0.8187500084750354

# %%
# round(12.54673, 2)

# %%
# fig = plt.figure()
# ax = plt.subplot()
# ax.plot(list(range(0, (10))), list(range(0, (10))), label="Meta Train")
# ax.text(5, 0, 'Meta Test:95%', style='italic',
#         bbox={'facecolor': 'red', 'alpha': 0.25, 'pad': 5}, ha='center', va='center')
# # ax.plot(list(range(0, len(Meta_Val_Accuracy))), Meta_Val_Accuracy, label="Meta Val")
# plt.title('Adaption')
# plt.xlabel('Iteration')
# plt.ylabel('Meta Accuracy')
# ax.legend()
# # plt.show()



# # plt.plot(list(range(0, len(Meta_Train_Accuracy))), Meta_Train_Accuracy,
# #         list(range(0, len(Meta_Val_Accuracy))), Meta_Val_Accuracy, label = ("A", "B"))#, list(range(0, len(Meta_Train_Error))), 
# #          Meta_Train_Error)#,label = ["Meta Train Accuracy", "Meta Train Error"])
# plt.savefig('foo.png')

# %%
# plt.plot(list(range(0, len(Meta_Train_Accuracy))), Meta_Train_Accuracy,
#         list(range(0, len(Meta_Val_Accuracy))), Meta_Val_Accuracy, label = ("A", "B"))#, list(range(0, len(Meta_Train_Error))), 
# #          Meta_Train_Error)#,label = ["Meta Train Accuracy", "Meta Train Error"])
