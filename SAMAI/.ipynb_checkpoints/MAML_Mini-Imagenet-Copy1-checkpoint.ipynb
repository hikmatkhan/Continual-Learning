# %%
#!/usr/bin/env python3

"""
Demonstrates how to:
    * use the MAML wrapper for fast-adaptation,
    * use the benchmark interface to load mini-ImageNet, and
    * sample tasks and split them in adaptation and evaluation sets.

To contrast the use of the benchmark interface with directly instantiating mini-ImageNet datasets and tasks, compare with `protonet_miniimagenet.py`.
"""

import random
import numpy as np

import torch
from torch import nn, optim
import matplotlib.pyplot as plt
import learn2learn as l2l
from learn2learn.data.transforms import (NWays,
                                         KShots,
                                         LoadData,
                                         RemapLabels,
                                         ConsecutiveLabels)
import os

# %%
def accuracy(predictions, targets):
    predictions = predictions.argmax(dim=1).view(targets.shape)
    return (predictions == targets).sum().float() / targets.size(0)


def fast_adapt(batch, learner, loss, adaptation_steps, shots, ways, device):
    data, labels = batch
    data, labels = data.to(device), labels.to(device)

    # Separate data into adaptation/evalutation sets
    adaptation_indices = np.zeros(data.size(0), dtype=bool)
    adaptation_indices[np.arange(shots*ways) * 2] = True
    evaluation_indices = torch.from_numpy(~adaptation_indices)
    adaptation_indices = torch.from_numpy(adaptation_indices)
    adaptation_data, adaptation_labels = data[adaptation_indices], labels[adaptation_indices]
    evaluation_data, evaluation_labels = data[evaluation_indices], labels[evaluation_indices]

    # Adapt the model
    for step in range(adaptation_steps):
        adaptation_error = loss(learner(adaptation_data), adaptation_labels)
        learner.adapt(adaptation_error)

    # Evaluate the adapted model
    predictions = learner(evaluation_data)
    evaluation_error = loss(predictions, evaluation_labels)
    evaluation_accuracy = accuracy(predictions, evaluation_labels)
    return evaluation_error, evaluation_accuracy


def perform_experiment(dataset,
        ways=5,
        shots=5,
        meta_lr=0.003,
        fast_lr=0.5,
        meta_batch_size=32,
        adaptation_steps=1,
        num_iterations=60000,
        cuda=True,
        seed=42,
):
    
    Meta_Train_Accuracy = []
    Meta_Train_Error = []
    Meta_Val_Accuracy = []
    Meta_Val_Error = []
#     Iterations = []
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    device = torch.device('cpu')
    if cuda and torch.cuda.device_count():
        torch.cuda.manual_seed(seed)
        device = torch.device('cuda')

    # Create Tasksets using the benchmark interface
    tasksets = l2l.vision.benchmarks.get_tasksets(dataset,
                                                  train_samples=2*shots,
                                                  train_ways=ways,
                                                  test_samples=2*shots,
                                                  test_ways=ways,
                                                  root='~/data',
    )

    # Create model
    model = l2l.vision.models.MiniImagenetCNN(ways)
    model.to(device)
    maml = l2l.algorithms.MAML(model, lr=fast_lr, first_order=False)
    opt = optim.Adam(maml.parameters(), meta_lr)
    loss = nn.CrossEntropyLoss(reduction='mean')

    for iteration in range(num_iterations):
        opt.zero_grad()
        meta_train_error = 0.0
        meta_train_accuracy = 0.0
        meta_valid_error = 0.0
        meta_valid_accuracy = 0.0
        for task in range(meta_batch_size):
            # Compute meta-training loss
            learner = maml.clone()
            batch = tasksets.train.sample()
            evaluation_error, evaluation_accuracy = fast_adapt(batch,
                                                               learner,
                                                               loss,
                                                               adaptation_steps,
                                                               shots,
                                                               ways,
                                                               device)
            evaluation_error.backward()
            meta_train_error += evaluation_error.item()
            meta_train_accuracy += evaluation_accuracy.item()

            # Compute meta-validation loss
            learner = maml.clone()
            batch = tasksets.validation.sample()
            evaluation_error, evaluation_accuracy = fast_adapt(batch,
                                                               learner,
                                                               loss,
                                                               adaptation_steps,
                                                               shots,
                                                               ways,
                                                               device)
            meta_valid_error += evaluation_error.item()
            meta_valid_accuracy += evaluation_accuracy.item()

        # Print some metrics
#         print('\n')
#         print('Iteration', iteration)
#         print('Meta Train Error', meta_train_error / meta_batch_size)
#         print('Meta Train Accuracy', meta_train_accuracy / meta_batch_size)
#         print('Meta Valid Error', meta_valid_error / meta_batch_size)
#         print('Meta Valid Accuracy', meta_valid_accuracy / meta_batch_size)
        
        meta_train_error =  meta_train_error / meta_batch_size
        meta_train_accuracy = meta_train_accuracy / meta_batch_size
        meta_val_error =  meta_valid_error / meta_batch_size
        meta_val_accuracy = meta_valid_accuracy / meta_batch_size
        if(iteration % 4 ==0):
            print('\n')
            print('Iteration', iteration)
            print('Meta Train Error', meta_train_error)
            print('Meta Train Accuracy', meta_train_accuracy)
            print('Meta Valid Error', meta_val_error)
            print('Meta Valid Accuracy', meta_val_accuracy)

        Meta_Train_Accuracy.append(meta_train_accuracy)
        Meta_Train_Error.append(meta_train_error)
        Meta_Val_Accuracy.append(meta_val_accuracy)
        Meta_Val_Error.append(meta_val_error)

        # Average the accumulated gradients and optimize
        for p in maml.parameters():
            p.grad.data.mul_(1.0 / meta_batch_size)
        opt.step()

    meta_test_error = 0.0
    meta_test_accuracy = 0.0
    for task in range(meta_batch_size):
        # Compute meta-testing loss
        learner = maml.clone()
        batch = tasksets.test.sample()
        evaluation_error, evaluation_accuracy = fast_adapt(batch,
                                                           learner,
                                                           loss,
                                                           adaptation_steps,
                                                           shots,
                                                           ways,
                                                           device)
        meta_test_error += evaluation_error.item()
        meta_test_accuracy += evaluation_accuracy.item()
#     print('Meta Test Error', meta_test_error / meta_batch_size)
#     print('Meta Test Accuracy', meta_test_accuracy / meta_batch_size)
    Meta_Test_Error = meta_test_error / meta_batch_size
    print('Meta Test Error', Meta_Test_Error)
    Meta_Test_Accuracy = meta_test_accuracy / meta_batch_size
    print('Meta Test Accuracy', Meta_Test_Accuracy)
    
    if not os.path.exists('plots'):
        os.makedirs('plots')
    if not os.path.exists('plots/acc'):
        os.makedirs('plots/acc')
    if not os.path.exists('plots/loss'):
        os.makedirs('plots/loss')
        
    ###### Plot Accuracies ######
    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
    fig = plt.figure()
    ax = plt.subplot(111)
    ax.plot(list(range(0, len(Meta_Train_Accuracy))), Meta_Train_Accuracy, label="Meta Train ")
    ax.plot(list(range(0, len(Meta_Val_Accuracy))), Meta_Val_Accuracy, label="Meta Val")
#     ax.text((len(Meta_Val_Accuracy)/2), 0, 'Meta Test:{0}'.format(round(meta_test_accuracy, 2)), style='italic',
#         bbox={'facecolor': 'red', 'alpha': 0.25, 'pad': 5})
    # place a text box in upper left in axes coords
    ax.text(0.05, 0.5, 'Meta Test:{0}'.format(round(Meta_Test_Accuracy, 2)), transform=ax.transAxes, fontsize=14,
            verticalalignment='top', bbox=props)
    plt.title('Adaption')
    plt.xlabel('Iteration')
    plt.ylabel('Meta Accuracy')
    ax.legend()
    plt.savefig('./plots/acc/{0}_ways_{1}_shots_{2}_Acc_I_{3}.png'.format(dataset, ways, shots, num_iterations))
    ###### Plot Accuracies ######

    ###### Plot Errors ######
    fig = plt.figure()
    ax = plt.subplot(111)
    ax.plot(list(range(0, len(Meta_Train_Error))), Meta_Train_Error, label="Meta Train ")
    ax.plot(list(range(0, len(Meta_Val_Error))), Meta_Val_Accuracy, label="Meta Val Lss")
#     ax.text((len(Meta_Val_Accuracy)/2),0, 'Meta Test Accuracy:{0}  Meta Test Loss:{1}'.format(round(meta_test_accuracy, 2),
#                               round(meta_test_error, 2)), style='italic',
#         bbox={'facecolor': 'red', 'alpha': 0.25, 'pad': 5})
    ax.text(0.05, 0.5, 'MTestAcc:{0}  MTestLoss:{1}'.format(round(Meta_Test_Accuracy, 2),
                                           round(Meta_Test_Error, 2)), transform=ax.transAxes, fontsize=14,
            verticalalignment='top', bbox=props)
    plt.title('Adaption')
    plt.xlabel('Iteration')
    plt.ylabel('Meta Loss')
    ax.legend()
    plt.savefig('./plots/loss/{0}_ways_{1}_shots_{2}_Loss_I_{3}.png'.format(dataset, ways, shots, num_iterations))
    ###### Plot Errors ######


if __name__ == '__main__':
    perform_experiment(dataset='mini-imagenet',
    ways=5,
    shots=1,
    meta_lr=0.003,
    fast_lr=0.5,
    meta_batch_size=32,
    adaptation_steps=1,
    num_iterations=60000,
    cuda=True,
    seed=42)
# Out:
# Iteration 0
# Meta Train Error 9.065270200371742
# Meta Train Accuracy 0.18750000279396772
# Meta Valid Error 8.114383161067963
# Meta Valid Accuracy 0.218750003259629
#
#
# Iteration 4
# Meta Train Error 3.0861685760319233
# Meta Train Accuracy 0.23750000493600965
# Meta Valid Error 3.43958405777812
# Meta Valid Accuracy 0.218750003259629
#
#
# Iteration 8
# Meta Train Error 3.018300198018551
# Meta Train Accuracy 0.22500000381842256
# Meta Valid Error 3.080197136849165
# Meta Valid Accuracy 0.23125000344589353
#
#
# Iteration 12
# Meta Train Error 2.635277282446623
# Meta Train Accuracy 0.25000000558793545
# Meta Valid Error 2.5470616035163403
# Meta Valid Accuracy 0.20625000400468707
#
#
# Iteration 16
# Meta Train Error 2.3820297587662935
# Meta Train Accuracy 0.2875000066123903
# Meta Valid Error 2.3402087166905403
# Meta Valid Accuracy 0.2625000053085387
#
#
# Iteration 20
# Meta Train Error 2.156994268298149
# Meta Train Accuracy 0.2937500048428774
# Meta Valid Error 2.2516865469515324
# Meta Valid Accuracy 0.21875000465661287
#
#
# Iteration 24
# Meta Train Error 1.84074567258358
# Meta Train Accuracy 0.31250000558793545
# Meta Valid Error 1.9802589751780033
# Meta Valid Accuracy 0.2687500063329935
#
#
# Iteration 28
# Meta Train Error 1.7967583499848843
# Meta Train Accuracy 0.29375000577419996
# Meta Valid Error 1.8377921245992184
# Meta Valid Accuracy 0.26875000493600965
#
#
# Iteration 32
# Meta Train Error 1.813301583752036
# Meta Train Accuracy 0.26250000577419996
# Meta Valid Error 1.8506513237953186
# Meta Valid Accuracy 0.31875000707805157
#
#
# Iteration 36
# Meta Train Error 1.7615054212510586
# Meta Train Accuracy 0.3000000067986548
# Meta Valid Error 1.8404598087072372
# Meta Valid Accuracy 0.2562500056810677
#
#
# Iteration 40
# Meta Train Error 1.6820411160588264
# Meta Train Accuracy 0.3062500054948032
# Meta Valid Error 1.86040223762393
# Meta Valid Accuracy 0.2750000054948032
#
#
# Iteration 44
# Meta Train Error 1.860485065728426
# Meta Train Accuracy 0.29375000577419996
# Meta Valid Error 1.7344059646129608
# Meta Valid Accuracy 0.28125000605359674
#
#
# Iteration 48
# Meta Train Error 1.571640344336629
# Meta Train Accuracy 0.38125000754371285
# Meta Valid Error 1.820817667990923
# Meta Valid Accuracy 0.23750000493600965
#
#
# Iteration 52
# Meta Train Error 1.6787894535809755
# Meta Train Accuracy 0.28125000558793545
# Meta Valid Error 1.675927709788084
# Meta Valid Accuracy 0.2875000052154064
#
#
# Iteration 56
# Meta Train Error 1.7343642972409725
# Meta Train Accuracy 0.22500000335276127
# Meta Valid Error 1.7279533632099628
# Meta Valid Accuracy 0.23750000493600965
#
#
# Iteration 60
# Meta Train Error 1.6335541382431984
# Meta Train Accuracy 0.3062500054948032
# Meta Valid Error 1.5747385025024414
# Meta Valid Accuracy 0.3625000072643161
#
#
# Iteration 64
# Meta Train Error 1.6708941124379635
# Meta Train Accuracy 0.281250006519258
# Meta Valid Error 1.7287978641688824
# Meta Valid Accuracy 0.25000000558793545
#
#
# Iteration 68
# Meta Train Error 1.6875078156590462
# Meta Train Accuracy 0.2000000039115548
# Meta Valid Error 1.6028724424540997
# Meta Valid Accuracy 0.2750000054948032
#
#
# Iteration 72
# Meta Train Error 1.6396421790122986
# Meta Train Accuracy 0.32500000670552254
# Meta Valid Error 1.6435080543160439
# Meta Valid Accuracy 0.23750000540167093
#
#
# Iteration 76
# Meta Train Error 1.6785660162568092
# Meta Train Accuracy 0.24375000456348062
# Meta Valid Error 1.5732951499521732
# Meta Valid Accuracy 0.2875000056810677
#
#
# Iteration 80
# Meta Train Error 1.5562150850892067
# Meta Train Accuracy 0.35000000754371285
# Meta Valid Error 1.7093873172998428
# Meta Valid Accuracy 0.2437500050291419
#
#
# Iteration 84
# Meta Train Error 1.6297402270138264
# Meta Train Accuracy 0.30000000819563866
# Meta Valid Error 1.5888798721134663
# Meta Valid Accuracy 0.29375000623986125
#
#
# Iteration 88
# Meta Train Error 1.6549207158386707
# Meta Train Accuracy 0.27500000642612576
# Meta Valid Error 1.6726775877177715
# Meta Valid Accuracy 0.2500000046566129
#
#
# Iteration 92
# Meta Train Error 1.6154022924602032
# Meta Train Accuracy 0.29375000623986125
# Meta Valid Error 1.645432986319065
# Meta Valid Accuracy 0.23125000344589353
#
#
# Iteration 96
# Meta Train Error 1.6232257150113583
# Meta Train Accuracy 0.28125000605359674
# Meta Valid Error 1.6493906565010548
# Meta Valid Accuracy 0.26250000577419996
#
#
# Iteration 100
# Meta Train Error 1.5890963599085808
# Meta Train Accuracy 0.24375000596046448
# Meta Valid Error 1.6594771593809128
# Meta Valid Accuracy 0.22500000521540642
#
#
# Iteration 104
# Meta Train Error 1.582067135721445
# Meta Train Accuracy 0.3125000069849193
# Meta Valid Error 1.5829060524702072
# Meta Valid Accuracy 0.28125000512227416
#
#
# Iteration 108
# Meta Train Error 1.6431067641824484
# Meta Train Accuracy 0.25625000428408384
# Meta Valid Error 1.689983893185854
# Meta Valid Accuracy 0.281250006519258
#
#
# Iteration 112
# Meta Train Error 1.5480621419847012
# Meta Train Accuracy 0.29375000577419996
# Meta Valid Error 1.635567169636488
# Meta Valid Accuracy 0.23750000400468707
#
#
# Iteration 116
# Meta Train Error 1.5516745410859585
# Meta Train Accuracy 0.3437500074505806
# Meta Valid Error 1.5732471719384193
# Meta Valid Accuracy 0.28750000707805157
#
#
# Iteration 120
# Meta Train Error 1.5551244467496872
# Meta Train Accuracy 0.281250006519258
# Meta Valid Error 1.5261823125183582
# Meta Valid Accuracy 0.31875000847503543
#
#
# Iteration 124
# Meta Train Error 1.6016812697052956
# Meta Train Accuracy 0.26875000493600965
# Meta Valid Error 1.5804306492209435
# Meta Valid Accuracy 0.35000000707805157
#
#
# Iteration 128
# Meta Train Error 1.5901310630142689
# Meta Train Accuracy 0.32500000670552254
# Meta Valid Error 1.5359328016638756
# Meta Valid Accuracy 0.318750006146729
#
#
# Iteration 132
# Meta Train Error 1.6104513183236122
# Meta Train Accuracy 0.2937500053085387
# Meta Valid Error 1.6450678929686546
# Meta Valid Accuracy 0.2750000059604645
#
#
# Iteration 136
# Meta Train Error 1.4846312068402767
# Meta Train Accuracy 0.3312500063329935
# Meta Valid Error 1.6686930507421494
# Meta Valid Accuracy 0.23750000400468707
#
#
# Iteration 140
# Meta Train Error 1.6021854057908058
# Meta Train Accuracy 0.24375000596046448
# Meta Valid Error 1.640866905450821
# Meta Valid Accuracy 0.28125000558793545
#
#
# Iteration 144
# Meta Train Error 1.6036912016570568
# Meta Train Accuracy 0.2750000050291419
# Meta Valid Error 1.5413103625178337
# Meta Valid Accuracy 0.29375000623986125
#
#
# Iteration 148
# Meta Train Error 1.5567809902131557
# Meta Train Accuracy 0.34375000884756446
# Meta Valid Error 1.5092623569071293
# Meta Valid Accuracy 0.35000000800937414
#
#
# Iteration 152
# Meta Train Error 1.5427454635500908
# Meta Train Accuracy 0.29375000623986125
# Meta Valid Error 1.5621160082519054
# Meta Valid Accuracy 0.3062500050291419
#
#
# Iteration 156
# Meta Train Error 1.5641329400241375
# Meta Train Accuracy 0.34375000884756446
# Meta Valid Error 1.5947538912296295
# Meta Valid Accuracy 0.2750000045634806
#
#
# Iteration 160
# Meta Train Error 1.587239757180214
# Meta Train Accuracy 0.23125000530853868
# Meta Valid Error 1.5169182289391756
# Meta Valid Accuracy 0.3687500082887709
#
#
# Iteration 164
# Meta Train Error 1.5620016567409039
# Meta Train Accuracy 0.3187500066123903
# Meta Valid Error 1.5899999886751175
# Meta Valid Accuracy 0.2687500063329935
#
#
# Iteration 168
# Meta Train Error 1.517748262733221
# Meta Train Accuracy 0.3750000079162419
# Meta Valid Error 1.5234673395752907
# Meta Valid Accuracy 0.31875000707805157
#
#
# Iteration 172
# Meta Train Error 1.5367825776338577
# Meta Train Accuracy 0.31250000605359674
# Meta Valid Error 1.5050654336810112
# Meta Valid Accuracy 0.318750006146729
#
#
# Iteration 176
# Meta Train Error 1.4923532158136368
# Meta Train Accuracy 0.31875000847503543
# Meta Valid Error 1.6041095703840256
# Meta Valid Accuracy 0.2500000046566129
#
#
# Iteration 180
# Meta Train Error 1.5207200087606907
# Meta Train Accuracy 0.3312500072643161
# Meta Valid Error 1.5406814068555832
# Meta Valid Accuracy 0.3250000081025064
#
#
# Iteration 184
# Meta Train Error 1.5702009983360767
# Meta Train Accuracy 0.2937500053085387
# Meta Valid Error 1.5207708589732647
# Meta Valid Accuracy 0.3000000063329935
#
#
# Iteration 188
# Meta Train Error 1.5197887495160103
# Meta Train Accuracy 0.34375000838190317
# Meta Valid Error 1.5966628640890121
# Meta Valid Accuracy 0.2750000059604645
#
#
# Iteration 192
# Meta Train Error 1.6664648614823818
# Meta Train Accuracy 0.2312500048428774
# Meta Valid Error 1.5581374783068895
# Meta Valid Accuracy 0.31875000707805157
#
#
# Iteration 196
# Meta Train Error 1.5052326805889606
# Meta Train Accuracy 0.36875001015141606
# Meta Valid Error 1.5465709418058395
# Meta Valid Accuracy 0.33125000772997737
# Iteration 200
# Meta Train Error 1.5387386344373226
# Meta Train Accuracy 0.36875000689178705
# Meta Valid Error 1.5691822990775108
# Meta Valid Accuracy 0.3187500066123903
#
#
# Iteration 204
# Meta Train Error 1.5291913077235222
# Meta Train Accuracy 0.3750000074505806
# Meta Valid Error 1.4963830970227718
# Meta Valid Accuracy 0.412500012665987
#
#
# Iteration 208
# Meta Train Error 1.5289310812950134
# Meta Train Accuracy 0.30625000642612576
# Meta Valid Error 1.5647390261292458
# Meta Valid Accuracy 0.27500000642612576
#
#
# Iteration 212
# Meta Train Error 1.5275090597569942
# Meta Train Accuracy 0.312500006519258
# Meta Valid Error 1.5951522029936314
# Meta Valid Accuracy 0.25000000558793545
#
#
# Iteration 216
# Meta Train Error 1.5054858513176441
# Meta Train Accuracy 0.33125000819563866
# Meta Valid Error 1.5186665952205658
# Meta Valid Accuracy 0.3562500085681677
#
#
# Iteration 220
# Meta Train Error 1.5324389580637217
# Meta Train Accuracy 0.29375000670552254
# Meta Valid Error 1.5556150749325752
# Meta Valid Accuracy 0.30625000689178705
#
#
# Iteration 224
# Meta Train Error 1.5414412915706635
# Meta Train Accuracy 0.2875000066123903
# Meta Valid Error 1.5226448439061642
# Meta Valid Accuracy 0.30625000642612576
#
#
# Iteration 228
# Meta Train Error 1.5745938457548618
# Meta Train Accuracy 0.2750000050291419
# Meta Valid Error 1.524556715041399
# Meta Valid Accuracy 0.31875000707805157
#
#
# Iteration 232
# Meta Train Error 1.5506896637380123
# Meta Train Accuracy 0.29375000670552254
# Meta Valid Error 1.5628337413072586
# Meta Valid Accuracy 0.3062500054948032
#
#
# Iteration 236
# Meta Train Error 1.506684247404337
# Meta Train Accuracy 0.3187500056810677
# Meta Valid Error 1.5311749279499054
# Meta Valid Accuracy 0.3500000098720193
#
#
# Iteration 240
# Meta Train Error 1.5588145777583122
# Meta Train Accuracy 0.2625000043772161
# Meta Valid Error 1.5563811995089054
# Meta Valid Accuracy 0.33125000912696123
#
#
# Iteration 244
# Meta Train Error 1.4935848750174046
# Meta Train Accuracy 0.3125000074505806
# Meta Valid Error 1.5997662656009197
# Meta Valid Accuracy 0.26875000540167093
#
#
# Iteration 248
# Meta Train Error 1.563647072762251
# Meta Train Accuracy 0.34375000605359674
# Meta Valid Error 1.4717062525451183
# Meta Valid Accuracy 0.3375000078231096
#
#
# Iteration 252
# Meta Train Error 1.5179718546569347
# Meta Train Accuracy 0.287500006146729
# Meta Valid Error 1.5482196919620037
# Meta Valid Accuracy 0.33125000772997737
#
#
# Iteration 256
# Meta Train Error 1.594980739057064
# Meta Train Accuracy 0.2750000054948032
# Meta Valid Error 1.567016862332821
# Meta Valid Accuracy 0.28125000512227416
#
#
# Iteration 260
# Meta Train Error 1.548894889652729
# Meta Train Accuracy 0.2875000066123903
# Meta Valid Error 1.50892848148942
# Meta Valid Accuracy 0.33750000642612576
#
#
# Iteration 264
# Meta Train Error 1.5418045595288277
# Meta Train Accuracy 0.29375000670552254
# Meta Valid Error 1.5883703082799911
# Meta Valid Accuracy 0.28125000558793545
#
#
# Iteration 268
# Meta Train Error 1.5366542786359787
# Meta Train Accuracy 0.31875000754371285
# Meta Valid Error 1.5274715684354305
# Meta Valid Accuracy 0.3250000085681677
#
#
# Iteration 272
# Meta Train Error 1.502472348511219
# Meta Train Accuracy 0.33750000689178705
# Meta Valid Error 1.519058894366026
# Meta Valid Accuracy 0.32500000670552254
#
#
# Iteration 276
# Meta Train Error 1.477909903973341
# Meta Train Accuracy 0.4125000098720193
# Meta Valid Error 1.482333481311798
# Meta Valid Accuracy 0.36250000866129994
#
#
# Iteration 280
# Meta Train Error 1.563351321965456
# Meta Train Accuracy 0.281250006519258
# Meta Valid Error 1.6200720444321632
# Meta Valid Accuracy 0.24375000456348062
#
#
# Iteration 284
# Meta Train Error 1.5263820737600327
# Meta Train Accuracy 0.36250000819563866
# Meta Valid Error 1.5965080633759499
# Meta Valid Accuracy 0.24375000456348062
#
#
# Iteration 288
# Meta Train Error 1.5331476889550686
# Meta Train Accuracy 0.2875000066123903
# Meta Valid Error 1.481062388047576
# Meta Valid Accuracy 0.3250000076368451
#
#
# Iteration 292
# Meta Train Error 1.4555052034556866
# Meta Train Accuracy 0.36875000689178705
# Meta Valid Error 1.5260584950447083
# Meta Valid Accuracy 0.3375000082887709
#
#
# Iteration 296
# Meta Train Error 1.566545631736517
# Meta Train Accuracy 0.31875000800937414
# Meta Valid Error 1.5601548105478287
# Meta Valid Accuracy 0.2625000043772161
#
#
# Iteration 300
# Meta Train Error 1.4831163473427296
# Meta Train Accuracy 0.35000000707805157
# Meta Valid Error 1.5214773416519165
# Meta Valid Accuracy 0.30625000642612576
#
#
# Iteration 304
# Meta Train Error 1.5028988644480705
# Meta Train Accuracy 0.3062500078231096
# Meta Valid Error 1.525615006685257
# Meta Valid Accuracy 0.3437500079162419
#
#
# Iteration 308
# Meta Train Error 1.4753284603357315
# Meta Train Accuracy 0.3250000076368451
# Meta Valid Error 1.5327494591474533
# Meta Valid Accuracy 0.3250000085681677
#
#
# Iteration 312
# Meta Train Error 1.494068879634142
# Meta Train Accuracy 0.3687500078231096
# Meta Valid Error 1.4639283940196037
# Meta Valid Accuracy 0.35000000707805157
#
#
# Iteration 316
# Meta Train Error 1.4896243512630463
# Meta Train Accuracy 0.30000000540167093
# Meta Valid Error 1.5055602192878723
# Meta Valid Accuracy 0.3250000048428774
#
#
# Iteration 320
# Meta Train Error 1.5747713930904865
# Meta Train Accuracy 0.3000000072643161
# Meta Valid Error 1.4945866465568542
# Meta Valid Accuracy 0.40625000838190317
#
#
# Iteration 324
# Meta Train Error 1.4817818962037563
# Meta Train Accuracy 0.3562500076368451
# Meta Valid Error 1.5722411088645458
# Meta Valid Accuracy 0.2875000066123903
#
#
# Iteration 328
# Meta Train Error 1.5167958550155163
# Meta Train Accuracy 0.36250000772997737
# Meta Valid Error 1.5350667722523212
# Meta Valid Accuracy 0.32500000670552254
#
#
# Iteration 332
# Meta Train Error 1.4620290845632553
# Meta Train Accuracy 0.3750000111758709
# Meta Valid Error 1.5535791777074337
# Meta Valid Accuracy 0.3375000078231096
#
#
# Iteration 336
# Meta Train Error 1.4981613270938396
# Meta Train Accuracy 0.33125000912696123
# Meta Valid Error 1.6172427721321583
# Meta Valid Accuracy 0.28125000605359674
#
#
# Iteration 340
# Meta Train Error 1.4629835672676563
# Meta Train Accuracy 0.34375000838190317
# Meta Valid Error 1.5228359624743462
# Meta Valid Accuracy 0.3562500085681677
#
#
# Iteration 344
# Meta Train Error 1.5515743345022202
# Meta Train Accuracy 0.35000000707805157
# Meta Valid Error 1.5996047966182232
# Meta Valid Accuracy 0.25000000605359674
#
#
# Iteration 348
# Meta Train Error 1.5039025358855724
# Meta Train Accuracy 0.3000000067986548
# Meta Valid Error 1.5422851853072643
# Meta Valid Accuracy 0.35625000996515155
#
#
# Iteration 352
# Meta Train Error 1.4881897028535604
# Meta Train Accuracy 0.3500000066123903
# Meta Valid Error 1.4986944608390331
# Meta Valid Accuracy 0.3312500072643161
#
#
# Iteration 356
# Meta Train Error 1.428577397018671
# Meta Train Accuracy 0.4375000116415322
# Meta Valid Error 1.5110802128911018
# Meta Valid Accuracy 0.3312500072643161
#
#
# Iteration 360
# Meta Train Error 1.4744225721806288
# Meta Train Accuracy 0.37500000977888703
# Meta Valid Error 1.505579236894846
# Meta Valid Accuracy 0.31250000512227416
#
#
# Iteration 364
# Meta Train Error 1.461172254756093
# Meta Train Accuracy 0.39375000772997737
# Meta Valid Error 1.5254802145063877
# Meta Valid Accuracy 0.343750006519258
#
#
# Iteration 368
# Meta Train Error 1.5124356523156166
# Meta Train Accuracy 0.35000000707805157
# Meta Valid Error 1.500049788504839
# Meta Valid Accuracy 0.31875000754371285
#
#
# Iteration 372
# Meta Train Error 1.4273321889340878
# Meta Train Accuracy 0.38750000949949026
# Meta Valid Error 1.5156231857836246
# Meta Valid Accuracy 0.312500006519258
#
#
# Iteration 376
# Meta Train Error 1.4633535258471966
# Meta Train Accuracy 0.3750000079162419
# Meta Valid Error 1.5669548623263836
# Meta Valid Accuracy 0.28125000605359674
#
#
# Iteration 380
# Meta Train Error 1.4561235308647156
# Meta Train Accuracy 0.36875000735744834
# Meta Valid Error 1.5792214795947075
# Meta Valid Accuracy 0.31875000800937414
#
#
# Iteration 384
# Meta Train Error 1.4013182446360588
# Meta Train Accuracy 0.4000000096857548
# Meta Valid Error 1.5247402414679527
# Meta Valid Accuracy 0.3250000085681677
#
#
# Iteration 388
# Meta Train Error 1.5993654504418373
# Meta Train Accuracy 0.3250000076368451
# Meta Valid Error 1.5952348373830318
# Meta Valid Accuracy 0.28125000512227416
#
#
# Iteration 392
# Meta Train Error 1.57967159897089
# Meta Train Accuracy 0.2937500053085387
# Meta Valid Error 1.5069196447730064
# Meta Valid Accuracy 0.2750000045634806
#
#
# Iteration 396
# Meta Train Error 1.5526471976190805
# Meta Train Accuracy 0.28125000512227416
# Meta Valid Error 1.5329489670693874
# Meta Valid Accuracy 0.29375000623986125
# Iteration 400
# Meta Train Error 1.565462950617075
# Meta Train Accuracy 0.27500000689178705
# Meta Valid Error 1.5201080366969109
# Meta Valid Accuracy 0.3625000072643161
#
#
# Iteration 404
# Meta Train Error 1.484643343836069
# Meta Train Accuracy 0.36250000819563866
# Meta Valid Error 1.5893443264067173
# Meta Valid Accuracy 0.26875000540167093
#
#
# Iteration 408
# Meta Train Error 1.4135856609791517
# Meta Train Accuracy 0.3625000072643161
# Meta Valid Error 1.5779850855469704
# Meta Valid Accuracy 0.2812500041909516
#
#
# Iteration 412
# Meta Train Error 1.4369971435517073
# Meta Train Accuracy 0.36250000866129994
# Meta Valid Error 1.4783737175166607
# Meta Valid Accuracy 0.3000000063329935
#
#
# Iteration 416
# Meta Train Error 1.4864582940936089
# Meta Train Accuracy 0.3562500071711838
# Meta Valid Error 1.5134857185184956
# Meta Valid Accuracy 0.30000000772997737
#
#
# Iteration 420
# Meta Train Error 1.4513348303735256
# Meta Train Accuracy 0.3562500081025064
# Meta Valid Error 1.5855462960898876
# Meta Valid Accuracy 0.3312500067986548
#
#
# Iteration 424
# Meta Train Error 1.4988823533058167
# Meta Train Accuracy 0.33125000772997737
# Meta Valid Error 1.5753975361585617
# Meta Valid Accuracy 0.30625000642612576
#
#
# Iteration 428
# Meta Train Error 1.5136301591992378
# Meta Train Accuracy 0.343750006519258
# Meta Valid Error 1.4743089601397514
# Meta Valid Accuracy 0.3687500082887709
#
#
# Iteration 432
# Meta Train Error 1.4863316249102354
# Meta Train Accuracy 0.39375000866129994
# Meta Valid Error 1.5087879337370396
# Meta Valid Accuracy 0.3000000058673322
#
#
# Iteration 436
# Meta Train Error 1.4050945397466421
# Meta Train Accuracy 0.418750009033829
# Meta Valid Error 1.5405514352023602
# Meta Valid Accuracy 0.2875000056810677
#
#
# Iteration 440
# Meta Train Error 1.4840583987534046
# Meta Train Accuracy 0.356250009033829
# Meta Valid Error 1.5021508485078812
# Meta Valid Accuracy 0.39375000912696123
#
#
# Iteration 444
# Meta Train Error 1.4243201911449432
# Meta Train Accuracy 0.36250000772997737
# Meta Valid Error 1.486772608011961
# Meta Valid Accuracy 0.34375000558793545
#
#
# Iteration 448
# Meta Train Error 1.5429603308439255
# Meta Train Accuracy 0.33750000735744834
# Meta Valid Error 1.5998314693570137
# Meta Valid Accuracy 0.26250000623986125
#
#
# Iteration 452
# Meta Train Error 1.473968606442213
# Meta Train Accuracy 0.37500000931322575
# Meta Valid Error 1.5889252163469791
# Meta Valid Accuracy 0.25000000558793545
#
#
# Iteration 456
# Meta Train Error 1.477958021685481
# Meta Train Accuracy 0.33750000689178705
# Meta Valid Error 1.5219708289951086
# Meta Valid Accuracy 0.3312500067986548
#
#
# Iteration 460
# Meta Train Error 1.4855876229703426
# Meta Train Accuracy 0.387500009033829
# Meta Valid Error 1.4209279865026474
# Meta Valid Accuracy 0.4062500107102096
#
#
# Iteration 464
# Meta Train Error 1.4597306586802006
# Meta Train Accuracy 0.3250000085681677
# Meta Valid Error 1.587695423513651
# Meta Valid Accuracy 0.2750000059604645
#
#
# Iteration 468
# Meta Train Error 1.5273989960551262
# Meta Train Accuracy 0.3500000098720193
# Meta Valid Error 1.5662471801042557
# Meta Valid Accuracy 0.3062500054948032
#
#
# Iteration 472
# Meta Train Error 1.3776869401335716
# Meta Train Accuracy 0.43750000884756446
# Meta Valid Error 1.444635346531868
# Meta Valid Accuracy 0.35000000707805157
#
#
# Iteration 476
# Meta Train Error 1.4202182237058878
# Meta Train Accuracy 0.37500000838190317
# Meta Valid Error 1.464251585304737
# Meta Valid Accuracy 0.3875000085681677
#
#
# Iteration 480
# Meta Train Error 1.4935836605727673
# Meta Train Accuracy 0.33125000772997737
# Meta Valid Error 1.5198308378458023
# Meta Valid Accuracy 0.31875000800937414
#
#
# Iteration 484
# Meta Train Error 1.571015376597643
# Meta Train Accuracy 0.24375000409781933
# Meta Valid Error 1.5284321196377277
# Meta Valid Accuracy 0.3187500056810677
#
#
# Iteration 488
# Meta Train Error 1.4751833342015743
# Meta Train Accuracy 0.381250009406358
# Meta Valid Error 1.5303477831184864
# Meta Valid Accuracy 0.33125000866129994
#
#
# Iteration 492
# Meta Train Error 1.5128804072737694
# Meta Train Accuracy 0.3312500072643161
# Meta Valid Error 1.5454781465232372
# Meta Valid Accuracy 0.3062500078231096
#
#
# Iteration 496
# Meta Train Error 1.4179141446948051
# Meta Train Accuracy 0.37500000838190317
# Meta Valid Error 1.4933310002088547
# Meta Valid Accuracy 0.3375000082887709
#
#
# Iteration 500
# Meta Train Error 1.4907867200672626
# Meta Train Accuracy 0.3312500063329935
# Meta Valid Error 1.4530964344739914
# Meta Valid Accuracy 0.33125000912696123
#
#
# Iteration 504
# Meta Train Error 1.531803797930479
# Meta Train Accuracy 0.33125000866129994
# Meta Valid Error 1.4459318462759256
# Meta Valid Accuracy 0.39375000819563866
#
#
# Iteration 508
# Meta Train Error 1.5108136273920536
# Meta Train Accuracy 0.33750000642612576
# Meta Valid Error 1.4770717732608318
# Meta Valid Accuracy 0.387500009033829
#
#
# Iteration 512
# Meta Train Error 1.5310727711766958
# Meta Train Accuracy 0.35000000754371285
# Meta Valid Error 1.5538111105561256
# Meta Valid Accuracy 0.30625000689178705
#
#
# Iteration 516
# Meta Train Error 1.4615949373692274
# Meta Train Accuracy 0.3500000089406967
# Meta Valid Error 1.5313004739582539
# Meta Valid Accuracy 0.3687500082887709
#
#
# Iteration 520
# Meta Train Error 1.5379726123064756
# Meta Train Accuracy 0.3125000079162419
# Meta Valid Error 1.5268640331923962
# Meta Valid Accuracy 0.32500000577419996
#
#
# Iteration 524
# Meta Train Error 1.456915631890297
# Meta Train Accuracy 0.36875000735744834
# Meta Valid Error 1.5240988209843636
# Meta Valid Accuracy 0.343750006519258
#
#
# Iteration 528
# Meta Train Error 1.467632219195366
# Meta Train Accuracy 0.36250000866129994
# Meta Valid Error 1.5728516913950443
# Meta Valid Accuracy 0.30625000689178705
#
#
# Iteration 532
# Meta Train Error 1.463507018983364
# Meta Train Accuracy 0.33750000689178705
# Meta Valid Error 1.56014109775424
# Meta Valid Accuracy 0.28125000512227416
#
#
# Iteration 536
# Meta Train Error 1.4993432089686394
# Meta Train Accuracy 0.33750000735744834
# Meta Valid Error 1.5568028576672077
# Meta Valid Accuracy 0.3000000067986548
#
#
# Iteration 540
# Meta Train Error 1.469532985240221
# Meta Train Accuracy 0.356250009033829
# Meta Valid Error 1.4686944633722305
# Meta Valid Accuracy 0.3562500081025064
#
#
# Iteration 544
# Meta Train Error 1.4212201684713364
# Meta Train Accuracy 0.35625000670552254
# Meta Valid Error 1.3868067469447851
# Meta Valid Accuracy 0.37500000884756446
#
#
# Iteration 548
# Meta Train Error 1.4683331213891506
# Meta Train Accuracy 0.33750000735744834
# Meta Valid Error 1.5226391721516848
# Meta Valid Accuracy 0.3375000082887709
#
#
# Iteration 552
# Meta Train Error 1.378565788269043
# Meta Train Accuracy 0.4312500087544322
# Meta Valid Error 1.5003413446247578
# Meta Valid Accuracy 0.3562500081025064
#
#
# Iteration 556
# Meta Train Error 1.4639709554612637
# Meta Train Accuracy 0.36250000819563866
# Meta Valid Error 1.5625357367098331
# Meta Valid Accuracy 0.3000000058673322
#
#
# Iteration 560
# Meta Train Error 1.3929168246686459
# Meta Train Accuracy 0.4000000092200935
# Meta Valid Error 1.4615895822644234
# Meta Valid Accuracy 0.3437500069849193
#
#
# Iteration 564
# Meta Train Error 1.4782766662538052
# Meta Train Accuracy 0.33750000735744834
# Meta Valid Error 1.539164163172245
# Meta Valid Accuracy 0.3000000063329935
#
#
# Iteration 568
# Meta Train Error 1.3639848921447992
# Meta Train Accuracy 0.4062500079162419
# Meta Valid Error 1.573145542293787
# Meta Valid Accuracy 0.3125000069849193
#
#
# Iteration 572
# Meta Train Error 1.3908952604979277
# Meta Train Accuracy 0.40625000884756446
# Meta Valid Error 1.5228827558457851
# Meta Valid Accuracy 0.33750000642612576
#
#
# Iteration 576
# Meta Train Error 1.4599159769713879
# Meta Train Accuracy 0.36875000735744834
# Meta Valid Error 1.5749722309410572
# Meta Valid Accuracy 0.3187500066123903
#
#
# Iteration 580
# Meta Train Error 1.4853291995823383
# Meta Train Accuracy 0.3250000071711838
# Meta Valid Error 1.6177046708762646
# Meta Valid Accuracy 0.2875000066123903
#
#
# Iteration 584
# Meta Train Error 1.464333064854145
# Meta Train Accuracy 0.3000000058673322
# Meta Valid Error 1.5318095721304417
# Meta Valid Accuracy 0.31250000605359674
#
#
# Iteration 588
# Meta Train Error 1.4171952046453953
# Meta Train Accuracy 0.37500000977888703
# Meta Valid Error 1.4934733137488365
# Meta Valid Accuracy 0.3437500069849193
#
#
# Iteration 592
# Meta Train Error 1.4866480380296707
# Meta Train Accuracy 0.3375000054948032
# Meta Valid Error 1.522789429873228
# Meta Valid Accuracy 0.3375000078231096
#
#
# Iteration 596
# Meta Train Error 1.4328939653933048
# Meta Train Accuracy 0.350000009406358
# Meta Valid Error 1.5565682761371136
# Meta Valid Accuracy 0.31875000800937414
# Iteration 600
# Meta Train Error 1.4660748671740294
# Meta Train Accuracy 0.356250009033829
# Meta Valid Error 1.5709236674010754
# Meta Valid Accuracy 0.3062500059604645
#
#
# Iteration 604
# Meta Train Error 1.4399312622845173
# Meta Train Accuracy 0.39375000819563866
# Meta Valid Error 1.5442638508975506
# Meta Valid Accuracy 0.32500000577419996
#
#
# Iteration 608
# Meta Train Error 1.483158752322197
# Meta Train Accuracy 0.3250000071711838
# Meta Valid Error 1.5686802081763744
# Meta Valid Accuracy 0.287500006146729
#
#
# Iteration 612
# Meta Train Error 1.4475794956088066
# Meta Train Accuracy 0.36250000819563866
# Meta Valid Error 1.6079553589224815
# Meta Valid Accuracy 0.26250000623986125
#
#
# Iteration 616
# Meta Train Error 1.502252247184515
# Meta Train Accuracy 0.3562500085681677
# Meta Valid Error 1.5539839528501034
# Meta Valid Accuracy 0.33125000866129994
#
#
# Iteration 620
# Meta Train Error 1.4546268545091152
# Meta Train Accuracy 0.41875001043081284
# Meta Valid Error 1.5804770812392235
# Meta Valid Accuracy 0.23750000400468707
#
#
# Iteration 624
# Meta Train Error 1.4734798539429903
# Meta Train Accuracy 0.38125000707805157
# Meta Valid Error 1.559878945350647
# Meta Valid Accuracy 0.3125000079162419
#
#
# Iteration 628
# Meta Train Error 1.4874884374439716
# Meta Train Accuracy 0.3250000085681677
# Meta Valid Error 1.5538756772875786
# Meta Valid Accuracy 0.36250000866129994
#
#
# Iteration 632
# Meta Train Error 1.4456054344773293
# Meta Train Accuracy 0.38750000949949026
# Meta Valid Error 1.445586621761322
# Meta Valid Accuracy 0.4062500102445483
#
#
# Iteration 636
# Meta Train Error 1.3662821482867002
# Meta Train Accuracy 0.45000000996515155
# Meta Valid Error 1.5315932855010033
# Meta Valid Accuracy 0.3250000081025064
#
#
# Iteration 640
# Meta Train Error 1.455481857061386
# Meta Train Accuracy 0.33125000819563866
# Meta Valid Error 1.4900877475738525
# Meta Valid Accuracy 0.33125000540167093
#
#
# Iteration 644
# Meta Train Error 1.4330133367329836
# Meta Train Accuracy 0.4000000096857548
# Meta Valid Error 1.537493882700801
# Meta Valid Accuracy 0.35000000800937414
#
#
# Iteration 648
# Meta Train Error 1.5196864064782858
# Meta Train Accuracy 0.312500006519258
# Meta Valid Error 1.537933323532343
# Meta Valid Accuracy 0.343750006519258
#
#
# Iteration 652
# Meta Train Error 1.4583941865712404
# Meta Train Accuracy 0.36250000866129994
# Meta Valid Error 1.512308545410633
# Meta Valid Accuracy 0.31875000754371285
#
#
# Iteration 656
# Meta Train Error 1.43118916451931
# Meta Train Accuracy 0.4312500087544322
# Meta Valid Error 1.531602531671524
# Meta Valid Accuracy 0.31250000605359674
#
#
# Iteration 660
# Meta Train Error 1.4956401102244854
# Meta Train Accuracy 0.3312500072643161
# Meta Valid Error 1.5667175240814686
# Meta Valid Accuracy 0.28125000558793545
#
#
# Iteration 664
# Meta Train Error 1.461311200633645
# Meta Train Accuracy 0.3562500081025064
# Meta Valid Error 1.4362627286463976
# Meta Valid Accuracy 0.38750000949949026
#
#
# Iteration 668
# Meta Train Error 1.491500400006771
# Meta Train Accuracy 0.36250000912696123
# Meta Valid Error 1.4666337557137012
# Meta Valid Accuracy 0.3312500072643161
#
#
# Iteration 672
# Meta Train Error 1.3394537456333637
# Meta Train Accuracy 0.41875000949949026
# Meta Valid Error 1.534141581505537
# Meta Valid Accuracy 0.31875000754371285
#
#
# Iteration 676
# Meta Train Error 1.3970977030694485
# Meta Train Accuracy 0.40625000977888703
# Meta Valid Error 1.5709801129996777
# Meta Valid Accuracy 0.3000000063329935
#
#
# Iteration 680
# Meta Train Error 1.3694894835352898
# Meta Train Accuracy 0.38125000800937414
# Meta Valid Error 1.5159168541431427
# Meta Valid Accuracy 0.3437500079162419
#
#
# Iteration 684
# Meta Train Error 1.3241338469088078
# Meta Train Accuracy 0.4562500095926225
# Meta Valid Error 1.4983057416975498
# Meta Valid Accuracy 0.312500006519258
#
#
# Iteration 688
# Meta Train Error 1.4506573770195246
# Meta Train Accuracy 0.39375000819563866
# Meta Valid Error 1.5891566686332226
# Meta Valid Accuracy 0.29375000670552254
#
#
# Iteration 692
# Meta Train Error 1.5209749601781368
# Meta Train Accuracy 0.31875000800937414
# Meta Valid Error 1.3718186486512423
# Meta Valid Accuracy 0.43750000931322575
#
#
# Iteration 696
# Meta Train Error 1.4285285957157612
# Meta Train Accuracy 0.40625000838190317
# Meta Valid Error 1.5085383169353008
# Meta Valid Accuracy 0.3500000066123903
#
#
# Iteration 700
# Meta Train Error 1.3900644984096289
# Meta Train Accuracy 0.44375001080334187
# Meta Valid Error 1.4860707521438599
# Meta Valid Accuracy 0.3375000082887709
#
#
# Iteration 704
# Meta Train Error 1.382708316668868
# Meta Train Accuracy 0.41875000996515155
# Meta Valid Error 1.5193649418652058
# Meta Valid Accuracy 0.3562500081025064
#
#
# Iteration 708
# Meta Train Error 1.3690133579075336
# Meta Train Accuracy 0.412500009406358
# Meta Valid Error 1.5809883810579777
# Meta Valid Accuracy 0.28125000558793545
#
#
# Iteration 712
# Meta Train Error 1.5220526158809662
# Meta Train Accuracy 0.34375000884756446
# Meta Valid Error 1.4154224209487438
# Meta Valid Accuracy 0.43125001061707735
#
#
# Iteration 716
# Meta Train Error 1.4210152067244053
# Meta Train Accuracy 0.387500009033829
# Meta Valid Error 1.5864829886704683
# Meta Valid Accuracy 0.318750006146729
#
#
# Iteration 720
# Meta Train Error 1.53335927054286
# Meta Train Accuracy 0.2875000056810677
# Meta Valid Error 1.5389764439314604
# Meta Valid Accuracy 0.3250000085681677
#
#
# Iteration 724
# Meta Train Error 1.3802599124610424
# Meta Train Accuracy 0.4250000105239451
# Meta Valid Error 1.5515174940228462
# Meta Valid Accuracy 0.287500006146729
#
#
# Iteration 728
# Meta Train Error 1.4185664355754852
# Meta Train Accuracy 0.4000000096857548
# Meta Valid Error 1.533602051436901
# Meta Valid Accuracy 0.3437500074505806
#
#
# Iteration 732
# Meta Train Error 1.378356333822012
# Meta Train Accuracy 0.40625000838190317
# Meta Valid Error 1.5097738727927208
# Meta Valid Accuracy 0.2750000045634806
#
#
# Iteration 736
# Meta Train Error 1.4380951169878244
# Meta Train Accuracy 0.40000000735744834
# Meta Valid Error 1.4657450709491968
# Meta Valid Accuracy 0.3875000081025064
#
#
# Iteration 740
# Meta Train Error 1.4319272954016924
# Meta Train Accuracy 0.3812500103376806
# Meta Valid Error 1.491618424654007
# Meta Valid Accuracy 0.35000000800937414
#
#
# Iteration 744
# Meta Train Error 1.3977265991270542
# Meta Train Accuracy 0.43125001061707735
# Meta Valid Error 1.5702222287654877
# Meta Valid Accuracy 0.33750000689178705
#
#
# Iteration 748
# Meta Train Error 1.412935158237815
# Meta Train Accuracy 0.38125000754371285
# Meta Valid Error 1.4680257588624954
# Meta Valid Accuracy 0.356250009033829
#
#
# Iteration 752
# Meta Train Error 1.2941442094743252
# Meta Train Accuracy 0.5125000132247806
# Meta Valid Error 1.455414256080985
# Meta Valid Accuracy 0.3687500092200935
#
#
# Iteration 756
# Meta Train Error 1.3751562051475048
# Meta Train Accuracy 0.4250000095926225
# Meta Valid Error 1.484712053090334
# Meta Valid Accuracy 0.3375000087544322
#
#
# Iteration 760
# Meta Train Error 1.360425230115652
# Meta Train Accuracy 0.43125001061707735
# Meta Valid Error 1.5336375329643488
# Meta Valid Accuracy 0.3500000066123903
#
#
# Iteration 764
# Meta Train Error 1.448507346212864
# Meta Train Accuracy 0.36250000819563866
# Meta Valid Error 1.5223462507128716
# Meta Valid Accuracy 0.3312500067986548
#
#
# Iteration 768
# Meta Train Error 1.4045270793139935
# Meta Train Accuracy 0.40000001015141606
# Meta Valid Error 1.621436133980751
# Meta Valid Accuracy 0.26250000623986125
#
#
# Iteration 772
# Meta Train Error 1.4227594956755638
# Meta Train Accuracy 0.418750009033829
# Meta Valid Error 1.4684502091258764
# Meta Valid Accuracy 0.38750000949949026
#
#
# Iteration 776
# Meta Train Error 1.3767388053238392
# Meta Train Accuracy 0.42500001145526767
# Meta Valid Error 1.5760741159319878
# Meta Valid Accuracy 0.3000000067986548
#
#
# Iteration 780
# Meta Train Error 1.4040204752236605
# Meta Train Accuracy 0.3750000079162419
# Meta Valid Error 1.5561220832169056
# Meta Valid Accuracy 0.2750000059604645
#
#
# Iteration 784
# Meta Train Error 1.4284241925925016
# Meta Train Accuracy 0.3687500082887709
# Meta Valid Error 1.4382547624409199
# Meta Valid Accuracy 0.38125000800937414
#
#
# Iteration 788
# Meta Train Error 1.4873691406100988
# Meta Train Accuracy 0.3562500085681677
# Meta Valid Error 1.538946621119976
# Meta Valid Accuracy 0.34375000884756446
#
#
# Iteration 792
# Meta Train Error 1.388440653681755
# Meta Train Accuracy 0.41250001080334187
# Meta Valid Error 1.5030003748834133
# Meta Valid Accuracy 0.3562500076368451
#
#
# Iteration 796
# Meta Train Error 1.3741560522466898
# Meta Train Accuracy 0.40625000884756446
# Meta Valid Error 1.5564994551241398
# Meta Valid Accuracy 0.31875000707805157
# Iteration 800
# Meta Train Error 1.490201473236084
# Meta Train Accuracy 0.3875000081025064
# Meta Valid Error 1.486720398068428
# Meta Valid Accuracy 0.3000000067986548
#
#
# Iteration 804
# Meta Train Error 1.4613036010414362
# Meta Train Accuracy 0.3687500087544322
# Meta Valid Error 1.5665568485856056
# Meta Valid Accuracy 0.2937500053085387
#
#
# Iteration 808
# Meta Train Error 1.3763794507831335
# Meta Train Accuracy 0.418750009033829
# Meta Valid Error 1.4843381941318512
# Meta Valid Accuracy 0.35000000847503543
#
#
# Iteration 812
# Meta Train Error 1.3295484893023968
# Meta Train Accuracy 0.4375000102445483
# Meta Valid Error 1.41923239082098
# Meta Valid Accuracy 0.38750001043081284
#
#
# Iteration 816
# Meta Train Error 1.4127493314445019
# Meta Train Accuracy 0.39375000866129994
# Meta Valid Error 1.4984003212302923
# Meta Valid Accuracy 0.3187500066123903
#
#
# Iteration 820
# Meta Train Error 1.3681095745414495
# Meta Train Accuracy 0.4250000095926225
# Meta Valid Error 1.5432269256561995
# Meta Valid Accuracy 0.2937500076368451
#
#
# Iteration 824
# Meta Train Error 1.3140117898583412
# Meta Train Accuracy 0.42500001145526767
# Meta Valid Error 1.5089607052505016
# Meta Valid Accuracy 0.31250000605359674
#
#
# Iteration 828
# Meta Train Error 1.3986485917121172
# Meta Train Accuracy 0.4375000111758709
# Meta Valid Error 1.4929174147546291
# Meta Valid Accuracy 0.3562500071711838
#
#
# Iteration 832
# Meta Train Error 1.3173403888940811
# Meta Train Accuracy 0.4562500133179128
# Meta Valid Error 1.5651934575289488
# Meta Valid Accuracy 0.343750006519258
#
#
# Iteration 836
# Meta Train Error 1.345183840021491
# Meta Train Accuracy 0.42500000912696123
# Meta Valid Error 1.3839171696454287
# Meta Valid Accuracy 0.40625000931322575
#
#
# Iteration 840
# Meta Train Error 1.380358463153243
# Meta Train Accuracy 0.40000001015141606
# Meta Valid Error 1.4539007283747196
# Meta Valid Accuracy 0.3625000072643161
#
#
# Iteration 844
# Meta Train Error 1.3719177395105362
# Meta Train Accuracy 0.4062500107102096
# Meta Valid Error 1.4798067416995764
# Meta Valid Accuracy 0.3437500079162419
#
#
# Iteration 848
# Meta Train Error 1.5276865065097809
# Meta Train Accuracy 0.34375000884756446
# Meta Valid Error 1.4719704240560532
# Meta Valid Accuracy 0.40000001108273864
#
#
# Iteration 852
# Meta Train Error 1.472981572151184
# Meta Train Accuracy 0.39375000912696123
# Meta Valid Error 1.4018552377820015
# Meta Valid Accuracy 0.4000000115483999
#
#
# Iteration 856
# Meta Train Error 1.5125031135976315
# Meta Train Accuracy 0.35625000623986125
# Meta Valid Error 1.4733392763882875
# Meta Valid Accuracy 0.34375000838190317
#
#
# Iteration 860
# Meta Train Error 1.3846881818026304
# Meta Train Accuracy 0.42500000772997737
# Meta Valid Error 1.4776141960173845
# Meta Valid Accuracy 0.37500000884756446
#
#
# Iteration 864
# Meta Train Error 1.4856124836951494
# Meta Train Accuracy 0.318750009406358
# Meta Valid Error 1.5196101628243923
# Meta Valid Accuracy 0.31875000754371285
#
#
# Iteration 868
# Meta Train Error 1.4548118244856596
# Meta Train Accuracy 0.38750001043081284
# Meta Valid Error 1.4940417762845755
# Meta Valid Accuracy 0.3312500067986548
#
#
# Iteration 872
# Meta Train Error 1.4297437947243452
# Meta Train Accuracy 0.4000000096857548
# Meta Valid Error 1.4403532724827528
# Meta Valid Accuracy 0.42500000912696123
#
#
# Iteration 876
# Meta Train Error 1.3931196257472038
# Meta Train Accuracy 0.4187500108964741
# Meta Valid Error 1.5316051226109266
# Meta Valid Accuracy 0.31875000800937414
#
#
# Iteration 880
# Meta Train Error 1.3440684080123901
# Meta Train Accuracy 0.4187500118277967
# Meta Valid Error 1.5096965804696083
# Meta Valid Accuracy 0.3062500054948032
#
#
# Iteration 884
# Meta Train Error 1.3367745261639357
# Meta Train Accuracy 0.5062500098720193
# Meta Valid Error 1.4289179742336273
# Meta Valid Accuracy 0.36250000912696123
#
#
# Iteration 888
# Meta Train Error 1.342102874070406
# Meta Train Accuracy 0.43125001015141606
# Meta Valid Error 1.527550395578146
# Meta Valid Accuracy 0.31250000605359674
#
#
# Iteration 892
# Meta Train Error 1.3715184926986694
# Meta Train Accuracy 0.3687500078231096
# Meta Valid Error 1.535193657502532
# Meta Valid Accuracy 0.28750000707805157
#
#
# Iteration 896
# Meta Train Error 1.3244023881852627
# Meta Train Accuracy 0.4312500115483999
# Meta Valid Error 1.5010466389358044
# Meta Valid Accuracy 0.36875000735744834
#
#
# Iteration 900
# Meta Train Error 1.350277142599225
# Meta Train Accuracy 0.4312500115483999
# Meta Valid Error 1.5470114313066006
# Meta Valid Accuracy 0.3125000069849193
#
#
# Iteration 904
# Meta Train Error 1.4629701469093561
# Meta Train Accuracy 0.36875000735744834
# Meta Valid Error 1.5754344817250967
# Meta Valid Accuracy 0.31875000847503543
#
#
# Iteration 908
# Meta Train Error 1.3844695929437876
# Meta Train Accuracy 0.4312500082887709
# Meta Valid Error 1.435859851539135
# Meta Valid Accuracy 0.38750000949949026
#
#
# Iteration 912
# Meta Train Error 1.402952242642641
# Meta Train Accuracy 0.3687500096857548
# Meta Valid Error 1.544967494904995
# Meta Valid Accuracy 0.30625000642612576
#
#
# Iteration 916
# Meta Train Error 1.4118596985936165
# Meta Train Accuracy 0.37500000884756446
# Meta Valid Error 1.4252414982765913
# Meta Valid Accuracy 0.4000000082887709
#
#
# Iteration 920
# Meta Train Error 1.4415323194116354
# Meta Train Accuracy 0.39375000912696123
# Meta Valid Error 1.4865162745118141
# Meta Valid Accuracy 0.32500000577419996
#
#
# Iteration 924
# Meta Train Error 1.368928473442793
# Meta Train Accuracy 0.4500000118277967
# Meta Valid Error 1.5135555639863014
# Meta Valid Accuracy 0.3250000071711838
#
#
# Iteration 928
# Meta Train Error 1.409672997891903
# Meta Train Accuracy 0.38125000847503543
# Meta Valid Error 1.5150348544120789
# Meta Valid Accuracy 0.34375000884756446
#
#
# Iteration 932
# Meta Train Error 1.3817490711808205
# Meta Train Accuracy 0.4312500092200935
# Meta Valid Error 1.434769643470645
# Meta Valid Accuracy 0.3937500100582838
#
#
# Iteration 936
# Meta Train Error 1.3929172959178686
# Meta Train Accuracy 0.4312500082887709
# Meta Valid Error 1.4936375487595797
# Meta Valid Accuracy 0.34375000605359674
#
#
# Iteration 940
# Meta Train Error 1.4425122402608395
# Meta Train Accuracy 0.3687500082887709
# Meta Valid Error 1.4327251464128494
# Meta Valid Accuracy 0.381250009406358
#
#
# Iteration 944
# Meta Train Error 1.4670081157237291
# Meta Train Accuracy 0.38125000754371285
# Meta Valid Error 1.5239503663033247
# Meta Valid Accuracy 0.418750009033829
#
#
# Iteration 948
# Meta Train Error 1.4176504611968994
# Meta Train Accuracy 0.4250000105239451
# Meta Valid Error 1.5400456748902798
# Meta Valid Accuracy 0.35000000707805157
#
#
# Iteration 952
# Meta Train Error 1.4977144319564104
# Meta Train Accuracy 0.3875000081025064
# Meta Valid Error 1.4574265964329243
# Meta Valid Accuracy 0.4187500085681677
#
#
# Iteration 956
# Meta Train Error 1.4549346826970577
# Meta Train Accuracy 0.31875000707805157
# Meta Valid Error 1.6070414334535599
# Meta Valid Accuracy 0.2937500071711838
#
#
# Iteration 960
# Meta Train Error 1.3669626545161009
# Meta Train Accuracy 0.4500000113621354
# Meta Valid Error 1.591518808156252
# Meta Valid Accuracy 0.28125000605359674
#
#
# Iteration 964
# Meta Train Error 1.345611073076725
# Meta Train Accuracy 0.46875000931322575
# Meta Valid Error 1.4192226473242044
# Meta Valid Accuracy 0.3687500078231096
#
#
# Iteration 968
# Meta Train Error 1.3979583289474249
# Meta Train Accuracy 0.3812500089406967
# Meta Valid Error 1.4800553545355797
# Meta Valid Accuracy 0.4062500107102096
#
#
# Iteration 972
# Meta Train Error 1.2785584293305874
# Meta Train Accuracy 0.4687500111758709
# Meta Valid Error 1.555228402838111
# Meta Valid Accuracy 0.3125000074505806
#
#
# Iteration 976
# Meta Train Error 1.3391689714044333
# Meta Train Accuracy 0.49375001061707735
# Meta Valid Error 1.44799168035388
# Meta Valid Accuracy 0.37500000884756446
#
#
# Iteration 980
# Meta Train Error 1.4117887914180756
# Meta Train Accuracy 0.42500000819563866
# Meta Valid Error 1.512261739000678
# Meta Valid Accuracy 0.31875000707805157
#
#
# Iteration 984
# Meta Train Error 1.3666889872401953
# Meta Train Accuracy 0.4187500085681677
# Meta Valid Error 1.4993416219949722
# Meta Valid Accuracy 0.3375000082887709
#
#
# Iteration 988
# Meta Train Error 1.401076190173626
# Meta Train Accuracy 0.4187500081025064
# Meta Valid Error 1.4827188607305288
# Meta Valid Accuracy 0.3687500092200935
#
#
# Iteration 992
# Meta Train Error 1.3888475764542818
# Meta Train Accuracy 0.3812500089406967
# Meta Valid Error 1.5198605377227068
# Meta Valid Accuracy 0.38125000800937414
#
#
# Iteration 996
# Meta Train Error 1.4155922122299671
# Meta Train Accuracy 0.40000001015141606
# Meta Valid Error 1.531040532514453
# Meta Valid Accuracy 0.312500006519258
# Iteration 1000
# Meta Train Error 1.423321582376957
# Meta Train Accuracy 0.4125000103376806
# Meta Valid Error 1.4955007787793875
# Meta Valid Accuracy 0.3250000071711838
#
#
# Iteration 1004
# Meta Train Error 1.3704416900873184
# Meta Train Accuracy 0.39375000819563866
# Meta Valid Error 1.470120606943965
# Meta Valid Accuracy 0.3625000072643161
#
#
# Iteration 1008
# Meta Train Error 1.3710524402558804
# Meta Train Accuracy 0.4187500085681677
# Meta Valid Error 1.571662601083517
# Meta Valid Accuracy 0.29375000623986125
#
#
# Iteration 1012
# Meta Train Error 1.4456372540444136
# Meta Train Accuracy 0.3875000076368451
# Meta Valid Error 1.4731985479593277
# Meta Valid Accuracy 0.356250009033829
#
#
# Iteration 1016
# Meta Train Error 1.3420648742467165
# Meta Train Accuracy 0.4375000102445483
# Meta Valid Error 1.4413726925849915
# Meta Valid Accuracy 0.4312500092200935
#
#
# Iteration 1020
# Meta Train Error 1.3216043412685394
# Meta Train Accuracy 0.4437500098720193
# Meta Valid Error 1.3924609944224358
# Meta Valid Accuracy 0.4187500118277967
#
#
# Iteration 1024
# Meta Train Error 1.272642768919468
# Meta Train Accuracy 0.45000001043081284
# Meta Valid Error 1.514660619199276
# Meta Valid Accuracy 0.31250000512227416
#
#
# Iteration 1028
# Meta Train Error 1.460190288722515
# Meta Train Accuracy 0.3687500087544322
# Meta Valid Error 1.5030543394386768
# Meta Valid Accuracy 0.33125000772997737
#
#
# Iteration 1032
# Meta Train Error 1.3561052456498146
# Meta Train Accuracy 0.45000001043081284
# Meta Valid Error 1.4133897013962269
# Meta Valid Accuracy 0.40625000884756446
#
#
# Iteration 1036
# Meta Train Error 1.4284493904560804
# Meta Train Accuracy 0.3437500074505806
# Meta Valid Error 1.481629278510809
# Meta Valid Accuracy 0.3562500085681677
#
#
# Iteration 1040
# Meta Train Error 1.333559898659587
# Meta Train Accuracy 0.44375001173466444
# Meta Valid Error 1.4122874680906534
# Meta Valid Accuracy 0.3812500089406967
#
#
# Iteration 1044
# Meta Train Error 1.3368766028434038
# Meta Train Accuracy 0.4375000107102096
# Meta Valid Error 1.3853301033377647
# Meta Valid Accuracy 0.3937500095926225
#
#
# Iteration 1048
# Meta Train Error 1.3787453602999449
# Meta Train Accuracy 0.4312500096857548
# Meta Valid Error 1.5042378176003695
# Meta Valid Accuracy 0.3000000072643161
#
#
# Iteration 1052
# Meta Train Error 1.4112650156021118
# Meta Train Accuracy 0.38125000707805157
# Meta Valid Error 1.4140383657068014
# Meta Valid Accuracy 0.38750000996515155
#
#
# Iteration 1056
# Meta Train Error 1.3349536582827568
# Meta Train Accuracy 0.4312500092200935
# Meta Valid Error 1.454914154484868
# Meta Valid Accuracy 0.3875000085681677
#
#
# Iteration 1060
# Meta Train Error 1.3095262926071882
# Meta Train Accuracy 0.46875001257285476
# Meta Valid Error 1.3950026910752058
# Meta Valid Accuracy 0.4437500103376806
#
#
# Iteration 1064
# Meta Train Error 1.4085874147713184
# Meta Train Accuracy 0.4812500113621354
# Meta Valid Error 1.5025796927511692
# Meta Valid Accuracy 0.3000000067986548
#
#
# Iteration 1068
# Meta Train Error 1.3301570154726505
# Meta Train Accuracy 0.443750009406358
# Meta Valid Error 1.4712515212595463
# Meta Valid Accuracy 0.39375000912696123
#
#
# Iteration 1072
# Meta Train Error 1.3400840274989605
# Meta Train Accuracy 0.46875000931322575
# Meta Valid Error 1.4632569961249828
# Meta Valid Accuracy 0.38750000949949026
#
#
# Iteration 1076
# Meta Train Error 1.3621142152696848
# Meta Train Accuracy 0.4250000100582838
# Meta Valid Error 1.4167025834321976
# Meta Valid Accuracy 0.418750009033829
#
#
# Iteration 1080
# Meta Train Error 1.3513372298330069
# Meta Train Accuracy 0.45625001238659024
# Meta Valid Error 1.498701523989439
# Meta Valid Accuracy 0.33750000642612576
#
#
# Iteration 1084
# Meta Train Error 1.3180197980254889
# Meta Train Accuracy 0.4250000109896064
# Meta Valid Error 1.5143345817923546
# Meta Valid Accuracy 0.30625000642612576
#
#
# Iteration 1088
# Meta Train Error 1.3667564243078232
# Meta Train Accuracy 0.4250000095926225
# Meta Valid Error 1.4976784884929657
# Meta Valid Accuracy 0.3625000067986548
#
#
# Iteration 1092
# Meta Train Error 1.456437524408102
# Meta Train Accuracy 0.3625000063329935
# Meta Valid Error 1.3908659275621176
# Meta Valid Accuracy 0.4250000095926225
#
#
# Iteration 1096
# Meta Train Error 1.3021801002323627
# Meta Train Accuracy 0.45625001145526767
# Meta Valid Error 1.4212274067103863
# Meta Valid Accuracy 0.3750000079162419
#
#
# Iteration 1100
# Meta Train Error 1.4016456622630358
# Meta Train Accuracy 0.38750000949949026
# Meta Valid Error 1.5852237939834595
# Meta Valid Accuracy 0.28125000558793545
#
#
# Iteration 1104
# Meta Train Error 1.3615539949387312
# Meta Train Accuracy 0.39375000866129994
# Meta Valid Error 1.5477578341960907
# Meta Valid Accuracy 0.3687500078231096
#
#
# Iteration 1108
# Meta Train Error 1.4265809003263712
# Meta Train Accuracy 0.4250000109896064
# Meta Valid Error 1.4766972251236439
# Meta Valid Accuracy 0.3937500105239451
#
#
# Iteration 1112
# Meta Train Error 1.410042269155383
# Meta Train Accuracy 0.38750000949949026
# Meta Valid Error 1.4365964233875275
# Meta Valid Accuracy 0.38750001043081284
#
#
# Iteration 1116
# Meta Train Error 1.2939162123948336
# Meta Train Accuracy 0.4125000089406967
# Meta Valid Error 1.555358411744237
# Meta Valid Accuracy 0.31250000605359674
#
#
# Iteration 1120
# Meta Train Error 1.3041666094213724
# Meta Train Accuracy 0.4812500113621354
# Meta Valid Error 1.5994587317109108
# Meta Valid Accuracy 0.29375000670552254
#
#
# Iteration 1124
# Meta Train Error 1.3542530704289675
# Meta Train Accuracy 0.4312500092200935
# Meta Valid Error 1.5055136922746897
# Meta Valid Accuracy 0.40000000735744834
#
#
# Iteration 1128
# Meta Train Error 1.3570938352495432
# Meta Train Accuracy 0.4250000095926225
# Meta Valid Error 1.4710654690861702
# Meta Valid Accuracy 0.3812500089406967
#
#
# Iteration 1132
# Meta Train Error 1.2841916400939226
# Meta Train Accuracy 0.5000000111758709
# Meta Valid Error 1.61334159784019
# Meta Valid Accuracy 0.3250000076368451
#
#
# Iteration 1136
# Meta Train Error 1.420703537762165
# Meta Train Accuracy 0.3875000081025064
# Meta Valid Error 1.619822010397911
# Meta Valid Accuracy 0.28125000558793545
#
#
# Iteration 1140
# Meta Train Error 1.2584272902458906
# Meta Train Accuracy 0.45625000912696123
# Meta Valid Error 1.4708255305886269
# Meta Valid Accuracy 0.3687500082887709
#
#
# Iteration 1144
# Meta Train Error 1.3452283702790737
# Meta Train Accuracy 0.4187500108964741
# Meta Valid Error 1.498480200767517
# Meta Valid Accuracy 0.32500000670552254
#
#
# Iteration 1148
# Meta Train Error 1.2271652445197105
# Meta Train Accuracy 0.537500012665987
# Meta Valid Error 1.4564491100609303
# Meta Valid Accuracy 0.40625000931322575
#
#
# Iteration 1152
# Meta Train Error 1.4460455104708672
# Meta Train Accuracy 0.4125000103376806
# ...
# Meta Valid Error 1.3333369102329016
# Meta Valid Accuracy 0.4250000109896064
#
#
# Iteration 12352
# Meta Train Error 1.0592087237164378
# Meta Train Accuracy 0.6437500123865902
# Meta Valid Error 1.4289624895900488
# Meta Valid Accuracy 0.4250000100582838
#
#
# Iteration 12356
# Meta Train Error 1.0290087386965752
# Meta Train Accuracy 0.612500015180558
# Meta Valid Error 1.4270944967865944
# Meta Valid Accuracy 0.4250000100582838
#
#
# Iteration 12360
# Meta Train Error 0.9827834367752075
# Meta Train Accuracy 0.6375000108964741
# Meta Valid Error 1.2935026679188013
# Meta Valid Accuracy 0.4687500116415322
#
#
# Iteration 12364
# Meta Train Error 1.017598737962544
# Meta Train Accuracy 0.5812500137835741
# Meta Valid Error 1.2590135987848043
# Meta Valid Accuracy 0.5062500108033419
#
#
# Iteration 12368
# Meta Train Error 1.1961615066975355
# Meta Train Accuracy 0.4812500113621354
# Meta Valid Error 1.3571826312690973
# Meta Valid Accuracy 0.45000001275911927
#
#
# Iteration 12372
# Meta Train Error 1.0965383611619473
# Meta Train Accuracy 0.5312500121071935
# Meta Valid Error 1.2982432134449482
# Meta Valid Accuracy 0.49375001015141606
#
#
# Iteration 12376
# Meta Train Error 1.071945421397686
# Meta Train Accuracy 0.5437500141561031
# Meta Valid Error 1.2209465438500047
# Meta Valid Accuracy 0.4937500120140612
#
#
# Iteration 12380
# Meta Train Error 1.0521926926448941
# Meta Train Accuracy 0.5562500120140612
# Meta Valid Error 1.1533589670434594
# Meta Valid Accuracy 0.5437500108964741
#
#
# Iteration 12384
# Meta Train Error 1.1274274233728647
# Meta Train Accuracy 0.5500000133179128
# Meta Valid Error 1.3123166766017675
# Meta Valid Accuracy 0.5250000106170774
#
#
# Iteration 12388
# Meta Train Error 1.1308702733367682
# Meta Train Accuracy 0.5437500136904418
# Meta Valid Error 1.4242141749709845
# Meta Valid Accuracy 0.3937500105239451
#
#
# Iteration 12392
# Meta Train Error 1.114574917824939
# Meta Train Accuracy 0.5375000135973096
# Meta Valid Error 1.4183632638305426
# Meta Valid Accuracy 0.3937500095926225
#
#
# Iteration 12396
# Meta Train Error 0.9519895585253835
# Meta Train Accuracy 0.6062500113621354
# Meta Valid Error 1.3436098378151655
# Meta Valid Accuracy 0.4375000111758709
#
#
# Iteration 12400
# Meta Train Error 1.0308092320337892
# Meta Train Accuracy 0.5875000134110451
# Meta Valid Error 1.2240441273897886
# Meta Valid Accuracy 0.46250001061707735
#
#
# Iteration 12404
# Meta Train Error 1.1349161192774773
# Meta Train Accuracy 0.5250000124797225
# Meta Valid Error 1.3506566099822521
# Meta Valid Accuracy 0.41875000996515155
#
#
# Iteration 12408
# Meta Train Error 0.9755843821913004
# Meta Train Accuracy 0.6000000122003257
# Meta Valid Error 1.2116292491555214
# Meta Valid Accuracy 0.48750001285225153
#
#
# Iteration 12412
# Meta Train Error 1.0569030325859785
# Meta Train Accuracy 0.5812500114552677
# Meta Valid Error 1.324522016569972
# Meta Valid Accuracy 0.4312500092200935
#
#
# Iteration 12416
# Meta Train Error 0.9981029257178307
# Meta Train Accuracy 0.562500013038516
# Meta Valid Error 1.2232536356896162
# Meta Valid Accuracy 0.5187500109896064
#
#
# Iteration 12420
# Meta Train Error 1.039655332453549
# Meta Train Accuracy 0.5750000146217644
# Meta Valid Error 1.2587622720748186
# Meta Valid Accuracy 0.4875000137835741
#
#
# Iteration 12424
# Meta Train Error 1.0734291076660156
# Meta Train Accuracy 0.5750000108964741
# Meta Valid Error 1.2192361541092396
# Meta Valid Accuracy 0.506250012665987
#
#
# Iteration 12428
# Meta Train Error 0.9627433884888887
# Meta Train Accuracy 0.6187500120140612
# Meta Valid Error 1.3627007473260164
# Meta Valid Accuracy 0.4312500096857548
#
#
# Iteration 12432
# Meta Train Error 1.1536109754815698
# Meta Train Accuracy 0.531250013038516
# Meta Valid Error 1.262451377697289
# Meta Valid Accuracy 0.4937500096857548
#
#
# Iteration 12436
# Meta Train Error 1.053335988894105
# Meta Train Accuracy 0.5687500131316483
# Meta Valid Error 1.287212062627077
# Meta Valid Accuracy 0.5000000121071935
#
#
# Iteration 12440
# Meta Train Error 1.0973945977166295
# Meta Train Accuracy 0.5500000109896064
# Meta Valid Error 1.2858918271958828
# Meta Valid Accuracy 0.47500001080334187
#
#
# Iteration 12444
# Meta Train Error 1.1697274865582585
# Meta Train Accuracy 0.5312500093132257
# Meta Valid Error 1.2935326742008328
# Meta Valid Accuracy 0.48750001145526767
#
#
# Iteration 12448
# Meta Train Error 1.07193737430498
# Meta Train Accuracy 0.5750000094994903
# Meta Valid Error 1.2834303444251418
# Meta Valid Accuracy 0.4812500118277967
#
#
# Iteration 12452
# Meta Train Error 1.00183002371341
# Meta Train Accuracy 0.6125000142492354
# Meta Valid Error 1.342176390811801
# Meta Valid Accuracy 0.41875000949949026
#
#
# Iteration 12456
# Meta Train Error 1.0606942493468523
# Meta Train Accuracy 0.5812500147148967
# Meta Valid Error 1.205439643934369
# Meta Valid Accuracy 0.4875000095926225
#
#
# Iteration 12460
# Meta Train Error 1.1772940149530768
# Meta Train Accuracy 0.5687500145286322
# Meta Valid Error 1.1634246986359358
# Meta Valid Accuracy 0.5312500139698386
#
#
# Iteration 12464
# Meta Train Error 1.1864319536834955
# Meta Train Accuracy 0.5187500137835741
# Meta Valid Error 1.355994625017047
# Meta Valid Accuracy 0.44375001126900315
#
#
# Iteration 12468
# Meta Train Error 0.9308365946635604
# Meta Train Accuracy 0.5875000129453838
# Meta Valid Error 1.3135722428560257
# Meta Valid Accuracy 0.4375000107102096
#
#
# Iteration 12472
# Meta Train Error 1.015365781262517
# Meta Train Accuracy 0.6062500146217644
# Meta Valid Error 1.2978656738996506
# Meta Valid Accuracy 0.4187500108964741
#
#
# Iteration 12476
# Meta Train Error 1.0287979040294886
# Meta Train Accuracy 0.5750000136904418
# Meta Valid Error 1.3401278834789991
# Meta Valid Accuracy 0.45625000866129994
#
#
# Iteration 12480
# Meta Train Error 1.0781072899699211
# Meta Train Accuracy 0.5750000146217644
# Meta Valid Error 1.3080676086246967
# Meta Valid Accuracy 0.5187500109896064
#
#
# Iteration 12484
# Meta Train Error 1.0584956491366029
# Meta Train Accuracy 0.5625000135041773
# Meta Valid Error 1.293387952260673
# Meta Valid Accuracy 0.5125000113621354
#
#
# Iteration 12488
# Meta Train Error 1.1301713231950998
# Meta Train Accuracy 0.5750000118277967
# Meta Valid Error 1.3633854128420353
# Meta Valid Accuracy 0.44375001126900315
#
#
# Iteration 12492
# Meta Train Error 1.0216864198446274
# Meta Train Accuracy 0.562500013038516
# Meta Valid Error 1.2453249655663967
# Meta Valid Accuracy 0.5125000132247806
#
#
# Iteration 12496
# Meta Train Error 1.0888113649562001
# Meta Train Accuracy 0.5437500118277967
# Meta Valid Error 1.1671575866639614
# Meta Valid Accuracy 0.5250000115483999
#
#
# Iteration 12500
# Meta Train Error 1.0265335068106651
# Meta Train Accuracy 0.5625000121071935
# Meta Valid Error 1.3353756740689278
# Meta Valid Accuracy 0.4687500111758709
#
#
# Iteration 12504
# Meta Train Error 0.9479657895863056
# Meta Train Accuracy 0.6187500129453838
# Meta Valid Error 1.3357344083487988
# Meta Valid Accuracy 0.44375001080334187
#
#
# Iteration 12508
# Meta Train Error 1.1015396267175674
# Meta Train Accuracy 0.5562500134110451
# Meta Valid Error 1.351147448644042
# Meta Valid Accuracy 0.4125000089406967
#
#
# Iteration 12512
# Meta Train Error 1.1348132733255625
# Meta Train Accuracy 0.531250013038516
# Meta Valid Error 1.3045857679098845
# Meta Valid Accuracy 0.4687500111758709
#
#
# Iteration 12516
# Meta Train Error 1.0667138006538153
# Meta Train Accuracy 0.575000012293458
# Meta Valid Error 1.2832061080262065
# Meta Valid Accuracy 0.4500000118277967
#
#
# Iteration 12520
# Meta Train Error 1.1053983448073268
# Meta Train Accuracy 0.5375000140629709
# Meta Valid Error 1.2315720105543733
# Meta Valid Accuracy 0.5125000104308128
#
#
# Iteration 12524
# Meta Train Error 1.0802817111834884
# Meta Train Accuracy 0.5625000107102096
# Meta Valid Error 1.2270871102809906
# Meta Valid Accuracy 0.5187500128522515
#
#
# Iteration 12528
# Meta Train Error 0.9988131327554584
# Meta Train Accuracy 0.5937500121071935
# Meta Valid Error 1.2908234056085348
# Meta Valid Accuracy 0.47500001126900315
#
#
# Iteration 12532
# Meta Train Error 1.0491200489923358
# Meta Train Accuracy 0.575000012293458
# Meta Valid Error 1.2847736990079284
# Meta Valid Accuracy 0.5000000111758709
#
#
# Iteration 12536
# Meta Train Error 1.1143320240080357
# Meta Train Accuracy 0.5687500122003257
# Meta Valid Error 1.3592364098876715
# Meta Valid Accuracy 0.4125000098720193
# Iteration 12540
# Meta Train Error 0.9736001673154533
# Meta Train Accuracy 0.6250000125728548
# Meta Valid Error 1.3360531404614449
# Meta Valid Accuracy 0.4750000122003257
#
#
# Iteration 12544
# Meta Train Error 1.1311631202697754
# Meta Train Accuracy 0.5000000139698386
# Meta Valid Error 1.2431123480200768
# Meta Valid Accuracy 0.5187500137835741
#
#
# Iteration 12548
# Meta Train Error 0.9387551862746477
# Meta Train Accuracy 0.6437500128522515
# Meta Valid Error 1.4580290578305721
# Meta Valid Accuracy 0.37500000931322575
#
#
# Iteration 12552
# Meta Train Error 1.0602798257023096
# Meta Train Accuracy 0.5375000135973096
# Meta Valid Error 1.3484254907816648
# Meta Valid Accuracy 0.4437500089406967
#
#
# Iteration 12556
# Meta Train Error 0.9106925437226892
# Meta Train Accuracy 0.6312500117346644
# Meta Valid Error 1.2424701154232025
# Meta Valid Accuracy 0.4500000081025064
#
#
# Iteration 12560
# Meta Train Error 1.0430607716552913
# Meta Train Accuracy 0.5812500147148967
# Meta Valid Error 1.2784913647919893
# Meta Valid Accuracy 0.49375001108273864
#
#
# Iteration 12564
# Meta Train Error 1.027350359596312
# Meta Train Accuracy 0.5875000120140612
# Meta Valid Error 1.383528952486813
# Meta Valid Accuracy 0.3937500095926225
#
#
# Iteration 12568
# Meta Train Error 1.097613331861794
# Meta Train Accuracy 0.543750012293458
# Meta Valid Error 1.2187288906425238
# Meta Valid Accuracy 0.5437500132247806
#
#
# Iteration 12572
# Meta Train Error 1.0678759925067425
# Meta Train Accuracy 0.5875000115483999
# Meta Valid Error 1.3470167387276888
# Meta Valid Accuracy 0.45000000996515155
#
#
# Iteration 12576
# Meta Train Error 0.9005495952442288
# Meta Train Accuracy 0.6312500149942935
# Meta Valid Error 1.3325577098876238
# Meta Valid Accuracy 0.4437500098720193
#
#
# Iteration 12580
# Meta Train Error 1.0795812346041203
# Meta Train Accuracy 0.550000011920929
# Meta Valid Error 1.2488867361098528
# Meta Valid Accuracy 0.49375001108273864
#
#
# Iteration 12584
# Meta Train Error 0.9885471798479557
# Meta Train Accuracy 0.6187500143423676
# Meta Valid Error 1.1787959784269333
# Meta Valid Accuracy 0.5000000107102096
#
#
# Iteration 12588
# Meta Train Error 1.0685034394264221
# Meta Train Accuracy 0.5812500114552677
# Meta Valid Error 1.240010623820126
# Meta Valid Accuracy 0.46875000977888703
#
#
# Iteration 12592
# Meta Train Error 1.0550877172499895
# Meta Train Accuracy 0.6000000131316483
# Meta Valid Error 1.2129740566015244
# Meta Valid Accuracy 0.4875000109896064
#
#
# Iteration 12596
# Meta Train Error 1.0848807394504547
# Meta Train Accuracy 0.5500000114552677
# Meta Valid Error 1.214142482727766
# Meta Valid Accuracy 0.5187500086612999
#
#
# Iteration 12600
# Meta Train Error 1.021393901668489
# Meta Train Accuracy 0.5750000113621354
# Meta Valid Error 1.315164165571332
# Meta Valid Accuracy 0.46250001108273864
#
#
# Iteration 12604
# Meta Train Error 1.135033456608653
# Meta Train Accuracy 0.5625000139698386
# Meta Valid Error 1.2844571210443974
# Meta Valid Accuracy 0.47500001080334187
#
#
# Iteration 12608
# Meta Train Error 0.895404752343893
# Meta Train Accuracy 0.6437500133179128
# Meta Valid Error 1.2737722769379616
# Meta Valid Accuracy 0.4625000124797225
#
#
# Iteration 12612
# Meta Train Error 0.9924787976779044
# Meta Train Accuracy 0.5937500121071935
# Meta Valid Error 1.333613345399499
# Meta Valid Accuracy 0.4937500124797225
#
#
# Iteration 12616
# Meta Train Error 1.1101689105853438
# Meta Train Accuracy 0.5562500148080289
# Meta Valid Error 1.4043286945670843
# Meta Valid Accuracy 0.4312500092200935
#
#
# Iteration 12620
# Meta Train Error 1.0116368541494012
# Meta Train Accuracy 0.6187500092200935
# Meta Valid Error 1.359858026728034
# Meta Valid Accuracy 0.4187500108964741
#
#
# Iteration 12624
# Meta Train Error 0.9906648774631321
# Meta Train Accuracy 0.5937500144354999
# Meta Valid Error 1.247298251837492
# Meta Valid Accuracy 0.46875001257285476
#
#
# Iteration 12628
# Meta Train Error 1.0941954646259546
# Meta Train Accuracy 0.5625000125728548
# Meta Valid Error 1.3729829285293818
# Meta Valid Accuracy 0.4187500108964741
#
#
# Iteration 12632
# Meta Train Error 1.1297578616067767
# Meta Train Accuracy 0.5250000115483999
# Meta Valid Error 1.3472508089616895
# Meta Valid Accuracy 0.4687500107102096
#
#
# Iteration 12636
# Meta Train Error 0.965932990424335
# Meta Train Accuracy 0.5937500116415322
# Meta Valid Error 1.2517743594944477
# Meta Valid Accuracy 0.47500001080334187
#
#
# Iteration 12640
# Meta Train Error 0.9993901993148029
# Meta Train Accuracy 0.6000000117346644
# Meta Valid Error 1.2385484110563993
# Meta Valid Accuracy 0.5250000096857548
#
#
# Iteration 12644
# Meta Train Error 1.1100411303341389
# Meta Train Accuracy 0.5625000125728548
# Meta Valid Error 1.337474139407277
# Meta Valid Accuracy 0.4750000098720193
#
#
# Iteration 12648
# Meta Train Error 1.0109424330294132
# Meta Train Accuracy 0.581250011920929
# Meta Valid Error 1.3167039286345243
# Meta Valid Accuracy 0.4437500103376806
#
#
# Iteration 12652
# Meta Train Error 1.030171203892678
# Meta Train Accuracy 0.6125000086612999
# Meta Valid Error 1.2937482949346304
# Meta Valid Accuracy 0.4562500105239451
#
#
# Iteration 12656
# Meta Train Error 1.0037479400634766
# Meta Train Accuracy 0.5625000125728548
# Meta Valid Error 1.2062763422727585
# Meta Valid Accuracy 0.4562500109896064
#
#
# Iteration 12660
# Meta Train Error 1.057441795244813
# Meta Train Accuracy 0.6125000123865902
# Meta Valid Error 1.3605543207377195
# Meta Valid Accuracy 0.450000009033829
#
#
# Iteration 12664
# Meta Train Error 0.9802489187568426
# Meta Train Accuracy 0.6375000113621354
# Meta Valid Error 1.285103689879179
# Meta Valid Accuracy 0.512500015553087
#
#
# Iteration 12668
# Meta Train Error 0.9955280302092433
# Meta Train Accuracy 0.5750000127591193
# Meta Valid Error 1.2786395214498043
# Meta Valid Accuracy 0.506250012665987
#
#
# Iteration 12672
# Meta Train Error 1.1032138485461473
# Meta Train Accuracy 0.543750012293458
# Meta Valid Error 1.294071426615119
# Meta Valid Accuracy 0.4625000096857548
#
#
# Iteration 12676
# Meta Train Error 0.9976323628798127
# Meta Train Accuracy 0.6125000137835741
# Meta Valid Error 1.290882345288992
# Meta Valid Accuracy 0.45625001192092896
#
#
# Iteration 12680
# Meta Train Error 1.1221908805891871
# Meta Train Accuracy 0.543750012293458
# Meta Valid Error 1.3306321240961552
# Meta Valid Accuracy 0.4250000105239451
#
#
# Iteration 12684
# Meta Train Error 0.9785783444531262
# Meta Train Accuracy 0.6000000089406967
# Meta Valid Error 1.284769942983985
# Meta Valid Accuracy 0.43125001015141606
#
#
# Iteration 12688
# Meta Train Error 1.006070161703974
# Meta Train Accuracy 0.5875000120140612
# Meta Valid Error 1.1806865436956286
# Meta Valid Accuracy 0.5125000118277967
#
#
# Iteration 12692
# Meta Train Error 1.0728616872802377
# Meta Train Accuracy 0.5937500139698386
# Meta Valid Error 1.2884393390268087
# Meta Valid Accuracy 0.44375001126900315
#
#
# Iteration 12696
# Meta Train Error 1.0004724357277155
# Meta Train Accuracy 0.6062500127591193
# Meta Valid Error 1.3364681284874678
# Meta Valid Accuracy 0.4187500108964741
#
#
# Iteration 12700
# Meta Train Error 1.1323681576177478
# Meta Train Accuracy 0.531250013038516
# Meta Valid Error 1.269529509358108
# Meta Valid Accuracy 0.46875001210719347
#
#
# Iteration 12704
# Meta Train Error 0.911583298817277
# Meta Train Accuracy 0.6250000125728548
# Meta Valid Error 1.2858918122947216
# Meta Valid Accuracy 0.44375001126900315
#
#
# Iteration 12708
# Meta Train Error 1.0314256974961609
# Meta Train Accuracy 0.6062500118277967
# Meta Valid Error 1.3449214287102222
# Meta Valid Accuracy 0.40625000931322575
#
#
# Iteration 12712
# Meta Train Error 1.0704765669070184
# Meta Train Accuracy 0.5937500111758709
# Meta Valid Error 1.3517488315701485
# Meta Valid Accuracy 0.43750000884756446
#
#
# Iteration 12716
# Meta Train Error 0.9941381067037582
# Meta Train Accuracy 0.6125000114552677
# Meta Valid Error 1.2349570710211992
# Meta Valid Accuracy 0.5250000096857548
#
#
# Iteration 12720
# Meta Train Error 1.121620905585587
# Meta Train Accuracy 0.5812500123865902
# Meta Valid Error 1.3336871732026339
# Meta Valid Accuracy 0.475000009406358
#
#
# Iteration 12724
# Meta Train Error 1.000191311351955
# Meta Train Accuracy 0.5812500128522515
# Meta Valid Error 1.321927448734641
# Meta Valid Accuracy 0.4750000089406967
#
#
# Iteration 12728
# Meta Train Error 1.145307619124651
# Meta Train Accuracy 0.5250000120140612
# Meta Valid Error 1.3318762630224228
# Meta Valid Accuracy 0.4437500089406967
