# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
# For mutliple devices (GPUs: 4, 5, 6, 7)
os.environ["CUDA_VISIBLE_DEVICES"] = "7"

# %%
#!/usr/bin/env python3

"""
Demonstrates how to:
    * use the MAML wrapper for fast-adaptation,
    * use the benchmark interface to load mini-ImageNet, and
    * sample tasks and split them in adaptation and evaluation sets.

To contrast the use of the benchmark interface with directly instantiating mini-ImageNet datasets and tasks, compare with `protonet_miniimagenet.py`.
"""

import random
import numpy as np

import torch
from torch import nn, optim
import matplotlib.pyplot as plt
import learn2learn as l2l
from learn2learn.data.transforms import (NWays,
                                         KShots,
                                         LoadData,
                                         RemapLabels,
                                         ConsecutiveLabels)
import os
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /home/khanhi83/anaconda3/envs/PY3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
def accuracy(predictions, targets):
    predictions = predictions.argmax(dim=1).view(targets.shape)
    return (predictions == targets).sum().float() / targets.size(0)


def fast_adapt(batch, learner, loss, adaptation_steps, shots, ways, device):
    data, labels = batch
    data, labels = data.to(device), labels.to(device)

    # Separate data into adaptation/evalutation sets
    adaptation_indices = np.zeros(data.size(0), dtype=bool)
    adaptation_indices[np.arange(shots*ways) * 2] = True
    evaluation_indices = torch.from_numpy(~adaptation_indices)
    adaptation_indices = torch.from_numpy(adaptation_indices)
    adaptation_data, adaptation_labels = data[adaptation_indices], labels[adaptation_indices]
    evaluation_data, evaluation_labels = data[evaluation_indices], labels[evaluation_indices]

    # Adapt the model
    for step in range(adaptation_steps):
        adaptation_error = loss(learner(adaptation_data), adaptation_labels)
        learner.adapt(adaptation_error)

    # Evaluate the adapted model
    predictions = learner(evaluation_data)
    evaluation_error = loss(predictions, evaluation_labels)
    evaluation_accuracy = accuracy(predictions, evaluation_labels)
    return evaluation_error, evaluation_accuracy


def perform_experiment(dataset,
        ways=5,
        shots=5,
        meta_lr=0.003,
        fast_lr=0.5,
        meta_batch_size=32,
        adaptation_steps=1,
        num_iterations=60000,
        cuda=True,
        seed=42,
):
    
    Meta_Train_Accuracy = []
    Meta_Train_Error = []
    Meta_Val_Accuracy = []
    Meta_Val_Error = []
#     Iterations = []
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    device = torch.device('cpu')
    if cuda and torch.cuda.device_count():
        torch.cuda.manual_seed(seed)
        device = torch.device('cuda')

    # Create Tasksets using the benchmark interface
    tasksets = l2l.vision.benchmarks.get_tasksets(dataset,
                                                  train_samples=2*shots,
                                                  train_ways=ways,
                                                  test_samples=2*shots,
                                                  test_ways=ways,
                                                  root='~/data',
    )

    # Create model
    model = l2l.vision.models.MiniImagenetCNN(ways)
    model.to(device)
    maml = l2l.algorithms.MAML(model, lr=fast_lr, first_order=False)
    opt = optim.Adam(maml.parameters(), meta_lr)
    loss = nn.CrossEntropyLoss(reduction='mean')

    for iteration in range(num_iterations):
        opt.zero_grad()
        meta_train_error = 0.0
        meta_train_accuracy = 0.0
        meta_valid_error = 0.0
        meta_valid_accuracy = 0.0
        for task in range(meta_batch_size):
            # Compute meta-training loss
            learner = maml.clone()
            batch = tasksets.train.sample()
            evaluation_error, evaluation_accuracy = fast_adapt(batch,
                                                               learner,
                                                               loss,
                                                               adaptation_steps,
                                                               shots,
                                                               ways,
                                                               device)
            evaluation_error.backward()
            meta_train_error += evaluation_error.item()
            meta_train_accuracy += evaluation_accuracy.item()

            # Compute meta-validation loss
            learner = maml.clone()
            batch = tasksets.validation.sample()
            evaluation_error, evaluation_accuracy = fast_adapt(batch,
                                                               learner,
                                                               loss,
                                                               adaptation_steps,
                                                               shots,
                                                               ways,
                                                               device)
            meta_valid_error += evaluation_error.item()
            meta_valid_accuracy += evaluation_accuracy.item()

        # Print some metrics
#         print('\n')
#         print('Iteration', iteration)
#         print('Meta Train Error', meta_train_error / meta_batch_size)
#         print('Meta Train Accuracy', meta_train_accuracy / meta_batch_size)
#         print('Meta Valid Error', meta_valid_error / meta_batch_size)
#         print('Meta Valid Accuracy', meta_valid_accuracy / meta_batch_size)
        
        meta_train_error =  meta_train_error / meta_batch_size
        meta_train_accuracy = meta_train_accuracy / meta_batch_size
        meta_val_error =  meta_valid_error / meta_batch_size
        meta_val_accuracy = meta_valid_accuracy / meta_batch_size
        if(iteration % 32 ==0):
            print('\n')
            print('Iteration', iteration)
            print('Meta Train Error', meta_train_error)
            print('Meta Train Accuracy', meta_train_accuracy)
            print('Meta Valid Error', meta_val_error)
            print('Meta Valid Accuracy', meta_val_accuracy)

        Meta_Train_Accuracy.append(meta_train_accuracy)
        Meta_Train_Error.append(meta_train_error)
        Meta_Val_Accuracy.append(meta_val_accuracy)
        Meta_Val_Error.append(meta_val_error)

        # Average the accumulated gradients and optimize
        for p in maml.parameters():
            p.grad.data.mul_(1.0 / meta_batch_size)
        opt.step()

    meta_test_error = 0.0
    meta_test_accuracy = 0.0
    for task in range(meta_batch_size):
        # Compute meta-testing loss
        learner = maml.clone()
        batch = tasksets.test.sample()
        evaluation_error, evaluation_accuracy = fast_adapt(batch,
                                                           learner,
                                                           loss,
                                                           adaptation_steps,
                                                           shots,
                                                           ways,
                                                           device)
        meta_test_error += evaluation_error.item()
        meta_test_accuracy += evaluation_accuracy.item()
#     print('Meta Test Error', meta_test_error / meta_batch_size)
#     print('Meta Test Accuracy', meta_test_accuracy / meta_batch_size)
    Meta_Test_Error = meta_test_error / meta_batch_size
    print('Meta Test Error', Meta_Test_Error)
    Meta_Test_Accuracy = meta_test_accuracy / meta_batch_size
    print('Meta Test Accuracy', Meta_Test_Accuracy)
    
    if not os.path.exists('plots'):
        os.makedirs('plots')
    if not os.path.exists('plots/acc'):
        os.makedirs('plots/acc')
    if not os.path.exists('plots/loss'):
        os.makedirs('plots/loss')
        
    ###### Plot Accuracies ######
    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
    fig = plt.figure()
    ax = plt.subplot(111)
    ax.plot(list(range(0, len(Meta_Train_Accuracy))), Meta_Train_Accuracy, label="Meta Train ")
    ax.plot(list(range(0, len(Meta_Val_Accuracy))), Meta_Val_Accuracy, label="Meta Val")
#     ax.text((len(Meta_Val_Accuracy)/2), 0, 'Meta Test:{0}'.format(round(meta_test_accuracy, 2)), style='italic',
#         bbox={'facecolor': 'red', 'alpha': 0.25, 'pad': 5})
    # place a text box in upper left in axes coords
    ax.text(0.05, 0.5, 'Meta Test:{0}'.format(round(Meta_Test_Accuracy, 2)), transform=ax.transAxes, fontsize=14,
            verticalalignment='top', bbox=props)
    plt.title('Adaption')
    plt.xlabel('Iteration')
    plt.ylabel('Meta Accuracy')
    ax.legend()
    plt.savefig('./plots/acc/{0}_ways_{1}_shots_{2}_Acc_I_{3}.png'.format(dataset, ways, shots, num_iterations))
    ###### Plot Accuracies ######

    ###### Plot Errors ######
    fig = plt.figure()
    ax = plt.subplot(111)
    ax.plot(list(range(0, len(Meta_Train_Error))), Meta_Train_Error, label="Meta Train ")
    ax.plot(list(range(0, len(Meta_Val_Error))), Meta_Val_Accuracy, label="Meta Val Lss")
#     ax.text((len(Meta_Val_Accuracy)/2),0, 'Meta Test Accuracy:{0}  Meta Test Loss:{1}'.format(round(meta_test_accuracy, 2),
#                               round(meta_test_error, 2)), style='italic',
#         bbox={'facecolor': 'red', 'alpha': 0.25, 'pad': 5})
    ax.text(0.05, 0.5, 'MTestAcc:{0}  MTestLoss:{1}'.format(round(Meta_Test_Accuracy, 2),
                                           round(Meta_Test_Error, 2)), transform=ax.transAxes, fontsize=14,
            verticalalignment='top', bbox=props)
    plt.title('Adaption')
    plt.xlabel('Iteration')
    plt.ylabel('Meta Loss')
    ax.legend()
    plt.savefig('./plots/loss/{0}_ways_{1}_shots_{2}_Loss_I_{3}.png'.format(dataset, ways, shots, num_iterations))
    ###### Plot Errors ######

# %%
if __name__ == '__main__':
    perform_experiment(dataset='mini-imagenet',
    ways=5,
    shots=5,
    meta_lr=0.003,
    fast_lr=0.5,
    meta_batch_size=32,
    adaptation_steps=1,
    num_iterations=10000,
    cuda=True,
    seed=42)
# Out:
# Iteration 0
# Meta Train Error 6.996490091085434
# Meta Train Accuracy 0.21749999094754457
# Meta Valid Error 7.403145283460617
# Meta Valid Accuracy 0.21374999172985554
#
#
# Iteration 32
# Meta Train Error 1.4757372960448265
# Meta Train Accuracy 0.3774999901652336
# Meta Valid Error 1.5148613788187504
# Meta Valid Accuracy 0.33499999064952135
#
#
# Iteration 64
# Meta Train Error 1.472817212343216
# Meta Train Accuracy 0.3637499886099249
# Meta Valid Error 1.4684696048498154
# Meta Valid Accuracy 0.3649999916087836
#
#
# Iteration 96
# Meta Train Error 1.4054855518043041
# Meta Train Accuracy 0.41374998772516847
# Meta Valid Error 1.3974303379654884
# Meta Valid Accuracy 0.38124998891726136
#
#
# Iteration 128
# Meta Train Error 1.3701085448265076
# Meta Train Accuracy 0.4124999875202775
# Meta Valid Error 1.4431582540273666
# Meta Valid Accuracy 0.41374998819082975
#
#
# Iteration 160
# Meta Train Error 1.4111768919974566
# Meta Train Accuracy 0.39874998945742846
# Meta Valid Error 1.4000484608113766
# Meta Valid Accuracy 0.4037499902769923
#
#
# Iteration 192
# Meta Train Error 1.3788331970572472
# Meta Train Accuracy 0.4324999921955168
# Meta Valid Error 1.4295123666524887
# Meta Valid Accuracy 0.4124999865889549
#
#
# Iteration 224
# Meta Train Error 1.321498516947031
# Meta Train Accuracy 0.4437499870546162
# Meta Valid Error 1.3781900852918625
# Meta Valid Accuracy 0.4237499884329736
#
#
# Iteration 256
# Meta Train Error 1.3114472422748804
# Meta Train Accuracy 0.4649999854154885
# Meta Valid Error 1.3691676184535027
# Meta Valid Accuracy 0.4124999879859388
#
#
# Iteration 288
# Meta Train Error 1.3271608874201775
# Meta Train Accuracy 0.43999998830258846
# Meta Valid Error 1.3239472024142742
# Meta Valid Accuracy 0.4424999877810478
#
#
# Iteration 320
# Meta Train Error 1.2621422372758389
# Meta Train Accuracy 0.4824999887496233
# Meta Valid Error 1.3585506957024336
# Meta Valid Accuracy 0.4262499874457717
#
#
# Iteration 352
# Meta Train Error 1.2120314110070467
# Meta Train Accuracy 0.4974999874830246
# Meta Valid Error 1.3668669611215591
# Meta Valid Accuracy 0.42624998837709427
#
#
# Iteration 384
# Meta Train Error 1.1687664333730936
# Meta Train Accuracy 0.5199999874457717
# Meta Valid Error 1.2740822341293097
# Meta Valid Accuracy 0.44999998551793396
#
#
# Iteration 416
# Meta Train Error 1.1479111965745687
# Meta Train Accuracy 0.5399999897927046
# Meta Valid Error 1.2792852874845266
# Meta Valid Accuracy 0.46999998670071363
#
#
# Iteration 448
# Meta Train Error 1.0928318053483963
# Meta Train Accuracy 0.566249989438802
# Meta Valid Error 1.2848399877548218
# Meta Valid Accuracy 0.4624999896623194
#
#
# Iteration 480
# Meta Train Error 1.1405933424830437
# Meta Train Accuracy 0.5487499888986349
# Meta Valid Error 1.268705217167735
# Meta Valid Accuracy 0.5112499874085188
#
#
# Iteration 512
# Meta Train Error 1.1530110090970993
# Meta Train Accuracy 0.5624999878928065
# Meta Valid Error 1.273023596033454
# Meta Valid Accuracy 0.4712499878369272
#
#
# Iteration 544
# Meta Train Error 1.141913641244173
# Meta Train Accuracy 0.5424999827519059
# Meta Valid Error 1.1731701400130987
# Meta Valid Accuracy 0.5274999858811498
#
#
# Iteration 576
# Meta Train Error 1.067185627296567
# Meta Train Accuracy 0.5774999866262078
# Meta Valid Error 1.229449100792408
# Meta Valid Accuracy 0.5212499890476465
#
#
# Iteration 608
# Meta Train Error 1.081524295732379
# Meta Train Accuracy 0.5812499849125743
# Meta Valid Error 1.1880189925432205
# Meta Valid Accuracy 0.5012499862350523
#
#
# Iteration 640
# Meta Train Error 1.0725031476467848
# Meta Train Accuracy 0.5599999856203794
# Meta Valid Error 1.186685023829341
# Meta Valid Accuracy 0.5137499859556556
#
#
# Iteration 672
# Meta Train Error 1.0404023844748735
# Meta Train Accuracy 0.5774999866262078
# Meta Valid Error 1.1888931058347225
# Meta Valid Accuracy 0.5024999855086207
#
#
# Iteration 704
# Meta Train Error 1.0152501221746206
# Meta Train Accuracy 0.6149999871850014
# Meta Valid Error 1.1591438930481672
# Meta Valid Accuracy 0.5187499895691872
#
#
# Iteration 736
# Meta Train Error 0.9969964809715748
# Meta Train Accuracy 0.6174999875947833
# Meta Valid Error 1.1972176097333431
# Meta Valid Accuracy 0.5149999875575304
#
#
# Iteration 768
# Meta Train Error 1.0135246040299535
# Meta Train Accuracy 0.5949999867007136
# Meta Valid Error 1.1237800233066082
# Meta Valid Accuracy 0.5599999893456697
#
#
# Iteration 800
# Meta Train Error 1.0341318557038903
# Meta Train Accuracy 0.5974999815225601
# Meta Valid Error 1.1836391240358353
# Meta Valid Accuracy 0.5174999898299575
#
#
# Iteration 832
# Meta Train Error 0.971743993461132
# Meta Train Accuracy 0.6249999850988388
# Meta Valid Error 1.149865698069334
# Meta Valid Accuracy 0.5374999903142452
#
#
# Iteration 864
# Meta Train Error 1.0102324355393648
# Meta Train Accuracy 0.6062499834224582
# Meta Valid Error 1.2054785620421171
# Meta Valid Accuracy 0.4974999874830246
#
#
# Iteration 896
# Meta Train Error 0.9514221083372831
# Meta Train Accuracy 0.6274999808520079
# Meta Valid Error 1.1496600806713104
# Meta Valid Accuracy 0.5287499874830246
#
#
# Iteration 928
# Meta Train Error 1.011344999074936
# Meta Train Accuracy 0.5899999868124723
# Meta Valid Error 1.2031803037971258
# Meta Valid Accuracy 0.5224999850615859
#
#
# Iteration 960
# Meta Train Error 1.00046990159899
# Meta Train Accuracy 0.6087499856948853
# Meta Valid Error 1.091524887830019
# Meta Valid Accuracy 0.5437499862164259
#
#
# Iteration 992
# Meta Train Error 0.9897571271285415
# Meta Train Accuracy 0.6174999857321382
# Meta Valid Error 1.1164217572659254
# Meta Valid Accuracy 0.553749986924231
#
#
# Iteration 1024
# Meta Train Error 0.9758425913751125
# Meta Train Accuracy 0.6162499813362956
# Meta Valid Error 1.0960869118571281
# Meta Valid Accuracy 0.5624999813735485
#
#
# Iteration 1056
# Meta Train Error 0.9815176818519831
# Meta Train Accuracy 0.6012499863281846
# Meta Valid Error 1.103223066776991
# Meta Valid Accuracy 0.5587499858811498
#
#
# Iteration 1088
# Meta Train Error 0.95412343647331
# Meta Train Accuracy 0.6487499875947833
# Meta Valid Error 1.1734079774469137
# Meta Valid Accuracy 0.5324999857693911
#
#
# Iteration 1120
# Meta Train Error 1.006123362109065
# Meta Train Accuracy 0.6062499862164259
# Meta Valid Error 1.1249796319752932
# Meta Valid Accuracy 0.5387499900534749
#
#
# Iteration 1152
# Meta Train Error 1.0271915402263403
# Meta Train Accuracy 0.6049999841488898
# Meta Valid Error 1.1809185203164816
# Meta Valid Accuracy 0.5137499873526394
#
#
# Iteration 1184
# Meta Train Error 0.9387205988168716
# Meta Train Accuracy 0.6474999887868762
# Meta Valid Error 1.1004727967083454
# Meta Valid Accuracy 0.5687499870546162
#
#
# Iteration 1216
# Meta Train Error 0.9335626512765884
# Meta Train Accuracy 0.6237499816343188
# Meta Valid Error 1.0717945154756308
# Meta Valid Accuracy 0.5624999850988388
#
#
# Iteration 1248
# Meta Train Error 0.9420492015779018
# Meta Train Accuracy 0.6399999856948853
# Meta Valid Error 1.1239947490394115
# Meta Valid Accuracy 0.5437499899417162
#
#
# Iteration 1280
# Meta Train Error 0.9062976222485304
# Meta Train Accuracy 0.6487499820068479
# Meta Valid Error 1.103238221257925
# Meta Valid Accuracy 0.549999984446913
#
#
# Iteration 1312
# Meta Train Error 0.9000185197219253
# Meta Train Accuracy 0.6537499884143472
# Meta Valid Error 1.0980141069740057
# Meta Valid Accuracy 0.5437499871477485
#
#
# Iteration 1344
# Meta Train Error 0.866058100014925
# Meta Train Accuracy 0.6649999795481563
# Meta Valid Error 1.0821232236921787
# Meta Valid Accuracy 0.5537499859929085
#
#
# Iteration 1376
# Meta Train Error 0.832433670759201
# Meta Train Accuracy 0.6649999804794788
# Meta Valid Error 1.0851685209199786
# Meta Valid Accuracy 0.561249986756593
#
#
# Iteration 1408
# Meta Train Error 0.9759100265800953
# Meta Train Accuracy 0.6149999862536788
# Meta Valid Error 1.1151520851999521
# Meta Valid Accuracy 0.5437499852851033
#
#
# Iteration 1440
# Meta Train Error 0.9162982115522027
# Meta Train Accuracy 0.6299999859184027
# Meta Valid Error 1.0876133535057306
# Meta Valid Accuracy 0.5712499786168337
#
#
# Iteration 1472
# Meta Train Error 0.8851075517013669
# Meta Train Accuracy 0.6662499848753214
# Meta Valid Error 1.0982366744428873
# Meta Valid Accuracy 0.571249988861382
#
#
# Iteration 1504
# Meta Train Error 0.9460711218416691
# Meta Train Accuracy 0.6399999847635627
# Meta Valid Error 1.097243744879961
# Meta Valid Accuracy 0.571249982342124
#
#
# Iteration 1536
# Meta Train Error 0.880703735165298
# Meta Train Accuracy 0.6724999835714698
# Meta Valid Error 1.1035067979246378
# Meta Valid Accuracy 0.5512499874457717
#
#
# Iteration 1568
# Meta Train Error 0.9341139979660511
# Meta Train Accuracy 0.6374999824911356
# Meta Valid Error 1.034405916929245
# Meta Valid Accuracy 0.5799999861046672
# Iteration 1600
# Meta Train Error 0.9038502369076014
# Meta Train Accuracy 0.6449999823234975
# Meta Valid Error 1.1063604522496462
# Meta Valid Accuracy 0.5562499854713678
#
#
# Iteration 1632
# Meta Train Error 0.8316977806389332
# Meta Train Accuracy 0.6737499795854092
# Meta Valid Error 1.1072102300822735
# Meta Valid Accuracy 0.5424999864771962
#
#
# Iteration 1664
# Meta Train Error 0.8430547574535012
# Meta Train Accuracy 0.6712499801069498
# Meta Valid Error 1.0641416553407907
# Meta Valid Accuracy 0.5712499869987369
#
#
# Iteration 1696
# Meta Train Error 0.9332279022783041
# Meta Train Accuracy 0.6399999838322401
# Meta Valid Error 1.1029308084398508
# Meta Valid Accuracy 0.5512499874457717
#
#
# Iteration 1728
# Meta Train Error 0.8703517885878682
# Meta Train Accuracy 0.6412499798461795
# Meta Valid Error 1.0755242351442575
# Meta Valid Accuracy 0.5762499878183007
#
#
# Iteration 1760
# Meta Train Error 0.8938478492200375
# Meta Train Accuracy 0.6587499836459756
# Meta Valid Error 1.0782889630645514
# Meta Valid Accuracy 0.5712499860674143
#
#
# Iteration 1792
# Meta Train Error 0.8155162129551172
# Meta Train Accuracy 0.6912499815225601
# Meta Valid Error 1.060560703277588
# Meta Valid Accuracy 0.5637499885633588
#
#
# Iteration 1824
# Meta Train Error 0.8908711299300194
# Meta Train Accuracy 0.6599999833852053
# Meta Valid Error 1.0260588834062219
# Meta Valid Accuracy 0.5949999867007136
#
#
# Iteration 1856
# Meta Train Error 0.8927861014381051
# Meta Train Accuracy 0.6474999841302633
# Meta Valid Error 1.04104008898139
# Meta Valid Accuracy 0.5912499823607504
#
#
# Iteration 1888
# Meta Train Error 0.9343286640942097
# Meta Train Accuracy 0.6462499862536788
# Meta Valid Error 1.0914386715739965
# Meta Valid Accuracy 0.5512499874457717
#
#
# Iteration 1920
# Meta Train Error 0.8011177880689502
# Meta Train Accuracy 0.6962499767541885
# Meta Valid Error 1.10181387886405
# Meta Valid Accuracy 0.5687499903142452
#
#
# Iteration 1952
# Meta Train Error 0.8972734706476331
# Meta Train Accuracy 0.6737499814480543
# Meta Valid Error 1.0730152139440179
# Meta Valid Accuracy 0.5812499872408807
#
#
# Iteration 1984
# Meta Train Error 0.8266493771225214
# Meta Train Accuracy 0.6774999806657434
# Meta Valid Error 1.0792685598134995
# Meta Valid Accuracy 0.564999989233911
#
#
# Iteration 2016
# Meta Train Error 0.8516758698970079
# Meta Train Accuracy 0.6724999835714698
# Meta Valid Error 1.0496176704764366
# Meta Valid Accuracy 0.5974999787285924
#
#
# Iteration 2048
# Meta Train Error 0.8734745951369405
# Meta Train Accuracy 0.6624999782070518
# Meta Valid Error 1.1370860375463963
# Meta Valid Accuracy 0.571249988861382
#
#
# Iteration 2080
# Meta Train Error 0.7783717541024089
# Meta Train Accuracy 0.7124999817460775
# Meta Valid Error 1.0911641512066126
# Meta Valid Accuracy 0.564999989233911
#
#
# Iteration 2112
# Meta Train Error 0.7849032040685415
# Meta Train Accuracy 0.7012499822303653
# Meta Valid Error 1.018657697364688
# Meta Valid Accuracy 0.5974999871104956
#
#
# Iteration 2144
# Meta Train Error 0.7677600337192416
# Meta Train Accuracy 0.7187499776482582
# Meta Valid Error 1.0195706263184547
# Meta Valid Accuracy 0.587499987334013
#
#
# Iteration 2176
# Meta Train Error 0.8264591498300433
# Meta Train Accuracy 0.6712499763816595
# Meta Valid Error 1.0602811370044947
# Meta Valid Accuracy 0.5849999822676182
#
#
# Iteration 2208
# Meta Train Error 0.9142513871192932
# Meta Train Accuracy 0.6599999805912375
# Meta Valid Error 1.1418396290391684
# Meta Valid Accuracy 0.5424999897368252
#
#
# Iteration 2240
# Meta Train Error 0.816433522850275
# Meta Train Accuracy 0.6874999804422259
# Meta Valid Error 1.0805468242615461
# Meta Valid Accuracy 0.5587499840185046
#
#
# Iteration 2272
# Meta Train Error 0.7751516448333859
# Meta Train Accuracy 0.6999999824911356
# Meta Valid Error 1.037741219624877
# Meta Valid Accuracy 0.5687499875202775
#
#
# Iteration 2304
# Meta Train Error 0.8861321471631527
# Meta Train Accuracy 0.6537499781697989
# Meta Valid Error 0.9634229112416506
# Meta Valid Accuracy 0.6099999891594052
#
#
# Iteration 2336
# Meta Train Error 0.7860987586900592
# Meta Train Accuracy 0.679999983869493
# Meta Valid Error 1.045828938484192
# Meta Valid Accuracy 0.5662499885074794
#
#
# Iteration 2368
# Meta Train Error 0.8308954974636436
# Meta Train Accuracy 0.7012499831616879
# Meta Valid Error 1.0667565427720547
# Meta Valid Accuracy 0.5612499909475446
#
#
# Iteration 2400
# Meta Train Error 0.8358493708074093
# Meta Train Accuracy 0.674999981187284
# Meta Valid Error 1.072847692295909
# Meta Valid Accuracy 0.5899999849498272
#
#
# Iteration 2432
# Meta Train Error 0.8589180316776037
# Meta Train Accuracy 0.6837499821558595
# Meta Valid Error 1.053058322519064
# Meta Valid Accuracy 0.5674999849870801
#
#
# Iteration 2464
# Meta Train Error 0.8222582275047898
# Meta Train Accuracy 0.6924999803304672
# Meta Valid Error 1.0103760324418545
# Meta Valid Accuracy 0.5924999853596091
#
#
# Iteration 2496
# Meta Train Error 0.8096238458529115
# Meta Train Accuracy 0.6724999817088246
# Meta Valid Error 1.0281215514987707
# Meta Valid Accuracy 0.5962499836459756
#
#
# Iteration 2528
# Meta Train Error 0.7604784071445465
# Meta Train Accuracy 0.6987499827519059
# Meta Valid Error 1.0686680916696787
# Meta Valid Accuracy 0.5649999799206853
#
#
# Iteration 2560
# Meta Train Error 0.8335064668208361
# Meta Train Accuracy 0.6687499871477485
# Meta Valid Error 1.0307099185883999
# Meta Valid Accuracy 0.5799999888986349
#
#
# Iteration 2592
# Meta Train Error 0.8123172922059894
# Meta Train Accuracy 0.6774999806657434
# Meta Valid Error 1.0802189111709595
# Meta Valid Accuracy 0.5874999836087227
#
#
# Iteration 2624
# Meta Train Error 0.760637036524713
# Meta Train Accuracy 0.7199999783188105
# Meta Valid Error 1.0294943191111088
# Meta Valid Accuracy 0.5924999825656414
#
#
# Iteration 2656
# Meta Train Error 0.8222415065392852
# Meta Train Accuracy 0.6737499851733446
# Meta Valid Error 1.0376531444489956
# Meta Valid Accuracy 0.583749988116324
#
#
# Iteration 2688
# Meta Train Error 0.7795285703614354
# Meta Train Accuracy 0.6874999860301614
# Meta Valid Error 1.0063438545912504
# Meta Valid Accuracy 0.6074999868869781
#
#
# Iteration 2720
# Meta Train Error 0.783740658313036
# Meta Train Accuracy 0.6799999810755253
# Meta Valid Error 1.0026242854073644
# Meta Valid Accuracy 0.6024999879300594
#
#
# Iteration 2752
# Meta Train Error 0.8081573443487287
# Meta Train Accuracy 0.6712499829009175
# Meta Valid Error 1.1120833214372396
# Meta Valid Accuracy 0.5487499851733446
#
#
# Iteration 2784
# Meta Train Error 0.7100480413064361
# Meta Train Accuracy 0.7324999766424298
# Meta Valid Error 1.0653793513774872
# Meta Valid Accuracy 0.5574999870732427
#
#
# Iteration 2816
# Meta Train Error 0.7735559735447168
# Meta Train Accuracy 0.7099999785423279
# Meta Valid Error 1.044073300436139
# Meta Valid Accuracy 0.5887499870732427
#
#
# Iteration 2848
# Meta Train Error 0.80292400252074
# Meta Train Accuracy 0.7024999838322401
# Meta Valid Error 1.0231498591601849
# Meta Valid Accuracy 0.607499985024333
#
#
# Iteration 2880
# Meta Train Error 0.754491270519793
# Meta Train Accuracy 0.7224999815225601
# Meta Valid Error 1.0664383433759212
# Meta Valid Accuracy 0.5862499875947833
#
#
# Iteration 2912
# Meta Train Error 0.7389344619587064
# Meta Train Accuracy 0.7274999842047691
# Meta Valid Error 1.055331191048026
# Meta Valid Accuracy 0.5899999886751175
#
#
# Iteration 2944
# Meta Train Error 0.7662986330688
# Meta Train Accuracy 0.7099999766796827
# Meta Valid Error 1.0416643675416708
# Meta Valid Accuracy 0.5949999839067459
#
#
# Iteration 2976
# Meta Train Error 0.7034268504939973
# Meta Train Accuracy 0.7324999812990427
# Meta Valid Error 1.002109706401825
# Meta Valid Accuracy 0.5899999877437949
#
#
# Iteration 3008
# Meta Train Error 0.7696953248232603
# Meta Train Accuracy 0.7037499798461795
# Meta Valid Error 1.015403676778078
# Meta Valid Accuracy 0.6074999803677201
#
#
# Iteration 3040
# Meta Train Error 0.8614849932491779
# Meta Train Accuracy 0.6699999822303653
# Meta Valid Error 1.0574708860367537
# Meta Valid Accuracy 0.5674999868497252
#
#
# Iteration 3072
# Meta Train Error 0.7324287286028266
# Meta Train Accuracy 0.7324999812990427
# Meta Valid Error 1.0156326200813055
# Meta Valid Accuracy 0.6049999808892608
#
#
# Iteration 3104
# Meta Train Error 0.7690515341237187
# Meta Train Accuracy 0.6974999764934182
# Meta Valid Error 1.0260331202298403
# Meta Valid Accuracy 0.5687499772757292
#
#
# Iteration 3136
# Meta Train Error 0.7879325812682509
# Meta Train Accuracy 0.6849999818950891
# Meta Valid Error 1.0557369105517864
# Meta Valid Accuracy 0.5762499859556556
#
#
# Iteration 3168
# Meta Train Error 0.6551566366106272
# Meta Train Accuracy 0.7624999796971679
# Meta Valid Error 1.0486921295523643
# Meta Valid Accuracy 0.5837499834597111
# Iteration 3200
# Meta Train Error 0.817446275614202
# Meta Train Accuracy 0.6799999801442027
# Meta Valid Error 1.0141364876180887
# Meta Valid Accuracy 0.598749983124435
#
#
# Iteration 3232
# Meta Train Error 0.791101910173893
# Meta Train Accuracy 0.696249975822866
# Meta Valid Error 1.075308782979846
# Meta Valid Accuracy 0.5799999879673123
#
#
# Iteration 3264
# Meta Train Error 0.7262999070808291
# Meta Train Accuracy 0.7199999783188105
# Meta Valid Error 0.9704683423042297
# Meta Valid Accuracy 0.612499981187284
#
#
# Iteration 3296
# Meta Train Error 0.7658834187313914
# Meta Train Accuracy 0.7024999810382724
# Meta Valid Error 1.0306560331955552
# Meta Valid Accuracy 0.6024999814108014
#
#
# Iteration 3328
# Meta Train Error 0.7690308219753206
# Meta Train Accuracy 0.7074999809265137
# Meta Valid Error 0.9989279108121991
# Meta Valid Accuracy 0.622499986551702
#
#
# Iteration 3360
# Meta Train Error 0.7950497381389141
# Meta Train Accuracy 0.7049999786540866
# Meta Valid Error 1.0440335925668478
# Meta Valid Accuracy 0.5999999828636646
#
#
# Iteration 3392
# Meta Train Error 0.7259176317602396
# Meta Train Accuracy 0.7249999800696969
# Meta Valid Error 1.0331177040934563
# Meta Valid Accuracy 0.5937499841675162
#
#
# Iteration 3424
# Meta Train Error 0.7681249836459756
# Meta Train Accuracy 0.7212499799206853
# Meta Valid Error 0.9935538619756699
# Meta Valid Accuracy 0.591249986551702
#
#
# Iteration 3456
# Meta Train Error 0.7245446760207415
# Meta Train Accuracy 0.7174999807029963
# Meta Valid Error 1.0251722168177366
# Meta Valid Accuracy 0.5987499840557575
#
#
# Iteration 3488
# Meta Train Error 0.7749967901036143
# Meta Train Accuracy 0.7137499833479524
# Meta Valid Error 1.0693317279219627
# Meta Valid Accuracy 0.5799999907612801
#
#
# Iteration 3520
# Meta Train Error 0.8420411786064506
# Meta Train Accuracy 0.6737499888986349
# Meta Valid Error 1.0273608416318893
# Meta Valid Accuracy 0.6112499926239252
#
#
# Iteration 3552
# Meta Train Error 0.7659053672105074
# Meta Train Accuracy 0.7137499814853072
# Meta Valid Error 0.987178860232234
# Meta Valid Accuracy 0.6187499836087227
#
#
# Iteration 3584
# Meta Train Error 0.8103881888091564
# Meta Train Accuracy 0.6899999817833304
# Meta Valid Error 1.112550999969244
# Meta Valid Accuracy 0.5437499871477485
#
#
# Iteration 3616
# Meta Train Error 0.6904254844412208
# Meta Train Accuracy 0.7099999785423279
# Meta Valid Error 0.9911314342170954
# Meta Valid Accuracy 0.6149999834597111
#
#
# Iteration 3648
# Meta Train Error 0.7671301476657391
# Meta Train Accuracy 0.6949999770149589
# Meta Valid Error 0.9496787674725056
# Meta Valid Accuracy 0.6237499890848994
#
#
# Iteration 3680
# Meta Train Error 0.6702449796721339
# Meta Train Accuracy 0.7449999786913395
# Meta Valid Error 0.982159337028861
# Meta Valid Accuracy 0.593749986961484
#
#
# Iteration 3712
# Meta Train Error 0.7290266663767397
# Meta Train Accuracy 0.7249999772757292
# Meta Valid Error 1.0558287184685469
# Meta Valid Accuracy 0.5712499851360917
#
#
# Iteration 3744
# Meta Train Error 0.74652215000242
# Meta Train Accuracy 0.716249980032444
# Meta Valid Error 1.0505701936781406
# Meta Valid Accuracy 0.5887499833479524
#
#
# Iteration 3776
# Meta Train Error 0.7903122548013926
# Meta Train Accuracy 0.6987499818205833
# Meta Valid Error 1.0081832939758897
# Meta Valid Accuracy 0.5999999847263098
#
#
# Iteration 3808
# Meta Train Error 0.7767915781587362
# Meta Train Accuracy 0.7049999805167317
# Meta Valid Error 1.0701057389378548
# Meta Valid Accuracy 0.5674999849870801
#
#
# Iteration 3840
# Meta Train Error 0.7250837972387671
# Meta Train Accuracy 0.7224999787285924
# Meta Valid Error 1.0265405997633934
# Meta Valid Accuracy 0.5812499821186066
#
#
# Iteration 3872
# Meta Train Error 0.7238332349807024
# Meta Train Accuracy 0.7187499795109034
# Meta Valid Error 1.0042217671871185
# Meta Valid Accuracy 0.5874999789521098
#
#
# Iteration 3904
# Meta Train Error 0.8030361533164978
# Meta Train Accuracy 0.6912499815225601
# Meta Valid Error 1.057133598253131
# Meta Valid Accuracy 0.5874999789521098
#
#
# Iteration 3936
# Meta Train Error 0.6771251861937344
# Meta Train Accuracy 0.7387499865144491
# Meta Valid Error 0.9179536178708076
# Meta Valid Accuracy 0.643749987706542
#
#
# Iteration 3968
# Meta Train Error 0.6713919024914503
# Meta Train Accuracy 0.7549999738112092
# Meta Valid Error 1.0483800787478685
# Meta Valid Accuracy 0.5849999850615859
#
#
# Iteration 4000
# Meta Train Error 0.7185890451073647
# Meta Train Accuracy 0.726249978877604
# Meta Valid Error 1.0114197507500648
# Meta Valid Accuracy 0.6087499829009175
#
#
# Iteration 4032
# Meta Train Error 0.8251901138573885
# Meta Train Accuracy 0.6849999818950891
# Meta Valid Error 1.0246558617800474
# Meta Valid Accuracy 0.6174999875947833
#
#
# Iteration 4064
# Meta Train Error 0.7041990696452558
# Meta Train Accuracy 0.7062499802559614
# Meta Valid Error 1.0075962068513036
# Meta Valid Accuracy 0.6087499847635627
#
#
# Iteration 4096
# Meta Train Error 0.7336212871596217
# Meta Train Accuracy 0.7224999815225601
# Meta Valid Error 1.0548687875270844
# Meta Valid Accuracy 0.5824999874457717
#
#
# Iteration 4128
# Meta Train Error 0.866617064923048
# Meta Train Accuracy 0.6524999821558595
# Meta Valid Error 1.0224751373752952
# Meta Valid Accuracy 0.5887499833479524
#
#
# Iteration 4160
# Meta Train Error 0.702784382738173
# Meta Train Accuracy 0.7287499802187085
# Meta Valid Error 1.0464793592691422
# Meta Valid Accuracy 0.5762499868869781
#
#
# Iteration 4192
# Meta Train Error 0.6893394612707198
# Meta Train Accuracy 0.727499982342124
# Meta Valid Error 0.9678004262968898
# Meta Valid Accuracy 0.6237499825656414
#
#
# Iteration 4224
# Meta Train Error 0.7542113550007343
# Meta Train Accuracy 0.6949999844655395
# Meta Valid Error 1.0896399542689323
# Meta Valid Accuracy 0.5724999839439988
#
#
# Iteration 4256
# Meta Train Error 0.7295177588239312
# Meta Train Accuracy 0.7174999825656414
# Meta Valid Error 1.0155827812850475
# Meta Valid Accuracy 0.6024999842047691
#
#
# Iteration 4288
# Meta Train Error 0.6785078588873148
# Meta Train Accuracy 0.7512499755248427
# Meta Valid Error 1.0162876136600971
# Meta Valid Accuracy 0.6062499852851033
#
#
# Iteration 4320
# Meta Train Error 0.6887731268070638
# Meta Train Accuracy 0.7387499762699008
# Meta Valid Error 0.9809275958687067
# Meta Valid Accuracy 0.6212499802932143
#
#
# Iteration 4352
# Meta Train Error 0.7177889831364155
# Meta Train Accuracy 0.727499975822866
# Meta Valid Error 1.0663878004997969
# Meta Valid Accuracy 0.5687499893829226
#
#
# Iteration 4384
# Meta Train Error 0.666748708114028
# Meta Train Accuracy 0.7562499828636646
# Meta Valid Error 1.0005336087197065
# Meta Valid Accuracy 0.6374999890103936
#
#
# Iteration 4416
# Meta Train Error 0.7575738625600934
# Meta Train Accuracy 0.7074999865144491
# Meta Valid Error 1.0387330539524555
# Meta Valid Accuracy 0.6012499881908298
#
#
# Iteration 4448
# Meta Train Error 0.6390735139138997
# Meta Train Accuracy 0.7574999844655395
# Meta Valid Error 1.056877063587308
# Meta Valid Accuracy 0.5724999872036278
#
#
# Iteration 4480
# Meta Train Error 0.7196970134973526
# Meta Train Accuracy 0.7149999747052789
# Meta Valid Error 1.045061845332384
# Meta Valid Accuracy 0.5774999829009175
#
#
# Iteration 4512
# Meta Train Error 0.7120449189096689
# Meta Train Accuracy 0.7212499817833304
# Meta Valid Error 1.0296584405004978
# Meta Valid Accuracy 0.5799999916926026
#
#
# Iteration 4544
# Meta Train Error 0.7662712498567998
# Meta Train Accuracy 0.7012499794363976
# Meta Valid Error 1.0179748591035604
# Meta Valid Accuracy 0.5887499870732427
#
#
# Iteration 4576
# Meta Train Error 0.702207999303937
# Meta Train Accuracy 0.7274999804794788
# Meta Valid Error 0.9134458992630243
# Meta Valid Accuracy 0.6512499870732427
#
#
# Iteration 4608
# Meta Train Error 0.7095384728163481
# Meta Train Accuracy 0.711249983869493
# Meta Valid Error 1.0318619292229414
# Meta Valid Accuracy 0.582499984651804
#
#
# Iteration 4640
# Meta Train Error 0.7184954159893095
# Meta Train Accuracy 0.7237499821931124
# Meta Valid Error 0.9917005794122815
# Meta Valid Accuracy 0.6324999835342169
#
#
# Iteration 4672
# Meta Train Error 0.6619158796966076
# Meta Train Accuracy 0.7462499812245369
# Meta Valid Error 1.0903911851346493
# Meta Valid Accuracy 0.5562499864026904
#
#
# Iteration 4704
# Meta Train Error 0.7478304700925946
# Meta Train Accuracy 0.7087499834597111
# Meta Valid Error 1.0163428988307714
# Meta Valid Accuracy 0.6037499848753214
#
#
# Iteration 4736
# Meta Train Error 0.6436306862160563
# Meta Train Accuracy 0.7474999809637666
# Meta Valid Error 1.0524541269987822
# Meta Valid Accuracy 0.576249985024333
#
#
# Iteration 4768
# Meta Train Error 0.757616875693202
# Meta Train Accuracy 0.6999999796971679
# Meta Valid Error 1.0320912981405854
# Meta Valid Accuracy 0.5949999839067459
# Iteration 4800
# Meta Train Error 0.7102746688760817
# Meta Train Accuracy 0.7262499826028943
# Meta Valid Error 1.0411234330385923
# Meta Valid Accuracy 0.5799999861046672
#
#
# Iteration 4832
# Meta Train Error 0.7162460922263563
# Meta Train Accuracy 0.7187499767169356
# Meta Valid Error 1.0206708889454603
# Meta Valid Accuracy 0.5724999830126762
#
#
# Iteration 4864
# Meta Train Error 0.6146593131124973
# Meta Train Accuracy 0.7737499754875898
# Meta Valid Error 1.0300287622958422
# Meta Valid Accuracy 0.5862499875947833
#
#
# Iteration 4896
# Meta Train Error 0.7106749312952161
# Meta Train Accuracy 0.7237499775364995
# Meta Valid Error 0.9761864840984344
# Meta Valid Accuracy 0.6087499838322401
#
#
# Iteration 4928
# Meta Train Error 0.7300542062148452
# Meta Train Accuracy 0.7349999789148569
# Meta Valid Error 0.9962953180074692
# Meta Valid Accuracy 0.6199999805539846
#
#
# Iteration 4960
# Meta Train Error 0.758125551044941
# Meta Train Accuracy 0.7237499766051769
# Meta Valid Error 1.0187050513923168
# Meta Valid Accuracy 0.5849999813362956
#
#
# Iteration 4992
# Meta Train Error 0.661257516592741
# Meta Train Accuracy 0.7412499785423279
# Meta Valid Error 1.027298403903842
# Meta Valid Accuracy 0.614999988116324
#
#
# Iteration 5024
# Meta Train Error 0.7052126955240965
# Meta Train Accuracy 0.733749981969595
# Meta Valid Error 1.02517319470644
# Meta Valid Accuracy 0.5899999858811498
#
#
# Iteration 5056
# Meta Train Error 0.7877276884391904
# Meta Train Accuracy 0.7012499803677201
# Meta Valid Error 1.1337905246764421
# Meta Valid Accuracy 0.5624999860301614
#
#
# Iteration 5088
# Meta Train Error 0.7203519656322896
# Meta Train Accuracy 0.7224999805912375
# Meta Valid Error 1.0206966791301966
# Meta Valid Accuracy 0.6049999846145511
#
#
# Iteration 5120
# Meta Train Error 0.7082420866936445
# Meta Train Accuracy 0.7224999843165278
# Meta Valid Error 0.9964507352560759
# Meta Valid Accuracy 0.6174999829381704
#
#
# Iteration 5152
# Meta Train Error 0.7508904216811061
# Meta Train Accuracy 0.7112499848008156
# Meta Valid Error 0.9978075586259365
# Meta Valid Accuracy 0.6024999842047691
#
#
# Iteration 5184
# Meta Train Error 0.7431431100703776
# Meta Train Accuracy 0.7149999868124723
# Meta Valid Error 1.0266415867954493
# Meta Valid Accuracy 0.5862499857321382
#
#
# Iteration 5216
# Meta Train Error 0.7126590022817254
# Meta Train Accuracy 0.7287499764934182
# Meta Valid Error 0.9425884839147329
# Meta Valid Accuracy 0.616249986924231
#
#
# Iteration 5248
# Meta Train Error 0.7387471524998546
# Meta Train Accuracy 0.7237499766051769
# Meta Valid Error 1.0730004124343395
# Meta Valid Accuracy 0.5612499853596091
#
#
# Iteration 5280
# Meta Train Error 0.7198229869827628
# Meta Train Accuracy 0.7199999801814556
# Meta Valid Error 0.9191003106534481
# Meta Valid Accuracy 0.6424999823793769
#
#
# Iteration 5312
# Meta Train Error 0.7166741201654077
# Meta Train Accuracy 0.7162499837577343
# Meta Valid Error 1.01327152736485
# Meta Valid Accuracy 0.5912499846890569
#
#
# Iteration 5344
# Meta Train Error 0.6890837857499719
# Meta Train Accuracy 0.7262499714270234
# Meta Valid Error 1.06354770809412
# Meta Valid Accuracy 0.577499988488853
#
#
# Iteration 5376
# Meta Train Error 0.7512209760025144
# Meta Train Accuracy 0.7037499807775021
# Meta Valid Error 1.0507705062627792
# Meta Valid Accuracy 0.5737499883398414
#
#
# Iteration 5408
# Meta Train Error 0.694047724828124
# Meta Train Accuracy 0.7199999811127782
# Meta Valid Error 1.0208057034760714
# Meta Valid Accuracy 0.5899999840185046
#
#
# Iteration 5440
# Meta Train Error 0.6644387478008866
# Meta Train Accuracy 0.7637499794363976
# Meta Valid Error 1.0165901370346546
# Meta Valid Accuracy 0.5887499889358878
#
#
# Iteration 5472
# Meta Train Error 0.8017390230670571
# Meta Train Accuracy 0.6937499800696969
# Meta Valid Error 0.9779708422720432
# Meta Valid Accuracy 0.6262499839067459
#
#
# Iteration 5504
# Meta Train Error 0.6822453774511814
# Meta Train Accuracy 0.7449999805539846
# Meta Valid Error 1.036813873797655
# Meta Valid Accuracy 0.6024999897927046
#
#
# Iteration 5536
# Meta Train Error 0.771808142773807
# Meta Train Accuracy 0.7137499833479524
# Meta Valid Error 1.1093985615298152
# Meta Valid Accuracy 0.5412499895319343
#
#
# Iteration 5568
# Meta Train Error 0.729597651399672
# Meta Train Accuracy 0.7399999778717756
# Meta Valid Error 1.066119072958827
# Meta Valid Accuracy 0.5924999853596091
#
#
# Iteration 5600
# Meta Train Error 0.723466812632978
# Meta Train Accuracy 0.7274999804794788
# Meta Valid Error 1.0094255357980728
# Meta Valid Accuracy 0.5874999845400453
#
#
# Iteration 5632
# Meta Train Error 0.7111284481361508
# Meta Train Accuracy 0.7337499791756272
# Meta Valid Error 1.0232737101614475
# Meta Valid Accuracy 0.6024999860674143
#
#
# Iteration 5664
# Meta Train Error 0.7003292581066489
# Meta Train Accuracy 0.7437499780207872
# Meta Valid Error 1.0126579403877258
# Meta Valid Accuracy 0.5999999847263098
#
#
# Iteration 5696
# Meta Train Error 0.7535449075512588
# Meta Train Accuracy 0.7162499791011214
# Meta Valid Error 1.0651466809213161
# Meta Valid Accuracy 0.5824999818578362
#
#
# Iteration 5728
# Meta Train Error 0.7540492210537195
# Meta Train Accuracy 0.7162499837577343
# Meta Valid Error 1.0354222320020199
# Meta Valid Accuracy 0.5824999874457717
#
#
# Iteration 5760
# Meta Train Error 0.6944504887796938
# Meta Train Accuracy 0.7474999763071537
# Meta Valid Error 1.0084850620478392
# Meta Valid Accuracy 0.5949999867007136
#
#
# Iteration 5792
# Meta Train Error 0.651364229619503
# Meta Train Accuracy 0.7562499772757292
# Meta Valid Error 1.001562336459756
# Meta Valid Accuracy 0.5937499860301614
#
#
# Iteration 5824
# Meta Train Error 0.6982429567724466
# Meta Train Accuracy 0.7299999762326479
# Meta Valid Error 1.006114587187767
# Meta Valid Accuracy 0.6012499872595072
#
#
# Iteration 5856
# Meta Train Error 0.608877994120121
# Meta Train Accuracy 0.7724999766796827
# Meta Valid Error 1.073506748303771
# Meta Valid Accuracy 0.5737499864771962
#
#
# Iteration 5888
# Meta Train Error 0.6683480720967054
# Meta Train Accuracy 0.7574999751523137
# Meta Valid Error 1.0350733138620853
# Meta Valid Accuracy 0.5912499828264117
#
#
# Iteration 5920
# Meta Train Error 0.7349512930959463
# Meta Train Accuracy 0.7249999828636646
# Meta Valid Error 1.0717104841023684
# Meta Valid Accuracy 0.5599999893456697
#
#
# Iteration 5952
# Meta Train Error 0.6685690651647747
# Meta Train Accuracy 0.748749976977706
# Meta Valid Error 0.9884507060050964
# Meta Valid Accuracy 0.6149999871850014
#
#
# Iteration 5984
# Meta Train Error 0.7122355569154024
# Meta Train Accuracy 0.7349999863654375
# Meta Valid Error 1.0505339968949556
# Meta Valid Accuracy 0.5712499897927046
#
#
# Iteration 6016
# Meta Train Error 0.7016696939244866
# Meta Train Accuracy 0.7362499739974737
# Meta Valid Error 1.0760082993656397
# Meta Valid Accuracy 0.5574999856762588
#
#
# Iteration 6048
# Meta Train Error 0.7097906032577157
# Meta Train Accuracy 0.7249999810010195
# Meta Valid Error 1.076007341966033
# Meta Valid Accuracy 0.5812499895691872
#
#
# Iteration 6080
# Meta Train Error 0.6023418684490025
# Meta Train Accuracy 0.7687499783933163
# Meta Valid Error 0.9794262647628784
# Meta Valid Accuracy 0.627499982714653
#
#
# Iteration 6112
# Meta Train Error 0.7777158282697201
# Meta Train Accuracy 0.6924999821931124
# Meta Valid Error 0.975576987490058
# Meta Valid Accuracy 0.6174999857321382
#
#
# Iteration 6144
# Meta Train Error 0.6557142655365169
# Meta Train Accuracy 0.7537499777972698
# Meta Valid Error 1.1178969703614712
# Meta Valid Accuracy 0.5724999839439988
#
#
# Iteration 6176
# Meta Train Error 0.6446377034299076
# Meta Train Accuracy 0.7562499763444066
# Meta Valid Error 1.068980347365141
# Meta Valid Accuracy 0.5712499860674143
#
#
# Iteration 6208
# Meta Train Error 0.694277613889426
# Meta Train Accuracy 0.7212499864399433
# Meta Valid Error 1.0829247776418924
# Meta Valid Accuracy 0.5799999865703285
#
#
# Iteration 6240
# Meta Train Error 0.6608509952202439
# Meta Train Accuracy 0.7499999757856131
# Meta Valid Error 1.0007660742849112
# Meta Valid Accuracy 0.6012499900534749
#
#
# Iteration 6272
# Meta Train Error 0.5889570792205632
# Meta Train Accuracy 0.7837499771267176
# Meta Valid Error 0.9674416538327932
# Meta Valid Accuracy 0.6387499887496233
#
#
# Iteration 6304
# Meta Train Error 0.6655267090536654
# Meta Train Accuracy 0.7437499836087227
# Meta Valid Error 1.0156621616333723
# Meta Valid Accuracy 0.6199999852105975
#
#
# Iteration 6336
# Meta Train Error 0.6828036801889539
# Meta Train Accuracy 0.738749984651804
# Meta Valid Error 1.0060360841453075
# Meta Valid Accuracy 0.5812499905005097
#
#
# Iteration 6368
# Meta Train Error 0.6647796235047281
# Meta Train Accuracy 0.7437499715015292
# Meta Valid Error 0.958275780081749
# Meta Valid Accuracy 0.6249999860301614
# Iteration 6400
# Meta Train Error 0.7476243656128645
# Meta Train Accuracy 0.694999985396862
# Meta Valid Error 1.057786975055933
# Meta Valid Accuracy 0.5849999831989408
#
#
# Iteration 6432
# Meta Train Error 0.7148555098101497
# Meta Train Accuracy 0.7287499783560634
# Meta Valid Error 1.0268326383084059
# Meta Valid Accuracy 0.5962499864399433
#
#
# Iteration 6464
# Meta Train Error 0.6992430500686169
# Meta Train Accuracy 0.7362499767914414
# Meta Valid Error 0.9713278338313103
# Meta Valid Accuracy 0.6062499852851033
#
#
# Iteration 6496
# Meta Train Error 0.6729094022884965
# Meta Train Accuracy 0.7474999818950891
# Meta Valid Error 0.9554477613419294
# Meta Valid Accuracy 0.6337499804794788
#
#
# Iteration 6528
# Meta Train Error 0.7098221154883504
# Meta Train Accuracy 0.7299999846145511
# Meta Valid Error 1.1816605692729354
# Meta Valid Accuracy 0.5487499888986349
#
#
# Iteration 6560
# Meta Train Error 0.6566438125446439
# Meta Train Accuracy 0.7462499812245369
# Meta Valid Error 0.9794832039624453
# Meta Valid Accuracy 0.6049999883398414
#
#
# Iteration 6592
# Meta Train Error 0.6824256954714656
# Meta Train Accuracy 0.743749980814755
# Meta Valid Error 1.052454262971878
# Meta Valid Accuracy 0.5999999837949872
#
#
# Iteration 6624
# Meta Train Error 0.678840568754822
# Meta Train Accuracy 0.7399999778717756
# Meta Valid Error 0.9916787091642618
# Meta Valid Accuracy 0.6099999807775021
#
#
# Iteration 6656
# Meta Train Error 0.6875785156153142
# Meta Train Accuracy 0.7212499743327498
# Meta Valid Error 0.9892970994114876
# Meta Valid Accuracy 0.6137499883770943
#
#
# Iteration 6688
# Meta Train Error 0.6395463449880481
# Meta Train Accuracy 0.7712499788030982
# Meta Valid Error 1.0124400928616524
# Meta Valid Accuracy 0.5962499873712659
#
#
# Iteration 6720
# Meta Train Error 0.6892988649196923
# Meta Train Accuracy 0.7312499862164259
# Meta Valid Error 1.0953908413648605
# Meta Valid Accuracy 0.5699999858625233
#
#
# Iteration 6752
# Meta Train Error 0.6902693593874574
# Meta Train Accuracy 0.736249977722764
# Meta Valid Error 1.022256487980485
# Meta Valid Accuracy 0.5899999858811498
#
#
# Iteration 6784
# Meta Train Error 0.6596733499318361
# Meta Train Accuracy 0.7487499825656414
# Meta Valid Error 1.038446081802249
# Meta Valid Accuracy 0.6012499863281846
#
#
# Iteration 6816
# Meta Train Error 0.5688059004023671
# Meta Train Accuracy 0.7849999815225601
# Meta Valid Error 1.0353283733129501
# Meta Valid Accuracy 0.6012499844655395
#
#
# Iteration 6848
# Meta Train Error 0.6420382661744952
# Meta Train Accuracy 0.7624999787658453
# Meta Valid Error 1.0485270246863365
# Meta Valid Accuracy 0.5974999899044633
#
#
# Iteration 6880
# Meta Train Error 0.6515814121812582
# Meta Train Accuracy 0.7549999766051769
# Meta Valid Error 0.9817235711961985
# Meta Valid Accuracy 0.608749981969595
#
#
# Iteration 6912
# Meta Train Error 0.6613279040902853
# Meta Train Accuracy 0.7574999816715717
# Meta Valid Error 1.0017613880336285
# Meta Valid Accuracy 0.6049999790266156
#
#
# Iteration 6944
# Meta Train Error 0.6146765165030956
# Meta Train Accuracy 0.7674999833106995
# Meta Valid Error 0.9977191146463156
# Meta Valid Accuracy 0.5962499845772982
#
#
# Iteration 6976
# Meta Train Error 0.6506248824298382
# Meta Train Accuracy 0.7524999789893627
# Meta Valid Error 1.041298858821392
# Meta Valid Accuracy 0.5962499845772982
#
#
# Iteration 7008
# Meta Train Error 0.6858560869004577
# Meta Train Accuracy 0.7412499794736505
# Meta Valid Error 1.0633110664784908
# Meta Valid Accuracy 0.5787499826401472
#
#
# Iteration 7040
# Meta Train Error 0.6824242854490876
# Meta Train Accuracy 0.7437499798834324
# Meta Valid Error 1.0407283287495375
# Meta Valid Accuracy 0.5837499862536788
#
#
# Iteration 7072
# Meta Train Error 0.6920379744842649
# Meta Train Accuracy 0.7337499763816595
# Meta Valid Error 1.104718666523695
# Meta Valid Accuracy 0.5587499849498272
#
#
# Iteration 7104
# Meta Train Error 0.5883077527396381
# Meta Train Accuracy 0.7787499781697989
# Meta Valid Error 1.057342967018485
# Meta Valid Accuracy 0.581249981187284
#
#
# Iteration 7136
# Meta Train Error 0.6633820598945022
# Meta Train Accuracy 0.7624999806284904
# Meta Valid Error 0.9840912912040949
# Meta Valid Accuracy 0.609999991953373
#
#
# Iteration 7168
# Meta Train Error 0.708153210580349
# Meta Train Accuracy 0.7199999801814556
# Meta Valid Error 0.9497419968247414
# Meta Valid Accuracy 0.6237499844282866
#
#
# Iteration 7200
# Meta Train Error 0.6029603329952806
# Meta Train Accuracy 0.7799999788403511
# Meta Valid Error 0.9555227365344763
# Meta Valid Accuracy 0.6287499815225601
#
#
# Iteration 7232
# Meta Train Error 0.6970302751287818
# Meta Train Accuracy 0.7349999761208892
# Meta Valid Error 1.0428289286792278
# Meta Valid Accuracy 0.5737499902024865
#
#
# Iteration 7264
# Meta Train Error 0.6714594345539808
# Meta Train Accuracy 0.7349999835714698
# Meta Valid Error 1.013237165287137
# Meta Valid Accuracy 0.6074999836273491
#
#
# Iteration 7296
# Meta Train Error 0.6930782040581107
# Meta Train Accuracy 0.7287499783560634
# Meta Valid Error 1.0522430166602135
# Meta Valid Accuracy 0.5812499839812517
#
#
# Iteration 7328
# Meta Train Error 0.634583449922502
# Meta Train Accuracy 0.7637499831616879
# Meta Valid Error 1.0216060262173414
# Meta Valid Accuracy 0.6012499844655395
#
#
# Iteration 7360
# Meta Train Error 0.668492192402482
# Meta Train Accuracy 0.7499999795109034
# Meta Valid Error 0.9965801257640123
# Meta Valid Accuracy 0.6162499906495214
#
#
# Iteration 7392
# Meta Train Error 0.6882623718120158
# Meta Train Accuracy 0.7349999807775021
# Meta Valid Error 1.0415453035384417
# Meta Valid Accuracy 0.5962499864399433
#
#
# Iteration 7424
# Meta Train Error 0.64968744199723
# Meta Train Accuracy 0.756249975413084
# Meta Valid Error 1.0117679759860039
# Meta Valid Accuracy 0.5924999872222543
#
#
# Iteration 7456
# Meta Train Error 0.6502395323477685
# Meta Train Accuracy 0.7724999785423279
# Meta Valid Error 0.9698341432958841
# Meta Valid Accuracy 0.6224999902769923
#
#
# Iteration 7488
# Meta Train Error 0.641758581623435
# Meta Train Accuracy 0.7624999769032001
# Meta Valid Error 1.009195240214467
# Meta Valid Accuracy 0.5874999854713678
#
#
# Iteration 7520
# Meta Train Error 0.5933932354673743
# Meta Train Accuracy 0.7849999815225601
# Meta Valid Error 0.977681327611208
# Meta Valid Accuracy 0.6249999883584678
#
#
# Iteration 7552
# Meta Train Error 0.6791514828801155
# Meta Train Accuracy 0.7499999795109034
# Meta Valid Error 1.0895056277513504
# Meta Valid Accuracy 0.561249983496964
#
#
# Iteration 7584
# Meta Train Error 0.66756078787148
# Meta Train Accuracy 0.7687499690800905
# Meta Valid Error 1.1211169101297855
# Meta Valid Accuracy 0.5649999878369272
#
#
# Iteration 7616
# Meta Train Error 0.6558668026700616
# Meta Train Accuracy 0.7487499844282866
# Meta Valid Error 1.1138350013643503
# Meta Valid Accuracy 0.5637499848380685
#
#
# Iteration 7648
# Meta Train Error 0.6892347573302686
# Meta Train Accuracy 0.7437499798834324
# Meta Valid Error 1.0537491496652365
# Meta Valid Accuracy 0.5724999876692891
#
#
# Iteration 7680
# Meta Train Error 0.6864206790924072
# Meta Train Accuracy 0.7549999784678221
# Meta Valid Error 1.0957233253866434
# Meta Valid Accuracy 0.5487499865703285
#
#
# Iteration 7712
# Meta Train Error 0.6205424694344401
# Meta Train Accuracy 0.768749974668026
# Meta Valid Error 1.0377871412783861
# Meta Valid Accuracy 0.5962499864399433
#
#
# Iteration 7744
# Meta Train Error 0.6031538224779069
# Meta Train Accuracy 0.7662499826401472
# Meta Valid Error 1.0061031449586153
# Meta Valid Accuracy 0.5899999849498272
#
#
# Iteration 7776
# Meta Train Error 0.5860446500591934
# Meta Train Accuracy 0.7737499782815576
# Meta Valid Error 1.0107758957892656
# Meta Valid Accuracy 0.6124999849125743
#
#
# Iteration 7808
# Meta Train Error 0.6504401774145663
# Meta Train Accuracy 0.7612499790266156
# Meta Valid Error 1.0357146766036749
# Meta Valid Accuracy 0.5812499830499291
#
#
# Iteration 7840
# Meta Train Error 0.6836779229342937
# Meta Train Accuracy 0.7424999820068479
# Meta Valid Error 1.0037579350173473
# Meta Valid Accuracy 0.597499986179173
#
#
# Iteration 7872
# Meta Train Error 0.6498302007094026
# Meta Train Accuracy 0.7499999832361937
# Meta Valid Error 0.9804017823189497
# Meta Valid Accuracy 0.612499981187284
#
#
# Iteration 7904
# Meta Train Error 0.6689550001174212
# Meta Train Accuracy 0.7512499764561653
# Meta Valid Error 1.0697396881878376
# Meta Valid Accuracy 0.5849999841302633
#
#
# Iteration 7936
# Meta Train Error 0.6863695196807384
# Meta Train Accuracy 0.7424999848008156
# Meta Valid Error 1.0275322366505861
# Meta Valid Accuracy 0.5812499830499291
#
#
# Iteration 7968
# Meta Train Error 0.6385384825989604
# Meta Train Accuracy 0.7437499761581421
# Meta Valid Error 1.0739447642117739
# Meta Valid Accuracy 0.5649999864399433
# Iteration 8000
# Meta Train Error 0.7401662487536669
# Meta Train Accuracy 0.7262499798089266
# Meta Valid Error 1.0982180964201689
# Meta Valid Accuracy 0.566249986179173
#
#
# Iteration 8032
# Meta Train Error 0.6721406308934093
# Meta Train Accuracy 0.7524999789893627
# Meta Valid Error 1.0298546813428402
# Meta Valid Accuracy 0.5849999841302633
#
#
# Iteration 8064
# Meta Train Error 0.6823349520564079
# Meta Train Accuracy 0.7524999799206853
# Meta Valid Error 1.00677827373147
# Meta Valid Accuracy 0.5824999799951911
#
#
# Iteration 8096
# Meta Train Error 0.6677370774559677
# Meta Train Accuracy 0.7462499774992466
# Meta Valid Error 1.0210511982440948
# Meta Valid Accuracy 0.5949999848380685
#
#
# Iteration 8128
# Meta Train Error 0.6046096277423203
# Meta Train Accuracy 0.7712499685585499
# Meta Valid Error 1.0561736952513456
# Meta Valid Accuracy 0.5774999861605465
#
#
# Iteration 8160
# Meta Train Error 0.6363673866726458
# Meta Train Accuracy 0.7662499770522118
# Meta Valid Error 1.0763904172927141
# Meta Valid Accuracy 0.587499987334013
#
#
# Iteration 8192
# Meta Train Error 0.6699463361874223
# Meta Train Accuracy 0.7387499799951911
# Meta Valid Error 0.9920058231800795
# Meta Valid Accuracy 0.6149999806657434
#
#
# Iteration 8224
# Meta Train Error 0.6632787771522999
# Meta Train Accuracy 0.7637499794363976
# Meta Valid Error 0.9622794985771179
# Meta Valid Accuracy 0.6337499860674143
#
#
# Iteration 8256
# Meta Train Error 0.6856811000034213
# Meta Train Accuracy 0.737499974668026
# Meta Valid Error 1.0005824398249388
# Meta Valid Accuracy 0.6049999818205833
#
#
# Iteration 8288
# Meta Train Error 0.746406638994813
# Meta Train Accuracy 0.7162499763071537
# Meta Valid Error 1.0398590676486492
# Meta Valid Accuracy 0.592499983496964
#
#
# Iteration 8320
# Meta Train Error 0.6234792959876359
# Meta Train Accuracy 0.757499972358346
# Meta Valid Error 0.9704506080597639
# Meta Valid Accuracy 0.6224999818950891
#
#
# Iteration 8352
# Meta Train Error 0.6469883434474468
# Meta Train Accuracy 0.7449999824166298
# Meta Valid Error 0.9974516481161118
# Meta Valid Accuracy 0.5849999841302633
#
#
# Iteration 8384
# Meta Train Error 0.6298845484852791
# Meta Train Accuracy 0.7774999793618917
# Meta Valid Error 1.0064717344939709
# Meta Valid Accuracy 0.622499986551702
#
#
# Iteration 8416
# Meta Train Error 0.7273306399583817
# Meta Train Accuracy 0.7212499771267176
# Meta Valid Error 1.0351455118507147
# Meta Valid Accuracy 0.5949999843724072
#
#
# Iteration 8448
# Meta Train Error 0.6832245620898902
# Meta Train Accuracy 0.737499981187284
# Meta Valid Error 1.0920361410826445
# Meta Valid Accuracy 0.5649999883025885
#
#
# Iteration 8480
# Meta Train Error 0.7017034627497196
# Meta Train Accuracy 0.7287499755620956
# Meta Valid Error 1.0531167667359114
# Meta Valid Accuracy 0.5737499864771962
#
#
# Iteration 8512
# Meta Train Error 0.5987589862197638
# Meta Train Accuracy 0.7749999780207872
# Meta Valid Error 0.9852099614217877
# Meta Valid Accuracy 0.6024999786168337
#
#
# Iteration 8544
# Meta Train Error 0.6279689818620682
# Meta Train Accuracy 0.7612499799579382
# Meta Valid Error 0.9672642992809415
# Meta Valid Accuracy 0.6337499869987369
#
#
# Iteration 8576
# Meta Train Error 0.6401354572735727
# Meta Train Accuracy 0.7499999832361937
# Meta Valid Error 1.0077018197625875
# Meta Valid Accuracy 0.5899999821558595
#
#
# Iteration 8608
# Meta Train Error 0.6455604378134012
# Meta Train Accuracy 0.7499999776482582
# Meta Valid Error 1.0496252179145813
# Meta Valid Accuracy 0.5874999864026904
#
#
# Iteration 8640
# Meta Train Error 0.6684089433401823
# Meta Train Accuracy 0.7262499798089266
# Meta Valid Error 1.042704889550805
# Meta Valid Accuracy 0.5999999875202775
#
#
# Iteration 8672
# Meta Train Error 0.6625284291803837
# Meta Train Accuracy 0.753749979659915
# Meta Valid Error 1.0374263152480125
# Meta Valid Accuracy 0.5824999818578362
#
#
# Iteration 8704
# Meta Train Error 0.7172871232032776
# Meta Train Accuracy 0.6987499790266156
# Meta Valid Error 0.9677319619804621
# Meta Valid Accuracy 0.6049999836832285
#
#
# Iteration 8736
# Meta Train Error 0.6840450963936746
# Meta Train Accuracy 0.7474999781697989
# Meta Valid Error 1.0096820257604122
# Meta Valid Accuracy 0.6074999878183007
#
#
# Iteration 8768
# Meta Train Error 0.6873767971992493
# Meta Train Accuracy 0.747499980032444
# Meta Valid Error 1.1225374266505241
# Meta Valid Accuracy 0.5499999872408807
#
#
# Iteration 8800
# Meta Train Error 0.5962307024747133
# Meta Train Accuracy 0.7674999851733446
# Meta Valid Error 0.9891260899603367
# Meta Valid Accuracy 0.6074999896809459
#
#
# Iteration 8832
# Meta Train Error 0.6614182190969586
# Meta Train Accuracy 0.7362499814480543
# Meta Valid Error 0.9936207542195916
# Meta Valid Accuracy 0.6037499811500311
#
#
# Iteration 8864
# Meta Train Error 0.7083332780748606
# Meta Train Accuracy 0.7287499802187085
# Meta Valid Error 1.0209132609888911
# Meta Valid Accuracy 0.5887499833479524
#
#
# Iteration 8896
# Meta Train Error 0.5994267924688756
# Meta Train Accuracy 0.7824999811127782
# Meta Valid Error 1.0299205668270588
# Meta Valid Accuracy 0.5987499887123704
#
#
# Iteration 8928
# Meta Train Error 0.674283598549664
# Meta Train Accuracy 0.7412499757483602
# Meta Valid Error 1.0175547003746033
# Meta Valid Accuracy 0.6174999857321382
#
#
# Iteration 8960
# Meta Train Error 0.6143645728006959
# Meta Train Accuracy 0.7699999772012234
# Meta Valid Error 1.1035457588732243
# Meta Valid Accuracy 0.5762499859556556
#
#
# Iteration 8992
# Meta Train Error 0.6409444315358996
# Meta Train Accuracy 0.7687499765306711
# Meta Valid Error 1.034452635794878
# Meta Valid Accuracy 0.5874999864026904
#
#
# Iteration 9024
# Meta Train Error 0.6335142091847956
# Meta Train Accuracy 0.7624999769032001
# Meta Valid Error 1.0281087700277567
# Meta Valid Accuracy 0.5912499874830246
#
#
# Iteration 9056
# Meta Train Error 0.6457821959629655
# Meta Train Accuracy 0.7674999805167317
# Meta Valid Error 1.0559719037264585
# Meta Valid Accuracy 0.5549999866634607
#
#
# Iteration 9088
# Meta Train Error 0.6006766427308321
# Meta Train Accuracy 0.7749999761581421
# Meta Valid Error 1.026301583275199
# Meta Valid Accuracy 0.6024999842047691
#
#
# Iteration 9120
# Meta Train Error 0.7113790335133672
# Meta Train Accuracy 0.7337499838322401
# Meta Valid Error 1.0699131842702627
# Meta Valid Accuracy 0.5799999861046672
#
#
# Iteration 9152
# Meta Train Error 0.7038703246507794
# Meta Train Accuracy 0.7274999786168337
# Meta Valid Error 1.0089583415538073
# Meta Valid Accuracy 0.6137499855831265
#
#
# Iteration 9184
# Meta Train Error 0.6257818415760994
# Meta Train Accuracy 0.7712499760091305
# Meta Valid Error 1.069291653111577
# Meta Valid Accuracy 0.5837499853223562
#
#
# Iteration 9216
# Meta Train Error 0.6266878005117178
# Meta Train Accuracy 0.7574999816715717
# Meta Valid Error 1.0267300959676504
# Meta Valid Accuracy 0.5987499868497252
#
#
# Iteration 9248
# Meta Train Error 0.6017798343673348
# Meta Train Accuracy 0.7749999752268195
# Meta Valid Error 1.0720169302076101
# Meta Valid Accuracy 0.591249986551702
#
#
# Iteration 9280
# Meta Train Error 0.66921591386199
# Meta Train Accuracy 0.7487499788403511
# Meta Valid Error 1.006226483732462
# Meta Valid Accuracy 0.6062499834224582
#
#
# Iteration 9312
# Meta Train Error 0.666649513412267
# Meta Train Accuracy 0.752499982714653
# Meta Valid Error 1.007396675646305
# Meta Valid Accuracy 0.6037499802187085
#
#
# Iteration 9344
# Meta Train Error 0.6262065661139786
# Meta Train Accuracy 0.7549999859184027
# Meta Valid Error 1.0567824933677912
# Meta Valid Accuracy 0.5912499851547182
#
#
# Iteration 9376
# Meta Train Error 0.6334114577621222
# Meta Train Accuracy 0.7774999747052789
# Meta Valid Error 0.9577191825956106
# Meta Valid Accuracy 0.6387499887496233
#
#
# Iteration 9408
# Meta Train Error 0.6296976488083601
# Meta Train Accuracy 0.761249978095293
# Meta Valid Error 1.0203318912535906
# Meta Valid Accuracy 0.5987499859184027
#
#
# Iteration 9440
# Meta Train Error 0.5957506969571114
# Meta Train Accuracy 0.7624999769032001
# Meta Valid Error 1.0578638650476933
# Meta Valid Accuracy 0.5737499836832285
#
#
# Iteration 9472
# Meta Train Error 0.7295642397366464
# Meta Train Accuracy 0.7062499783933163
# Meta Valid Error 1.002275725826621
# Meta Valid Accuracy 0.6012499881908298
#
#
# Iteration 9504
# Meta Train Error 0.7038534730672836
# Meta Train Accuracy 0.7349999845027924
# Meta Valid Error 1.008915975689888
# Meta Valid Accuracy 0.6124999905005097
#
#
# Iteration 9536
# Meta Train Error 0.6217766748741269
# Meta Train Accuracy 0.7499999804422259
# Meta Valid Error 1.100847665220499
# Meta Valid Accuracy 0.582499987911433
#
#
# Iteration 9568
# Meta Train Error 0.6766927158460021
# Meta Train Accuracy 0.7424999792128801
# Meta Valid Error 1.0060775484889746
# Meta Valid Accuracy 0.5999999828636646
# Iteration 9600
# Meta Train Error 0.6670060949400067
# Meta Train Accuracy 0.7537499777972698
# Meta Valid Error 1.0390388425439596
# Meta Valid Accuracy 0.5962499845772982
#
#
# Iteration 9632
# Meta Train Error 0.7208412950858474
# Meta Train Accuracy 0.7124999798834324
# Meta Valid Error 1.071798788383603
# Meta Valid Accuracy 0.5762499859556556
#
#
# Iteration 9664
# Meta Train Error 0.686449462082237
# Meta Train Accuracy 0.733749981969595
# Meta Valid Error 0.9462465960532427
# Meta Valid Accuracy 0.6374999824911356
#
#
# Iteration 9696
# Meta Train Error 0.6974905664101243
# Meta Train Accuracy 0.7549999766051769
# Meta Valid Error 1.0772795844823122
# Meta Valid Accuracy 0.5749999824911356
#
#
# Iteration 9728
# Meta Train Error 0.6711484687402844
# Meta Train Accuracy 0.7512499801814556
# Meta Valid Error 1.0725201908499002
# Meta Valid Accuracy 0.5662499889731407
#
#
# Iteration 9760
# Meta Train Error 0.6807611910626292
# Meta Train Accuracy 0.7324999757111073
# Meta Valid Error 0.9962526429444551
# Meta Valid Accuracy 0.5912499818950891
#
#
# Iteration 9792
# Meta Train Error 0.6748548904433846
# Meta Train Accuracy 0.7362499805167317
# Meta Valid Error 1.0363121945410967
# Meta Valid Accuracy 0.5737499874085188
#
#
# Iteration 9824
# Meta Train Error 0.6553489817306399
# Meta Train Accuracy 0.7437499817460775
# Meta Valid Error 1.0103448648005724
# Meta Valid Accuracy 0.5924999816343188
#
#
# Iteration 9856
# Meta Train Error 0.6267700609751046
# Meta Train Accuracy 0.7624999806284904
# Meta Valid Error 1.0225389711558819
# Meta Valid Accuracy 0.5999999884516001
#
#
# Iteration 9888
# Meta Train Error 0.6136443996801972
# Meta Train Accuracy 0.7737499792128801
# Meta Valid Error 1.0077909771353006
# Meta Valid Accuracy 0.5912499874830246
#
#
# Iteration 9920
# Meta Train Error 0.6181004904210567
# Meta Train Accuracy 0.7699999837204814
# Meta Valid Error 1.0006543211638927
# Meta Valid Accuracy 0.6112499870359898
#
#
# Iteration 9952
# Meta Train Error 0.6082515423186123
# Meta Train Accuracy 0.769999978132546
# Meta Valid Error 0.9323403239250183
# Meta Valid Accuracy 0.6299999840557575
#
#
# Iteration 9984
# Meta Train Error 0.7043418465182185
# Meta Train Accuracy 0.7249999791383743
# Meta Valid Error 1.0730752749368548
# Meta Valid Accuracy 0.551249984651804
# Meta Test Error 0.9760141484439373
# Meta Test Accuracy 0.6212499849498272
